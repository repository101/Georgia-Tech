# %%
import pathlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from LoadData import LoadData

# %%
cwd = pathlib.Path().absolute()
boosted_accuracy_MNIST = np.loadtxt("{}/boosted_accuracy_MNIST.csv".format(cwd), delimiter=",")
boosted_runtime_MNIST = np.loadtxt("{}/boosted_runtime_MNIST.csv".format(cwd), delimiter=",")
boosted_accuracy_FashionMNIST = np.loadtxt("{}/boosted_accuracy_Fashion-MNIST.csv".format(cwd), delimiter=",")
boosted_runtime_FashionMNIST = np.loadtxt("{}/boosted_runtime_Fashion-MNIST.csv".format(cwd), delimiter=",")

decision_tree_entropy_accuracy_MNIST = np.loadtxt("{}/entropy_accuracy_MNIST.csv".format(cwd), delimiter=",")
decision_tree_entropy_runtime_MNIST = np.loadtxt("{}/entropy_runtime_MNIST.csv".format(cwd), delimiter=",")
decision_tree_entropy_accuracy_FashionMNIST = np.loadtxt("{}/entropy_accuracy_Fashion-MNIST.csv".format(cwd), delimiter=",")
decision_tree_entropy_runtime_FashionMNIST = np.loadtxt("{}/entropy_runtime_Fashion-MNIST.csv".format(cwd), delimiter=",")

decision_tree_gini_accuracy_MNIST = np.loadtxt("{}/gini_accuracy_MNIST.csv".format(cwd), delimiter=",")
decision_tree_gini_runtime_MNIST = np.loadtxt("{}/gini_runtime_MNIST.csv".format(cwd), delimiter=",")
decision_tree_gini_accuracy_FashionMNIST = np.loadtxt("{}/gini_accuracy_Fashion-MNIST.csv".format(cwd), delimiter=",")
decision_tree_gini_runtime_FashionMNIST = np.loadtxt("{}/gini_runtime_Fashion-MNIST.csv".format(cwd), delimiter=",")

knn_accuracy_MNIST = np.loadtxt("{}/knn_accuracy_MNIST.csv".format(cwd), delimiter=",")
knn_runtime_MNIST = np.loadtxt("{}/knn_runtime_MNIST.csv".format(cwd), delimiter=",")
knn_accuracy_FashionMNIST = np.loadtxt("{}/knn_accuracy_Fashion-MNIST.csv".format(cwd), delimiter=",")
knn_runtime_FashionMNIST = np.loadtxt("{}/knn_runtime_Fashion-MNIST.csv".format(cwd), delimiter=",")

neural_adam_accuracy_MNIST = np.loadtxt("{}/adam_accuracy_MNIST.csv".format(cwd), delimiter=",")
neural_adam_runtime_MNIST = np.loadtxt("{}/adam_runtime_MNIST.csv".format(cwd), delimiter=",")
neural_adam_accuracy_FashionMNIST = np.loadtxt("{}/adam_accuracy_Fashion-MNIST.csv".format(cwd), delimiter=",")
neural_adam_runtime_FashionMNIST = np.loadtxt("{}/adam_runtime_Fashion-MNIST.csv".format(cwd), delimiter=",")

neural_sgd_accuracy_MNIST = np.loadtxt("{}/sgd_accuracy_MNIST.csv".format(cwd), delimiter=",")
neural_sgd_runtime_MNIST = np.loadtxt("{}/sgd_runtime_MNIST.csv".format(cwd), delimiter=",")
neural_sgd_accuracy_FashionMNIST = np.loadtxt("{}/sgd_accuracy_Fashion-MNIST.csv".format(cwd), delimiter=",")
neural_sgd_runtime_FashionMNIST = np.loadtxt("{}/sgd_runtime_Fashion-MNIST.csv".format(cwd), delimiter=",")

svm_linear_accuracy_MNIST = np.loadtxt("{}/svm_linear_accuracy_MNIST.csv".format(cwd), delimiter=",")
svm_linear_runtime_MNIST = np.loadtxt("{}/svm_linear_runtime_MNIST.csv".format(cwd), delimiter=",")
svm_linear_accuracy_FashionMNIST = np.loadtxt("{}/svm_linear_accuracy_Fashion-MNIST.csv".format(cwd), delimiter=",")
svm_linear_runtime_FashionMNIST = np.loadtxt("{}/svm_linear_runtime_Fashion-MNIST.csv".format(cwd), delimiter=",")

svm_rbf_accuracy_MNIST = np.loadtxt("{}/svm_rbf_accuracy_MNIST.csv".format(cwd), delimiter=",")
svm_rbf_runtime_MNIST = np.loadtxt("{}/svm_rbf_runtime_MNIST.csv".format(cwd), delimiter=",")
svm_rbf_accuracy_FashionMNIST = np.loadtxt("{}/svm_rbf_accuracy_Fashion-MNIST.csv".format(cwd), delimiter=",")
svm_rbf_runtime_FashionMNIST = np.loadtxt("{}/svm_rbf_runtime_Fashion-MNIST.csv".format(cwd), delimiter=",")

# %%
names = ["Histogram Boosted Decision Tree", "Decision Tree (Entropy)", "Decision Tree (Gini)", 
        "K-Nearest Neighbor", "Neural Network (Adam)", "Neural Network (SGD)", "Support Vector Machine (Linear)", 
         "Support Vector Machine (RBF)"]

colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 
          'tab:purple', 'tab:brown', 'tab:pink', 'tab:olive']

accuracies_mnist = np.asarray([boosted_accuracy_MNIST, decision_tree_entropy_accuracy_MNIST, decision_tree_gini_accuracy_MNIST, 
                    knn_accuracy_MNIST, neural_adam_accuracy_MNIST, neural_sgd_accuracy_MNIST, svm_linear_accuracy_MNIST, 
                    svm_rbf_accuracy_MNIST])
accuracies_fashion = np.asarray([boosted_accuracy_FashionMNIST, decision_tree_entropy_accuracy_FashionMNIST, 
                      decision_tree_gini_accuracy_FashionMNIST, knn_accuracy_FashionMNIST, neural_adam_accuracy_FashionMNIST, 
                      neural_sgd_accuracy_FashionMNIST, svm_linear_accuracy_FashionMNIST, svm_rbf_accuracy_FashionMNIST])
runtime_mnist = np.asarray([boosted_runtime_MNIST, decision_tree_entropy_runtime_MNIST, decision_tree_gini_runtime_MNIST, 
                 knn_runtime_MNIST, neural_adam_runtime_MNIST, neural_sgd_runtime_MNIST, svm_linear_runtime_MNIST, 
                 svm_rbf_runtime_MNIST])
runtime_fashion = np.asarray([boosted_runtime_FashionMNIST, decision_tree_entropy_runtime_FashionMNIST, decision_tree_gini_runtime_FashionMNIST, 
                   knn_runtime_FashionMNIST, neural_adam_runtime_FashionMNIST, neural_sgd_runtime_FashionMNIST, svm_linear_runtime_FashionMNIST, 
                   svm_rbf_runtime_FashionMNIST])

# %%
somelist = []
limit = 11
Dataset = "MNIST"

if Dataset == "MNIST":
    somelist = np.asarray([i[:limit] for i in accuracies_mnist])
else:
    somelist = np.asarray([i[:limit] for i in accuracies_fashion])



with plt.style.context('ggplot'):
    fig0, ax0 = plt.subplots()
    ax0.set_xlabel("Percent of Training Set")
    ax0.set_ylabel("Accuracy (%)", color='tab:orange')
    ax0.set_title("Accuracy vs Training Set Size \n {}".format(Dataset))
    ax0.tick_params(axis='y', labelcolor="black")
    ax0.set_ylim(0, 1.1)
    for i in range(len(names)):
        ax0.plot([i for i in range(limit)], somelist[i], colors[i],
                 marker='o', label=names[i]+" -  {}%".format(round((somelist[i][-1] * 100), 2)))
#     ax3 = ax0.twinx()
#     ax3.set_ylabel("Training Time (s)", color="tab:blue")
#     ax3.set_ylim(0, max(max(adam_runtime), max(sgd_runtime)) + 10)
#     ax3.tick_params(axis='y', labelcolor="black")
#     for i in range(1):        
#         ax0.plot([i for i in range(11)], acc[solver], colors[i], marker='o', label=solvers[solver])
#         ax3.plot([i for i in range(11)], run[solver], colors[i+1], marker="1", label="{} training-time".format(solvers[solver]))
    from matplotlib.font_manager import FontProperties

    fontP = FontProperties()
    fontP.set_size('small')
    fig0.tight_layout()
    ax0.legend(bbox_to_anchor=(1.6, 1.3), prop=fontP)


    directory = "{}/Training_{}_{}_Set_Size_{}%_Impact_vs_Accuracy.png".format(cwd, "All", Dataset, str(limit * 10))
    plt.savefig(directory, bbox_inches='tight')

# %%
somelist = []
limit = 11
Dataset = "Fashion-MNIST"

if Dataset == "MNIST":
    somelist = np.asarray([i[:limit] for i in runtime_mnist])
else:
    somelist = np.asarray([i[:limit] for i in runtime_fashion])



with plt.style.context('ggplot'):
    fig0, ax0 = plt.subplots(figsize=(9, 6))
    ax0.set_xlabel("Percent of Training Set")
    ax0.set_ylabel("Training Time (s)", color='tab:orange')
    ax0.set_title("Training Time vs Training Set Size \n {}".format(Dataset))
    ax0.tick_params(axis='y', labelcolor="black")
    ax0.set_ylim(0, max([max(i) for i in somelist]) + (0.10 * max([max(i) for i in somelist])))
    for i in range(len(names)):
        ax0.plot([i for i in range(limit)], somelist[i], colors[i],
                 marker='o', label=names[i]+" -  {}s".format(round((somelist[i][-1]), 2)))
#     ax3 = ax0.twinx()
#     ax3.set_ylabel("Training Time (s)", color="tab:blue")
#     ax3.set_ylim(0, max(max(adam_runtime), max(sgd_runtime)) + 10)
#     ax3.tick_params(axis='y', labelcolor="black")
#     for i in range(1):        
#         ax0.plot([i for i in range(11)], acc[solver], colors[i], marker='o', label=solvers[solver])
#         ax3.plot([i for i in range(11)], run[solver], colors[i+1], marker="1", label="{} training-time".format(solvers[solver]))
    from matplotlib.font_manager import FontProperties

    fontP = FontProperties()
    fontP.set_size('small')
    ax0.legend(bbox_to_anchor=(1.01, 1.2), prop=fontP, borderaxespad=0.)


    directory = "{}/Training_{}_{}_Set_Size_{}%_Impact_vs_Training_Time.png".format(cwd, "All", Dataset, str(limit * 10))
#     plt.savefig(str(cwd) + "/test" + '.png', bbox_inches='tight')
    plt.savefig(directory, bbox_inches='tight')

# %%
def LoadData(path_to_csv):
    extension = path_to_csv[(len(path_to_csv) - 4): len(path_to_csv)]
    if extension != ".csv":
        path_to_csv += ".csv"
    print("Attempting to load: {}\n".format(path_to_csv.split("/")[-1]))
    raw_combined_data = np.loadtxt(path_to_csv, delimiter=",", dtype=np.uint8)
    print("Loading Complete")
    print("Data Statistics: \n"
          "   Number of Entries: {} \n"
          "   Shape of Entry: {}\n".format(raw_combined_data.shape[0], raw_combined_data[0].shape))
    labels = raw_combined_data[:, 0]
    data = raw_combined_data[:, 1::]
    return labels, data, raw_combined_data

# %%
Dataset = "Fashion-MNIST"
if Dataset == "MNIST":
    training_data_path = "{}/mnist-train-data.csv".format(cwd)
    testing_data_path = "{}/mnist-test-data.csv".format(cwd)
else:
    training_data_path = "{}/fashion-mnist-train-data.csv".format(cwd)
    testing_data_path = "{}/fashion-mnist-test-data.csv".format(cwd)

training_labels, training_data, _ = LoadData(training_data_path)
testing_labels, testing_data, _ = LoadData(testing_data_path)
# Out:
# Attempting to load: fashion-mnist-train-data.csv
#
# Loading Complete
# Data Statistics:
#    Number of Entries: 60000
#    Shape of Entry: (785,)
#
# Attempting to load: fashion-mnist-test-data.csv
#
# Loading Complete
# Data Statistics:
#    Number of Entries: 10000
#    Shape of Entry: (785,)

# %%
test = np.hstack(training_data)
test = test[test != 0]
test = test[test != 1]
test = test[test != 2]
test = test[test != 3]
test = test[test != 4]
test = test[test != 5]
test = test[test != 255]
test = test[test != 254]
test = test[test != 253]
test = test[test != 252]
test = test[test != 251]
test = test[test != 250]
test = test[test != 249]

# %%
df = pd.Series(test)

# %%
df.plot.hist(bins=243, title="{} Pixel Intensity Histogram".format(Dataset))
plt.savefig("{}/{} Pixel Intensity Histogram.png".format(cwd, Dataset))
