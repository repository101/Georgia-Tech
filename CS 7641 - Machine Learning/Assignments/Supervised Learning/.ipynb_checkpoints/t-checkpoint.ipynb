# %%
import pathlib
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from LoadData import LoadData
from sklearn.utils import parallel_backend
from sklearn import svm
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import learning_curve, validation_curve
from sklearn.metrics import classification_report, confusion_matrix


TESTING = True
DECISION_TREE = False
SUPPORT_VECTOR = True
NEURAL_NET = False
K_NEAREST = False
BOOSTING = False
NORMALIZE_DATA = False
USE_PCA = True
DataSetName = "MNIST"
dataset = "MNIST"

# %%
def plot_learning_curve(estimator, title, X, y, axes=None, ylim=None, cv=None,
                        n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5)):
    """
    Generate 3 plots: the test and training learning curve, the training
    samples vs fit times curve, the fit times vs score curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    axes : array of 3 axes, optional (default=None)
        Axes to use for plotting the curves.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : int, cross-validation generator or an iterable, optional
        Determines the cross-validation splitting strategy.
        Possible inputs for cv are:
          - None, to use the default 5-fold cross-validation,
          - integer, to specify the number of folds.
          - :term:`CV splitter`,
          - An iterable yielding (train, test) splits as arrays of indices.

        For integer/None inputs, if ``y`` is binary or multiclass,
        :class:`StratifiedKFold` used. If the estimator is not a classifier
        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.

        Refer :ref:`User Guide <cross_validation>` for the various
        cross-validators that can be used here.

    n_jobs : int or None, optional (default=None)
        Number of jobs to run in parallel.
        ``None`` means 1 unless in a :obj:`joblib.parallel_backend` context.
        ``-1`` means using all processors. See :term:`Glossary <n_jobs>`
        for more details.

    train_sizes : array-like, shape (n_ticks,), dtype float or int
        Relative or absolute numbers of training examples that will be used to
        generate the learning curve. If the dtype is float, it is regarded as a
        fraction of the maximum size of the training set (that is determined
        by the selected validation method), i.e. it has to be within (0, 1].
        Otherwise it is interpreted as absolute sizes of the training sets.
        Note that for classification the number of samples usually have to
        be big enough to contain at least one sample from each class.
        (default: np.linspace(0.1, 1.0, 5))
    """
    with plt.style.context('ggplot'):
        if axes is None:
            _, axes = plt.subplots(1, 3, figsize=(20, 5))

        axes[0].set_title(title)
        if ylim is not None:
            axes[0].set_ylim(*ylim)
        axes[0].set_xlabel("Training examples")
        axes[0].set_ylabel("Score")

        train_sizes, train_scores, test_scores, fit_times, _ = \
            learning_curve(estimator, X, y, cv=cv, n_jobs=n_jobs,
                           train_sizes=train_sizes,
                           return_times=True)
        train_scores_mean = np.mean(train_scores, axis=1)
        train_scores_std = np.std(train_scores, axis=1)
        test_scores_mean = np.mean(test_scores, axis=1)
        test_scores_std = np.std(test_scores, axis=1)
        fit_times_mean = np.mean(fit_times, axis=1)
        fit_times_std = np.std(fit_times, axis=1)

        # Plot learning curve
        axes[0].grid()
        axes[0].fill_between(train_sizes, train_scores_mean - train_scores_std,
                             train_scores_mean + train_scores_std, alpha=0.1,
                             color="r")
        axes[0].fill_between(train_sizes, test_scores_mean - test_scores_std,
                             test_scores_mean + test_scores_std, alpha=0.1,
                             color="g")
        axes[0].plot(train_sizes, train_scores_mean, 'o-', color="r",
                     label="Training score")
        axes[0].plot(train_sizes, test_scores_mean, 'o-', color="g",
                     label="Cross-validation score")
        axes[0].legend(loc="best")

        # Plot n_samples vs fit_times
        axes[1].grid()
        axes[1].plot(train_sizes, fit_times_mean, 'o-')
        axes[1].fill_between(train_sizes, fit_times_mean - fit_times_std,
                             fit_times_mean + fit_times_std, alpha=0.1)
        axes[1].set_xlabel("Training examples")
        axes[1].set_ylabel("fit_times")
        axes[1].set_title("Scalability of the model")

        # Plot fit_time vs score
        axes[2].grid()
        axes[2].plot(fit_times_mean, test_scores_mean, 'o-')
        axes[2].fill_between(fit_times_mean, test_scores_mean - test_scores_std,
                             test_scores_mean + test_scores_std, alpha=0.1)
        axes[2].set_xlabel("fit_times")
        axes[2].set_ylabel("Score")
        axes[2].set_title("Performance of the model")

        return plt

# %%
"""

1. Call train_test_split to get the training data and test data (x_train, x_test, y_train, and y_test respectively.
2. Save the test data (x_test, y_test) until the end.
3. Repeat the following for each algorithm: SVM, Decision Tree, Boosting, NN, and KNN:
4. Select a set of hyperparameters to optimize.
5. Pass these and the classifier object (DecisionTree for example) into GridSearchCV.
6. This returns a clf object that you then call clf.fit(x_train, y_train) to get the best hyperparameters.
7. Get the Learning Curve by taking the clf.best_estimator_ and passing it into learning_curve function of scikit learn.
8. Plot the learning curve results
9. Get the Model Complexity data by taking the clf.best_estimator_ and passing it into the validation_curve function. Pass in one hyperparameter to tune that was not tuned in your GridSearchCV process in number 5 above.
10. Plot the results of validation_curve.
11. Run the x_test and y_test through clf.best_estimator_ predict to see how the model performs.

"""

# %%
"""
STEP 1.

"""
classifiers = ["SVM", "Decision Tree", "Neural Network", "K-Nearest Neighbors", "Boosting"]
n_jobs = -1
cross_validation = 5
verbose_int = 3

cwd = pathlib.Path().absolute()

if DataSetName == "MNIST":
    training_data_path = "{}/sm-mnist-train-data.csv".format(cwd)
    testing_data_path = "{}/sm-mnist-test-data.csv".format(cwd)
else:
    training_data_path = "{}/sm-fashion-mnist-train-data.csv".format(cwd)
    testing_data_path = "{}/sm-fashion-mnist-test-data.csv".format(cwd)

training_labels, training_data, _ = LoadData(training_data_path)
testing_labels, testing_data, _ = LoadData(testing_data_path)

Scaler = StandardScaler().fit(training_data)

training_data = Scaler.transform(training_data)
testing_data = Scaler.transform(testing_data)
# Out:
# Attempting to load: sm-mnist-train-data.csv
#
# Loading Complete
# Data Statistics:
#    Number of Entries: 5000
#    Shape of Entry: (785,)
#
# Attempting to load: sm-mnist-test-data.csv
#
# Loading Complete
# Data Statistics:
#    Number of Entries: 5000
#    Shape of Entry: (785,)

# %%
"""
STEP 3.

"""

svm_params = {'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
             'gamma': [1e-4, 1e-3, 1e-2, 1e-1],
             'max_iter': [1000]}

decision_tree_params = {'criterion': ['gini', 'entropy'],
                       'max_depth': [50, 100, 150, 200],
                       'min_samples_split': [i for i in range(4, 13, 4)]}

neural_network_params = {'activation': ['identity', 'relu'],
                        'solver': ['lbfgs', 'sgd', 'adam'],
                        'max_iter': [1000],
                        'alpha': [1e-4, 1e-3, 1e-2, 1e-1]}

knn_params = {'n_neighbors': [3, 5, 7, 9, 11],
             'algorithm': ['ball_tree', 'kd_tree', 'brute']}

boosting_params = {'n_estimators': [50, 100, 150],
                  'max_depth': [1, 2, 3],
                  'learning_rate': [1e-1, 1e-2, 1e-3]}

# %%
X = training_data[:2000]
Validation_X = X[:400]
y = training_labels[:2000]
validation_y = y[:400]
container = {"train_sizes": None, "train_scores": None, "test_scores": None, "fit_times": None}
train_sizes = np.linspace(.1, 1.0, 50)
colors = ["tab:orange", "tab:blue", "tab:green", "tab:red"]

# %%
svm_segment = "Support Vector Machine"
svm_estimator=svm.SVC()
svm_grid_search = GridSearchCV(svm_estimator, param_grid=svm_params, n_jobs=n_jobs, verbose=verbose_int)
svm_learning_curve_results = {"train_sizes": None, "train_scores": None, "test_scores": None, "fit_times": None}
svm_validation_curve_results = {"train_scores": None, "test_scores": None}
svm_param_name = "C"

# %%
with parallel_backend('threading'):
    svm_grid_search.fit(X,y)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] gamma=0.0001, kernel=linear, max_iter=1000 ......................
# [CV] gamma=0.0001, kernel=linear, max_iter=1000 ......................
# [CV] gamma=0.0001, kernel=linear, max_iter=1000 ......................
# [CV] gamma=0.0001, kernel=linear, max_iter=1000 ......................
# [CV] gamma=0.0001, kernel=linear, max_iter=1000 ......................
# [CV] gamma=0.0001, kernel=poly, max_iter=1000 ........................[CV] gamma=0.0001, kernel=poly, max_iter=1000 ........................
# [CV] gamma=0.0001, kernel=poly, max_iter=1000 ........................
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# C:\Users\joshu\Anaconda3\envs\CS7641\lib\site-packages\sklearn\svm\_base.py:231: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\joshu\Anaconda3\envs\CS7641\lib\site-packages\sklearn\svm\_base.py:231: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\joshu\Anaconda3\envs\CS7641\lib\site-packages\sklearn\svm\_base.py:231: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# [CV]  gamma=0.0001, kernel=linear, max_iter=1000, score=0.853, total=   3.1s
# [CV] gamma=0.0001, kernel=poly, max_iter=1000 ........................
# [CV]  gamma=0.0001, kernel=linear, max_iter=1000, score=0.885, total=   3.1s
# [CV] gamma=0.0001, kernel=poly, max_iter=1000 ........................
# [CV]  gamma=0.0001, kernel=linear, max_iter=1000, score=0.925, total=   3.2s
# [CV] gamma=0.0001, kernel=rbf, max_iter=1000 .........................
# [CV]  gamma=0.0001, kernel=linear, max_iter=1000, score=0.833, total=   3.4s
# [CV] gamma=0.0001, kernel=rbf, max_iter=1000 .........................
# [CV]  gamma=0.0001, kernel=linear, max_iter=1000, score=0.882, total=   3.5s
# [CV] gamma=0.0001, kernel=rbf, max_iter=1000 .........................
# [CV]  gamma=0.0001, kernel=rbf, max_iter=1000, score=0.860, total=   8.1s
# [CV] gamma=0.0001, kernel=rbf, max_iter=1000 .........................
# [CV]  gamma=0.0001, kernel=rbf, max_iter=1000, score=0.805, total=   8.8s
# [CV] gamma=0.0001, kernel=rbf, max_iter=1000 .........................
# [CV]  gamma=0.0001, kernel=rbf, max_iter=1000, score=0.802, total=   8.8s
# [CV] gamma=0.0001, kernel=sigmoid, max_iter=1000 .....................
# [CV]  gamma=0.0001, kernel=poly, max_iter=1000, score=0.113, total=  12.7s
# [CV] gamma=0.0001, kernel=sigmoid, max_iter=1000 .....................
# [CV]  gamma=0.0001, kernel=poly, max_iter=1000, score=0.113, total=  13.3s
# [CV] gamma=0.0001, kernel=sigmoid, max_iter=1000 .....................
# [CV]  gamma=0.0001, kernel=poly, max_iter=1000, score=0.113, total=  13.5s
# [CV] gamma=0.0001, kernel=sigmoid, max_iter=1000 .....................
# [CV]  gamma=0.0001, kernel=poly, max_iter=1000, score=0.110, total=  13.2s
# [CV] gamma=0.0001, kernel=sigmoid, max_iter=1000 .....................
# [CV]  gamma=0.0001, kernel=poly, max_iter=1000, score=0.113, total=  13.5s
# [CV] gamma=0.001, kernel=linear, max_iter=1000 .......................
# C:\Users\joshu\Anaconda3\envs\CS7641\lib\site-packages\sklearn\svm\_base.py:231: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# [CV]  gamma=0.0001, kernel=rbf, max_iter=1000, score=0.887, total=   7.7s
# [CV] gamma=0.001, kernel=linear, max_iter=1000 .......................
# [CV]  gamma=0.001, kernel=linear, max_iter=1000, score=0.885, total=   3.8s
# [CV] gamma=0.001, kernel=linear, max_iter=1000 .......................
# [CV]  gamma=0.0001, kernel=rbf, max_iter=1000, score=0.853, total=   9.7s
# [CV] gamma=0.001, kernel=linear, max_iter=1000 .......................
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   20.9s
# [CV]  gamma=0.0001, kernel=sigmoid, max_iter=1000, score=0.815, total=   9.4s
# [CV] gamma=0.001, kernel=linear, max_iter=1000 .......................
# [CV]  gamma=0.0001, kernel=sigmoid, max_iter=1000, score=0.777, total=   9.2s
# [CV] gamma=0.001, kernel=poly, max_iter=1000 .........................
# C:\Users\joshu\Anaconda3\envs\CS7641\lib\site-packages\sklearn\svm\_base.py:231: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# [CV]  gamma=0.001, kernel=linear, max_iter=1000, score=0.853, total=   3.3s
# [CV] gamma=0.001, kernel=poly, max_iter=1000 .........................
# [CV]  gamma=0.001, kernel=linear, max_iter=1000, score=0.833, total=   3.1s
# [CV] gamma=0.001, kernel=poly, max_iter=1000 .........................
# C:\Users\joshu\Anaconda3\envs\CS7641\lib\site-packages\sklearn\svm\_base.py:231: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# [CV]  gamma=0.0001, kernel=sigmoid, max_iter=1000, score=0.740, total=  10.8s
# [CV] gamma=0.001, kernel=poly, max_iter=1000 .........................
# [CV]  gamma=0.0001, kernel=sigmoid, max_iter=1000, score=0.797, total=  10.8s
# [CV] gamma=0.001, kernel=poly, max_iter=1000 .........................
# [CV]  gamma=0.001, kernel=linear, max_iter=1000, score=0.882, total=   3.5s
# [CV] gamma=0.001, kernel=rbf, max_iter=1000 ..........................
# [CV]  gamma=0.001, kernel=linear, max_iter=1000, score=0.925, total=   3.4s
# [CV] gamma=0.001, kernel=rbf, max_iter=1000 ..........................
# [CV]  gamma=0.0001, kernel=sigmoid, max_iter=1000, score=0.833, total=  10.8s
# [CV] gamma=0.001, kernel=rbf, max_iter=1000 ..........................
# [CV]  gamma=0.001, kernel=rbf, max_iter=1000, score=0.895, total=   6.2s
# [CV] gamma=0.001, kernel=rbf, max_iter=1000 ..........................
# [CV]  gamma=0.001, kernel=rbf, max_iter=1000, score=0.863, total=   6.0s
# [CV] gamma=0.001, kernel=rbf, max_iter=1000 ..........................
# [CV]  gamma=0.001, kernel=rbf, max_iter=1000, score=0.863, total=   5.3s
# [CV] gamma=0.001, kernel=sigmoid, max_iter=1000 ......................
# [CV]  gamma=0.001, kernel=poly, max_iter=1000, score=0.343, total=  12.9s
# [CV] gamma=0.001, kernel=sigmoid, max_iter=1000 ......................
# [CV]  gamma=0.001, kernel=poly, max_iter=1000, score=0.290, total=  11.6s
# [CV] gamma=0.001, kernel=sigmoid, max_iter=1000 ......................
# [CV]  gamma=0.001, kernel=poly, max_iter=1000, score=0.328, total=  12.4s
# [CV] gamma=0.001, kernel=sigmoid, max_iter=1000 ......................
# [CV]  gamma=0.001, kernel=poly, max_iter=1000, score=0.307, total=  11.5s
# [CV] gamma=0.001, kernel=sigmoid, max_iter=1000 ......................
# [CV]  gamma=0.001, kernel=rbf, max_iter=1000, score=0.895, total=   5.5s
# [CV] gamma=0.01, kernel=linear, max_iter=1000 ........................
# [CV]  gamma=0.001, kernel=poly, max_iter=1000, score=0.343, total=  12.5s
# [CV] gamma=0.01, kernel=linear, max_iter=1000 ........................
# [CV]  gamma=0.001, kernel=sigmoid, max_iter=1000, score=0.890, total=   4.6s
# [CV] gamma=0.01, kernel=linear, max_iter=1000 ........................
# [CV]  gamma=0.001, kernel=rbf, max_iter=1000, score=0.927, total=   6.5s
# [CV] gamma=0.01, kernel=linear, max_iter=1000 ........................
# C:\Users\joshu\Anaconda3\envs\CS7641\lib\site-packages\sklearn\svm\_base.py:231: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# [CV]  gamma=0.01, kernel=linear, max_iter=1000, score=0.885, total=   3.1s
# [CV] gamma=0.01, kernel=linear, max_iter=1000 ........................
# [CV]  gamma=0.001, kernel=sigmoid, max_iter=1000, score=0.855, total=   4.3s
# [CV] gamma=0.01, kernel=poly, max_iter=1000 ..........................
# C:\Users\joshu\Anaconda3\envs\CS7641\lib\site-packages\sklearn\svm\_base.py:231: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# [CV]  gamma=0.001, kernel=sigmoid, max_iter=1000, score=0.853, total=   4.9s
# [CV] gamma=0.01, kernel=poly, max_iter=1000 ..........................
# [CV]  gamma=0.01, kernel=linear, max_iter=1000, score=0.833, total=   2.9s
# [CV] gamma=0.01, kernel=poly, max_iter=1000 ..........................
# [CV]  gamma=0.01, kernel=linear, max_iter=1000, score=0.853, total=   3.5s
# [CV] gamma=0.01, kernel=poly, max_iter=1000 ..........................
# C:\Users\joshu\Anaconda3\envs\CS7641\lib\site-packages\sklearn\svm\_base.py:231: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# [CV]  gamma=0.001, kernel=sigmoid, max_iter=1000, score=0.935, total=   4.7s
# [CV] gamma=0.01, kernel=poly, max_iter=1000 ..........................
# [CV]  gamma=0.001, kernel=sigmoid, max_iter=1000, score=0.887, total=   5.0s
# [CV] gamma=0.01, kernel=rbf, max_iter=1000 ...........................
# [CV]  gamma=0.01, kernel=linear, max_iter=1000, score=0.882, total=   3.4s
# [CV] gamma=0.01, kernel=rbf, max_iter=1000 ...........................
# [CV]  gamma=0.01, kernel=linear, max_iter=1000, score=0.925, total=   3.6s
# [CV] gamma=0.01, kernel=rbf, max_iter=1000 ...........................
# [CV]  gamma=0.01, kernel=poly, max_iter=1000, score=0.902, total=   9.7s
# [CV] gamma=0.01, kernel=rbf, max_iter=1000 ...........................
# [CV]  gamma=0.01, kernel=poly, max_iter=1000, score=0.855, total=   9.4s
# [CV] gamma=0.01, kernel=rbf, max_iter=1000 ...........................
# [CV]  gamma=0.01, kernel=poly, max_iter=1000, score=0.863, total=  10.2s
# [CV] gamma=0.01, kernel=sigmoid, max_iter=1000 .......................
# [CV]  gamma=0.01, kernel=poly, max_iter=1000, score=0.905, total=   9.5s
# [CV] gamma=0.01, kernel=sigmoid, max_iter=1000 .......................
# [CV]  gamma=0.01, kernel=poly, max_iter=1000, score=0.905, total=  10.4s
# [CV] gamma=0.01, kernel=sigmoid, max_iter=1000 .......................
# [CV]  gamma=0.01, kernel=sigmoid, max_iter=1000, score=0.590, total=   3.4s
# [CV] gamma=0.01, kernel=sigmoid, max_iter=1000 .......................
# [CV]  gamma=0.01, kernel=sigmoid, max_iter=1000, score=0.610, total=   4.0s
# [CV] gamma=0.01, kernel=sigmoid, max_iter=1000 .......................
# [CV]  gamma=0.01, kernel=sigmoid, max_iter=1000, score=0.555, total=   3.7s
# [CV] gamma=0.1, kernel=linear, max_iter=1000 .........................
# [CV]  gamma=0.01, kernel=rbf, max_iter=1000, score=0.730, total=  13.7s
# [CV] gamma=0.1, kernel=linear, max_iter=1000 .........................
# [CV]  gamma=0.01, kernel=rbf, max_iter=1000, score=0.603, total=  13.8s
# [CV] gamma=0.1, kernel=linear, max_iter=1000 .........................
# [CV]  gamma=0.01, kernel=rbf, max_iter=1000, score=0.630, total=  12.3s
# [CV] gamma=0.1, kernel=linear, max_iter=1000 .........................
# C:\Users\joshu\Anaconda3\envs\CS7641\lib\site-packages\sklearn\svm\_base.py:231: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\joshu\Anaconda3\envs\CS7641\lib\site-packages\sklearn\svm\_base.py:231: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# [CV]  gamma=0.01, kernel=sigmoid, max_iter=1000, score=0.575, total=   3.4s
# [CV] gamma=0.1, kernel=linear, max_iter=1000 .........................
# [CV]  gamma=0.1, kernel=linear, max_iter=1000, score=0.885, total=   3.2s
# [CV] gamma=0.1, kernel=poly, max_iter=1000 ...........................
# [CV]  gamma=0.1, kernel=linear, max_iter=1000, score=0.853, total=   3.2s
# [CV] gamma=0.1, kernel=poly, max_iter=1000 ...........................
# [CV]  gamma=0.01, kernel=sigmoid, max_iter=1000, score=0.695, total=   3.8s
# [CV] gamma=0.1, kernel=poly, max_iter=1000 ...........................
# C:\Users\joshu\Anaconda3\envs\CS7641\lib\site-packages\sklearn\svm\_base.py:231: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# [CV]  gamma=0.1, kernel=linear, max_iter=1000, score=0.833, total=   2.9s
# [CV] gamma=0.1, kernel=poly, max_iter=1000 ...........................
# [CV]  gamma=0.1, kernel=linear, max_iter=1000, score=0.882, total=   3.0s
# [CV] gamma=0.1, kernel=poly, max_iter=1000 ...........................
# [CV]  gamma=0.1, kernel=linear, max_iter=1000, score=0.925, total=   3.2s
# [CV] gamma=0.1, kernel=rbf, max_iter=1000 ............................
# [CV]  gamma=0.01, kernel=rbf, max_iter=1000, score=0.632, total=  12.3s
# [CV] gamma=0.1, kernel=rbf, max_iter=1000 ............................
# [CV]  gamma=0.01, kernel=rbf, max_iter=1000, score=0.700, total=  12.4s
# [CV] gamma=0.1, kernel=rbf, max_iter=1000 ............................
# [CV]  gamma=0.1, kernel=poly, max_iter=1000, score=0.863, total=   8.7s
# [CV] gamma=0.1, kernel=rbf, max_iter=1000 ............................
# [CV]  gamma=0.1, kernel=poly, max_iter=1000, score=0.855, total=   8.8s
# [CV] gamma=0.1, kernel=rbf, max_iter=1000 ............................
# [CV]  gamma=0.1, kernel=poly, max_iter=1000, score=0.902, total=   9.0s
# [CV] gamma=0.1, kernel=sigmoid, max_iter=1000 ........................
# [CV]  gamma=0.1, kernel=poly, max_iter=1000, score=0.905, total=   9.0s
# [CV] gamma=0.1, kernel=sigmoid, max_iter=1000 ........................
# [CV]  gamma=0.1, kernel=poly, max_iter=1000, score=0.905, total=   9.1s
# [CV] gamma=0.1, kernel=sigmoid, max_iter=1000 ........................
# [CV]  gamma=0.1, kernel=sigmoid, max_iter=1000, score=0.323, total=   5.3s
# [CV] gamma=0.1, kernel=sigmoid, max_iter=1000 ........................
# [CV]  gamma=0.1, kernel=sigmoid, max_iter=1000, score=0.297, total=   5.4s
# [CV] gamma=0.1, kernel=sigmoid, max_iter=1000 ........................
# [CV]  gamma=0.1, kernel=sigmoid, max_iter=1000, score=0.242, total=   5.1s
# [CV]  gamma=0.1, kernel=rbf, max_iter=1000, score=0.138, total=  13.0s
# [CV]  gamma=0.1, kernel=rbf, max_iter=1000, score=0.145, total=  12.6s
# [CV]  gamma=0.1, kernel=rbf, max_iter=1000, score=0.155, total=  12.6s
# [CV]  gamma=0.1, kernel=sigmoid, max_iter=1000, score=0.325, total=   3.5s
# [CV]  gamma=0.1, kernel=sigmoid, max_iter=1000, score=0.360, total=   3.3s
# [CV]  gamma=0.1, kernel=rbf, max_iter=1000, score=0.140, total=   9.9s
# [CV]  gamma=0.1, kernel=rbf, max_iter=1000, score=0.158, total=   9.8s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:  1.3min finished

# %%
with parallel_backend('threading'):
    svm_learning_curve_results["train_sizes"], svm_learning_curve_results["train_scores"], svm_learning_curve_results["test_scores"], svm_learning_curve_results["fit_times"], _ = learning_curve(svm_grid_search.best_estimator_, X, y, cv=cross_validation, verbose=3, n_jobs=n_jobs, train_sizes=train_sizes, return_times=True)
# Out:
# [learning_curve] Training set sizes: [ 160  189  218  248  277  306  336  365  395  424  453  483  512  542
#   571  600  630  659  688  718  747  777  806  835  865  894  924  953
#   982 1012 1041 1071 1100 1129 1159 1188 1217 1247 1276 1306 1335 1364
#  1394 1423 1453 1482 1511 1541 1570 1600]
# [CV]  ................................................................
# [CV]  ................................................................
# [CV]  ................................................................
# [CV]  ................................................................
# [CV]  ................................................................
# [CV]  ................................................................
# [CV]  ................................................................[CV]  ................................................................
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [CV] ................ , score=(train=0.944, test=0.703), total=   0.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.947, test=0.757), total=   0.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.950, test=0.787), total=   0.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.952, test=0.818), total=   0.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.957, test=0.818), total=   0.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.961, test=0.810), total=   0.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.970, test=0.820), total=   0.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.973, test=0.818), total=   0.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.972, test=0.833), total=   0.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.973, test=0.855), total=   0.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.972, test=0.840), total=   0.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.974, test=0.848), total=   0.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.967, test=0.850), total=   0.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.973, test=0.865), total=   0.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.970, test=0.858), total=   0.9s[CV] ................ , score=(train=0.978, test=0.868), total=   0.8s
# [CV]  ................................................................
#
# [CV]  ................................................................
# [CV] ................ , score=(train=0.968, test=0.858), total=   1.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.980, test=0.868), total=   0.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.976, test=0.875), total=   1.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.975, test=0.873), total=   1.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.978, test=0.873), total=   1.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.977, test=0.882), total=   1.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.976, test=0.880), total=   1.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.976, test=0.875), total=   1.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.976, test=0.875), total=   1.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.975, test=0.877), total=   1.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.974, test=0.877), total=   1.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.971, test=0.880), total=   2.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.970, test=0.873), total=   2.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.968, test=0.875), total=   2.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.970, test=0.877), total=   2.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.970, test=0.880), total=   2.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.972, test=0.880), total=   2.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.971, test=0.887), total=   2.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.970, test=0.880), total=   3.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.969, test=0.880), total=   3.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.968, test=0.882), total=   3.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.970, test=0.880), total=   3.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.970, test=0.880), total=   3.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.970, test=0.880), total=   4.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.970, test=0.880), total=   4.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.971, test=0.887), total=   4.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.971, test=0.892), total=   4.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.944, test=0.620), total=   0.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.952, test=0.645), total=   0.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.945, test=0.660), total=   0.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.973, test=0.892), total=   4.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.948, test=0.700), total=   0.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.946, test=0.708), total=   0.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.952, test=0.735), total=   0.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.948, test=0.715), total=   0.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.947, test=0.755), total=   0.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.973, test=0.890), total=   4.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.956, test=0.748), total=   0.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.973, test=0.900), total=   4.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.958, test=0.762), total=   0.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.972, test=0.900), total=   5.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.957, test=0.767), total=   0.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.956, test=0.775), total=   0.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.957, test=0.770), total=   0.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.959, test=0.777), total=   0.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.960, test=0.787), total=   0.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.962, test=0.802), total=   0.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.973, test=0.895), total=   4.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.959, test=0.807), total=   1.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.958, test=0.810), total=   1.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.956, test=0.818), total=   1.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.960, test=0.818), total=   1.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.973, test=0.895), total=   4.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.957, test=0.820), total=   1.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.974, test=0.895), total=   5.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.958, test=0.823), total=   1.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.958, test=0.820), total=   1.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.957, test=0.828), total=   1.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.958, test=0.830), total=   1.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.956, test=0.835), total=   1.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.957, test=0.840), total=   1.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.959, test=0.835), total=   2.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.958, test=0.838), total=   2.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.958, test=0.838), total=   2.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.959, test=0.845), total=   2.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.964, test=0.838), total=   2.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.963, test=0.848), total=   3.2s
# [CV]  ................................................................
# [Parallel(n_jobs=-1)]: Done  83 out of 250 | elapsed:   34.6s remaining:  1.2min
# [CV] ................ , score=(train=0.963, test=0.843), total=   3.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.961, test=0.850), total=   3.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.963, test=0.845), total=   3.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.964, test=0.848), total=   3.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.966, test=0.850), total=   3.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.966, test=0.850), total=   4.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.966, test=0.850), total=   4.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.968, test=0.863), total=   4.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.969, test=0.865), total=   4.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.968, test=0.860), total=   4.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.944, test=0.627), total=   0.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.970, test=0.858), total=   4.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.952, test=0.640), total=   0.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.945, test=0.652), total=   0.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.948, test=0.695), total=   0.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.946, test=0.708), total=   0.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.948, test=0.718), total=   0.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.969, test=0.865), total=   4.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.952, test=0.757), total=   0.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.956, test=0.750), total=   0.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.959, test=0.752), total=   0.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.948, test=0.760), total=   0.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.949, test=0.755), total=   0.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.954, test=0.775), total=   0.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.971, test=0.858), total=   5.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.955, test=0.782), total=   0.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.959, test=0.785), total=   0.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.972, test=0.860), total=   5.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.958, test=0.782), total=   0.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.962, test=0.790), total=   0.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.956, test=0.795), total=   1.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.972, test=0.868), total=   5.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.959, test=0.810), total=   0.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.971, test=0.860), total=   5.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.961, test=0.812), total=   1.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.964, test=0.823), total=   1.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.961, test=0.825), total=   1.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.963, test=0.830), total=   1.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.963, test=0.828), total=   1.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.965, test=0.830), total=   1.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.971, test=0.863), total=   5.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.963, test=0.835), total=   1.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.966, test=0.833), total=   1.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.964, test=0.838), total=   1.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.964, test=0.838), total=   2.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.965, test=0.840), total=   1.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.965, test=0.848), total=   2.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.963, test=0.845), total=   2.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.968, test=0.843), total=   2.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.968, test=0.843), total=   2.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.970, test=0.850), total=   2.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.969, test=0.848), total=   3.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.970, test=0.855), total=   2.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.970, test=0.848), total=   3.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.970, test=0.855), total=   3.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.971, test=0.853), total=   3.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.972, test=0.853), total=   4.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.973, test=0.853), total=   3.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.973, test=0.855), total=   4.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.974, test=0.858), total=   4.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.944, test=0.650), total=   0.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.952, test=0.685), total=   0.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.945, test=0.705), total=   0.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.948, test=0.740), total=   0.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.974, test=0.853), total=   4.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.946, test=0.743), total=   0.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.948, test=0.755), total=   0.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.952, test=0.770), total=   0.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.956, test=0.767), total=   0.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.975, test=0.853), total=   5.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.959, test=0.777), total=   0.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.973, test=0.855), total=   5.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.948, test=0.777), total=   0.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.949, test=0.780), total=   0.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.954, test=0.792), total=   0.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.955, test=0.795), total=   0.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.959, test=0.807), total=   0.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.972, test=0.858), total=   5.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.958, test=0.818), total=   0.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.962, test=0.820), total=   1.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.956, test=0.820), total=   0.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.975, test=0.858), total=   5.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.959, test=0.828), total=   0.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.972, test=0.860), total=   5.5s
# [CV]  ................................................................
# [Parallel(n_jobs=-1)]: Done 167 out of 250 | elapsed:  1.2min remaining:   36.7s
# [CV] ................ , score=(train=0.961, test=0.830), total=   1.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.976, test=0.863), total=   4.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.964, test=0.838), total=   1.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.964, test=0.838), total=   1.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.965, test=0.840), total=   1.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.965, test=0.843), total=   1.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.969, test=0.840), total=   1.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.964, test=0.840), total=   1.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.962, test=0.848), total=   1.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.964, test=0.835), total=   1.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.964, test=0.848), total=   2.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.964, test=0.848), total=   2.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.965, test=0.850), total=   2.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.964, test=0.855), total=   2.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.965, test=0.860), total=   2.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.965, test=0.860), total=   3.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.964, test=0.868), total=   2.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.964, test=0.875), total=   3.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.965, test=0.877), total=   3.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.967, test=0.880), total=   3.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.966, test=0.882), total=   3.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.966, test=0.877), total=   3.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.966, test=0.885), total=   3.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.966, test=0.890), total=   4.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.965, test=0.887), total=   4.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.966, test=0.887), total=   4.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.944, test=0.705), total=   0.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.952, test=0.725), total=   0.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.945, test=0.715), total=   0.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.969, test=0.892), total=   4.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.948, test=0.765), total=   0.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.946, test=0.785), total=   0.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.967, test=0.890), total=   4.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.948, test=0.807), total=   0.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.952, test=0.838), total=   0.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.966, test=0.897), total=   4.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.956, test=0.835), total=   0.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.948, test=0.843), total=   0.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.959, test=0.835), total=   0.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.949, test=0.858), total=   0.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.966, test=0.900), total=   4.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.954, test=0.870), total=   0.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.967, test=0.902), total=   5.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.955, test=0.875), total=   0.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.959, test=0.890), total=   0.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.958, test=0.877), total=   0.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.962, test=0.877), total=   0.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.956, test=0.885), total=   1.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.961, test=0.890), total=   1.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.967, test=0.902), total=   4.8s[CV] ................ , score=(train=0.959, test=0.900), total=   1.1s
#
# [CV]  ................................................................[CV]  ................................................................
#
# [CV] ................ , score=(train=0.964, test=0.887), total=   1.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.964, test=0.890), total=   1.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.965, test=0.887), total=   1.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.968, test=0.895), total=   5.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.965, test=0.897), total=   1.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.969, test=0.900), total=   1.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.964, test=0.902), total=   1.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.964, test=0.900), total=   2.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.962, test=0.905), total=   1.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.965, test=0.907), total=   1.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.964, test=0.907), total=   2.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.964, test=0.907), total=   2.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.965, test=0.905), total=   2.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.964, test=0.905), total=   2.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.965, test=0.907), total=   2.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.964, test=0.910), total=   3.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.964, test=0.915), total=   3.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.965, test=0.915), total=   3.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.965, test=0.922), total=   3.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.965, test=0.920), total=   4.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.967, test=0.922), total=   4.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.969, test=0.920), total=   4.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.969, test=0.917), total=   4.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.968, test=0.922), total=   4.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.967, test=0.922), total=   4.8s
# [CV] ................ , score=(train=0.966, test=0.925), total=   4.7s
# [CV] ................ , score=(train=0.968, test=0.930), total=   5.5s
# [CV] ................ , score=(train=0.969, test=0.930), total=   5.3s
# [CV] ................ , score=(train=0.970, test=0.927), total=   5.1s
# [CV] ................ , score=(train=0.968, test=0.932), total=   5.2s
# [CV] ................ , score=(train=0.968, test=0.930), total=   5.2s
# [CV] ................ , score=(train=0.970, test=0.927), total=   4.4s
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:  2.0min finished

# %%
with parallel_backend('threading'):    
    svm_validation_curve_results["train_scores"], svm_validation_curve_results["test_scores"] = validation_curve(svm_grid_search.best_estimator_, X=Validation_X, y=validation_y, n_jobs=n_jobs, cv=cross_validation, verbose=3, param_name=svm_param_name, param_range=np.linspace(0.1, 2.5, num=50))

plt.close("all")
# Out:
# [CV] C=0.1 ...........................................................[CV] C=0.1489795918367347 ............................................
#
# [CV] C=0.19795918367346937 ...........................................
# [CV] C=0.24693877551020407 ...........................................
# [CV] C=0.29591836734693877 ...........................................
# [CV] C=0.3448979591836735 ............................................
# [CV] C=0.3938775510204081 ............................................
# [CV] C=0.44285714285714284 ...........................................
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [CV]  C=0.44285714285714284, score=(train=0.884, test=0.800), total=   0.1s
# [CV] C=0.49183673469387756 ...........................................
# [CV]  C=0.3938775510204081, score=(train=0.878, test=0.812), total=   0.2s
# [CV] C=0.5408163265306122 ............................................
# [CV] ........... C=0.1, score=(train=0.375, test=0.250), total=   0.2s
# [CV] C=0.5897959183673469 ............................................
# [CV]  C=0.3448979591836735, score=(train=0.856, test=0.812), total=   0.2s
# [CV] C=0.6387755102040816 ............................................
# [CV]  C=0.19795918367346937, score=(train=0.750, test=0.637), total=   0.3s
# [CV] C=0.6877551020408162 ............................................
# [CV]  C=0.1489795918367347, score=(train=0.672, test=0.450), total=   0.3s
# [CV] C=0.736734693877551 .............................................
# [CV]  C=0.29591836734693877, score=(train=0.828, test=0.775), total=   0.3s
# [CV] C=0.7857142857142857 ............................................
# [CV]  C=0.24693877551020407, score=(train=0.787, test=0.700), total=   0.3s
# [CV] C=0.8346938775510203 ............................................
# [CV]  C=0.5897959183673469, score=(train=0.922, test=0.812), total=   0.1s
# [CV] C=0.883673469387755 .............................................
# [CV]  C=0.49183673469387756, score=(train=0.903, test=0.812), total=   0.2s
# [CV] C=0.9326530612244898 ............................................
# [CV]  C=0.6387755102040816, score=(train=0.925, test=0.825), total=   0.2s
# [CV] C=0.9816326530612244 ............................................
# [CV]  C=0.5408163265306122, score=(train=0.919, test=0.812), total=   0.2s
# [CV] C=1.030612244897959 .............................................
# [CV]  C=0.736734693877551, score=(train=0.934, test=0.838), total=   0.2s
# [CV] C=1.079591836734694 .............................................
# [CV]  C=0.6877551020408162, score=(train=0.931, test=0.838), total=   0.2s
# [CV] C=1.1285714285714286 ............................................
# [CV]  C=0.8346938775510203, score=(train=0.934, test=0.838), total=   0.2s
# [CV] C=1.1775510204081634 ............................................
# [CV]  C=0.7857142857142857, score=(train=0.934, test=0.838), total=   0.2s
# [CV] C=1.226530612244898 .............................................
# [CV]  C=0.883673469387755, score=(train=0.941, test=0.838), total=   0.2s
# [CV] C=1.2755102040816326 ............................................
# [CV]  C=0.9816326530612244, score=(train=0.950, test=0.850), total=   0.1s
# [CV] C=1.3244897959183675 ............................................
# [CV]  C=0.9326530612244898, score=(train=0.947, test=0.850), total=   0.2s
# [CV] C=1.373469387755102 .............................................
# [CV]  C=1.030612244897959, score=(train=0.950, test=0.850), total=   0.2s
# [CV] C=1.4224489795918367 ............................................
# [CV]  C=1.079591836734694, score=(train=0.953, test=0.838), total=   0.2s
# [CV] C=1.4714285714285715 ............................................
# [CV]  C=1.226530612244898, score=(train=0.959, test=0.838), total=   0.2s
# [CV] C=1.5204081632653061 ............................................
# [CV]  C=1.1285714285714286, score=(train=0.956, test=0.838), total=   0.2s
# [CV] C=1.5693877551020408 ............................................
# [CV]  C=1.1775510204081634, score=(train=0.959, test=0.838), total=   0.2s
# [CV] C=1.6183673469387756 ............................................
# [CV]  C=1.3244897959183675, score=(train=0.969, test=0.838), total=   0.1s
# [CV] C=1.6673469387755102 ............................................
# [CV]  C=1.2755102040816326, score=(train=0.959, test=0.838), total=   0.1s
# [CV] C=1.7163265306122448 ............................................
# [CV]  C=1.373469387755102, score=(train=0.972, test=0.838), total=   0.2s
# [CV] C=1.7653061224489797 ............................................
# [CV]  C=1.5204081632653061, score=(train=0.981, test=0.838), total=   0.1s
# [CV] C=1.8142857142857143 ............................................
# [CV]  C=1.4224489795918367, score=(train=0.978, test=0.838), total=   0.2s
# [CV] C=1.863265306122449 .............................................
# [CV]  C=1.4714285714285715, score=(train=0.981, test=0.838), total=   0.2s
# [CV] C=1.9122448979591837 ............................................
# [CV]  C=1.5693877551020408, score=(train=0.981, test=0.838), total=   0.2s
# [CV] C=1.9612244897959183 ............................................
# [CV]  C=1.6183673469387756, score=(train=0.984, test=0.838), total=   0.2s
# [CV] C=2.010204081632653 .............................................
# [CV]  C=1.6673469387755102, score=(train=0.984, test=0.838), total=   0.2s
# [CV] C=2.059183673469388 .............................................
# [CV]  C=1.7163265306122448, score=(train=0.984, test=0.838), total=   0.2s
# [CV] C=2.1081632653061226 ............................................
# [CV]  C=1.8142857142857143, score=(train=0.984, test=0.838), total=   0.2s
# [CV] C=2.157142857142857 .............................................
# [CV]  C=1.9122448979591837, score=(train=0.984, test=0.838), total=   0.2s
# [CV] C=2.206122448979592 .............................................
# [CV]  C=1.7653061224489797, score=(train=0.984, test=0.838), total=   0.2s
# [CV] C=2.2551020408163267 ............................................
# [CV]  C=1.863265306122449, score=(train=0.984, test=0.838), total=   0.2s
# [CV] C=2.304081632653061 .............................................
# [CV]  C=2.010204081632653, score=(train=0.984, test=0.838), total=   0.2s
# [CV] C=2.353061224489796 .............................................
# [CV]  C=1.9612244897959183, score=(train=0.984, test=0.838), total=   0.2s
# [CV] C=2.4020408163265308 ............................................
# [CV]  C=2.059183673469388, score=(train=0.984, test=0.838), total=   0.1s
# [CV] C=2.451020408163265 .............................................
# [CV]  C=2.1081632653061226, score=(train=0.988, test=0.838), total=   0.2s
# [CV] C=2.5 ...........................................................
# [CV]  C=2.157142857142857, score=(train=0.988, test=0.838), total=   0.2s
# [CV] C=0.1 ...........................................................
# [CV]  C=2.304081632653061, score=(train=0.991, test=0.838), total=   0.2s
# [CV] C=0.1489795918367347 ............................................
# [CV]  C=2.2551020408163267, score=(train=0.991, test=0.838), total=   0.2s
# [CV] C=0.19795918367346937 ...........................................
# [CV]  C=2.451020408163265, score=(train=0.991, test=0.838), total=   0.1s
# [CV] C=0.24693877551020407 ...........................................
# [CV]  C=2.206122448979592, score=(train=0.988, test=0.838), total=   0.2s
# [CV] C=0.29591836734693877 ...........................................
# [CV]  C=2.353061224489796, score=(train=0.991, test=0.838), total=   0.2s
# [CV] C=0.3448979591836735 ............................................
# [CV] ........... C=2.5, score=(train=0.991, test=0.838), total=   0.2s
# [CV] C=0.3938775510204081 ............................................
# [CV]  C=2.4020408163265308, score=(train=0.991, test=0.838), total=   0.2s
# [CV] C=0.44285714285714284 ...........................................
# [CV] ........... C=0.1, score=(train=0.284, test=0.163), total=   0.2s
# [CV] C=0.49183673469387756 ...........................................
# [CV]  C=0.1489795918367347, score=(train=0.584, test=0.537), total=   0.2s
# [CV] C=0.5408163265306122 ............................................
# [CV]  C=0.24693877551020407, score=(train=0.759, test=0.688), total=   0.2s[CV]  C=0.29591836734693877, score=(train=0.809, test=0.713), total=   0.2s
#
# [CV] C=0.5897959183673469 ............................................[CV] C=0.6387755102040816 ............................................
#
# [CV]  C=0.19795918367346937, score=(train=0.703, test=0.662), total=   0.2s
# [CV] C=0.6877551020408162 ............................................
# [CV]  C=0.3938775510204081, score=(train=0.887, test=0.762), total=   0.2s
# [CV] C=0.736734693877551 .............................................
# [CV]  C=0.44285714285714284, score=(train=0.903, test=0.762), total=   0.2s
# [CV] C=0.7857142857142857 ............................................
# [CV]  C=0.3448979591836735, score=(train=0.841, test=0.762), total=   0.2s
# [CV] C=0.8346938775510203 ............................................
# [CV]  C=0.49183673469387756, score=(train=0.912, test=0.775), total=   0.2s
# [CV] C=0.883673469387755 .............................................
# [CV]  C=0.5408163265306122, score=(train=0.919, test=0.825), total=   0.2s
# [CV] C=0.9326530612244898 ............................................
# [CV]  C=0.5897959183673469, score=(train=0.925, test=0.825), total=   0.2s
# [CV] C=0.9816326530612244 ............................................
# [CV]  C=0.6387755102040816, score=(train=0.928, test=0.838), total=   0.2s
# [CV] C=1.030612244897959 .............................................
# [CV]  C=0.7857142857142857, score=(train=0.947, test=0.850), total=   0.1s
# [CV] C=1.079591836734694 .............................................
# [CV]  C=0.883673469387755, score=(train=0.956, test=0.875), total=   0.2s
# [CV] C=1.1285714285714286 ............................................
# [CV]  C=0.6877551020408162, score=(train=0.938, test=0.850), total=   0.2s
# [CV] C=1.1775510204081634 ............................................
# [CV]  C=0.736734693877551, score=(train=0.944, test=0.850), total=   0.2s
# [CV] C=1.226530612244898 .............................................
# [CV]  C=0.8346938775510203, score=(train=0.956, test=0.850), total=   0.2s
# [CV] C=1.2755102040816326 ............................................
# [CV]  C=0.9326530612244898, score=(train=0.959, test=0.887), total=   0.2s
# [CV] C=1.3244897959183675 ............................................
# [CV]  C=1.030612244897959, score=(train=0.959, test=0.887), total=   0.1s
# [CV] C=1.373469387755102 .............................................
# [CV]  C=0.9816326530612244, score=(train=0.959, test=0.887), total=   0.2s
# [CV] C=1.4224489795918367 ............................................
# [CV]  C=1.1285714285714286, score=(train=0.966, test=0.887), total=   0.1s
# [CV] C=1.4714285714285715 ............................................
# [CV]  C=1.079591836734694, score=(train=0.959, test=0.887), total=   0.2s
# [CV] C=1.5204081632653061 ............................................
# [CV]  C=1.226530612244898, score=(train=0.972, test=0.887), total=   0.2s
# [CV] C=1.5693877551020408 ............................................
# [CV]  C=1.1775510204081634, score=(train=0.969, test=0.887), total=   0.2s
# [CV] C=1.6183673469387756 ............................................
# [CV]  C=1.2755102040816326, score=(train=0.972, test=0.887), total=   0.2s
# [CV] C=1.6673469387755102 ............................................
# [CV]  C=1.3244897959183675, score=(train=0.972, test=0.887), total=   0.2s
# [CV] C=1.7163265306122448 ............................................
# [CV]  C=1.4224489795918367, score=(train=0.978, test=0.887), total=   0.2s
# [CV] C=1.7653061224489797 ............................................
# [CV]  C=1.373469387755102, score=(train=0.978, test=0.887), total=   0.2s
# [CV] C=1.8142857142857143 ............................................
# [CV]  C=1.4714285714285715, score=(train=0.981, test=0.875), total=   0.2s
# [CV] C=1.863265306122449 .............................................
# [CV]  C=1.5693877551020408, score=(train=0.984, test=0.875), total=   0.2s
# [CV] C=1.9122448979591837 ............................................
# [CV]  C=1.5204081632653061, score=(train=0.984, test=0.875), total=   0.2s
# [CV] C=1.9612244897959183 ............................................
# [CV]  C=1.6183673469387756, score=(train=0.984, test=0.875), total=   0.2s
# [CV] C=2.010204081632653 .............................................
# [CV]  C=1.6673469387755102, score=(train=0.984, test=0.875), total=   0.2s
# [CV] C=2.059183673469388 .............................................
# [CV]  C=1.7653061224489797, score=(train=0.991, test=0.875), total=   0.2s
# [CV] C=2.1081632653061226 ............................................
# [CV]  C=1.7163265306122448, score=(train=0.988, test=0.875), total=   0.2s
# [CV] C=2.157142857142857 .............................................
# [CV]  C=1.8142857142857143, score=(train=0.991, test=0.875), total=   0.2s
# [CV] C=2.206122448979592 .............................................
# [Parallel(n_jobs=-1)]: Done  83 out of 250 | elapsed:    3.5s remaining:    7.1s
# [CV]  C=1.863265306122449, score=(train=0.991, test=0.875), total=   0.2s
# [CV] C=2.2551020408163267 ............................................
# [CV]  C=1.9122448979591837, score=(train=0.994, test=0.875), total=   0.2s
# [CV] C=2.304081632653061 .............................................
# [CV]  C=2.1081632653061226, score=(train=0.994, test=0.863), total=   0.2s
# [CV] C=2.353061224489796 .............................................
# [CV]  C=1.9612244897959183, score=(train=0.994, test=0.875), total=   0.2s
# [CV] C=2.4020408163265308 ............................................
# [CV]  C=2.010204081632653, score=(train=0.994, test=0.875), total=   0.2s
# [CV] C=2.451020408163265 .............................................
# [CV]  C=2.059183673469388, score=(train=0.994, test=0.863), total=   0.2s
# [CV] C=2.5 ...........................................................[CV]  C=2.206122448979592, score=(train=0.997, test=0.875), total=   0.2s
# [CV] C=0.1 ...........................................................
#
# [CV]  C=2.157142857142857, score=(train=0.994, test=0.863), total=   0.2s
# [CV] C=0.1489795918367347 ............................................
# [CV]  C=2.2551020408163267, score=(train=0.997, test=0.875), total=   0.2s
# [CV] C=0.19795918367346937 ...........................................
# [CV]  C=2.304081632653061, score=(train=0.997, test=0.875), total=   0.2s
# [CV] C=0.24693877551020407 ...........................................
# [CV]  C=2.353061224489796, score=(train=0.997, test=0.875), total=   0.2s
# [CV] C=0.29591836734693877 ...........................................
# [CV]  C=2.4020408163265308, score=(train=0.997, test=0.875), total=   0.2s
# [CV] C=0.3448979591836735 ............................................
# [CV] ........... C=2.5, score=(train=0.997, test=0.875), total=   0.2s
# [CV] C=0.3938775510204081 ............................................
# [CV]  C=2.451020408163265, score=(train=0.997, test=0.875), total=   0.2s
# [CV] C=0.44285714285714284 ...........................................
# [CV] ........... C=0.1, score=(train=0.259, test=0.237), total=   0.3s
# [CV] C=0.49183673469387756 ...........................................
# [CV]  C=0.1489795918367347, score=(train=0.544, test=0.550), total=   0.2s
# [CV] C=0.5408163265306122 ............................................
# [CV]  C=0.24693877551020407, score=(train=0.772, test=0.713), total=   0.2s
# [CV] C=0.5897959183673469 ............................................
# [CV]  C=0.19795918367346937, score=(train=0.684, test=0.662), total=   0.2s
# [CV] C=0.6387755102040816 ............................................
# [CV]  C=0.29591836734693877, score=(train=0.797, test=0.775), total=   0.2s
# [CV] C=0.6877551020408162 ............................................
# [CV]  C=0.3938775510204081, score=(train=0.863, test=0.812), total=   0.2s
# [CV] C=0.736734693877551 .............................................
# [CV]  C=0.3448979591836735, score=(train=0.822, test=0.812), total=   0.2s
# [CV] C=0.7857142857142857 ............................................
# [CV]  C=0.44285714285714284, score=(train=0.881, test=0.825), total=   0.2s
# [CV] C=0.8346938775510203 ............................................
# [CV]  C=0.5408163265306122, score=(train=0.912, test=0.825), total=   0.2s
# [CV] C=0.883673469387755 .............................................
# [CV]  C=0.49183673469387756, score=(train=0.900, test=0.825), total=   0.2s
# [CV] C=0.9326530612244898 ............................................
# [CV]  C=0.6387755102040816, score=(train=0.919, test=0.838), total=   0.2s
# [CV] C=0.9816326530612244 ............................................
# [CV]  C=0.5897959183673469, score=(train=0.912, test=0.838), total=   0.2s
# [CV] C=1.030612244897959 .............................................
# [CV]  C=0.6877551020408162, score=(train=0.934, test=0.825), total=   0.2s
# [CV] C=1.079591836734694 .............................................
# [CV]  C=0.8346938775510203, score=(train=0.950, test=0.825), total=   0.2s
# [CV] C=1.1285714285714286 ............................................
# [CV]  C=0.736734693877551, score=(train=0.941, test=0.825), total=   0.2s
# [CV] C=1.1775510204081634 ............................................
# [CV]  C=0.7857142857142857, score=(train=0.941, test=0.825), total=   0.2s
# [CV] C=1.226530612244898 .............................................
# [CV]  C=0.883673469387755, score=(train=0.956, test=0.825), total=   0.2s
# [CV] C=1.2755102040816326 ............................................
# [CV]  C=0.9326530612244898, score=(train=0.956, test=0.850), total=   0.2s
# [CV] C=1.3244897959183675 ............................................
# [CV]  C=1.030612244897959, score=(train=0.963, test=0.850), total=   0.2s
# [CV] C=1.373469387755102 .............................................
# [CV]  C=0.9816326530612244, score=(train=0.963, test=0.850), total=   0.2s
# [CV] C=1.4224489795918367 ............................................
# [CV]  C=1.079591836734694, score=(train=0.963, test=0.850), total=   0.2s
# [CV] C=1.4714285714285715 ............................................
# [CV]  C=1.1775510204081634, score=(train=0.969, test=0.863), total=   0.2s
# [CV] C=1.5204081632653061 ............................................
# [CV]  C=1.3244897959183675, score=(train=0.969, test=0.863), total=   0.2s
# [CV]  C=1.1285714285714286, score=(train=0.969, test=0.850), total=   0.2s[CV] C=1.5693877551020408 ............................................
#
# [CV] C=1.6183673469387756 ............................................
# [CV]  C=1.226530612244898, score=(train=0.969, test=0.863), total=   0.2s
# [CV] C=1.6673469387755102 ............................................
# [CV]  C=1.4224489795918367, score=(train=0.972, test=0.863), total=   0.2s
# [CV] C=1.7163265306122448 ............................................
# [CV]  C=1.373469387755102, score=(train=0.969, test=0.863), total=   0.2s
# [CV] C=1.7653061224489797 ............................................
# [CV]  C=1.2755102040816326, score=(train=0.969, test=0.863), total=   0.2s
# [CV] C=1.8142857142857143 ............................................
# [CV]  C=1.4714285714285715, score=(train=0.972, test=0.863), total=   0.2s
# [CV] C=1.863265306122449 .............................................
# [CV]  C=1.5693877551020408, score=(train=0.978, test=0.863), total=   0.2s
# [CV] C=1.9122448979591837 ............................................
# [CV]  C=1.5204081632653061, score=(train=0.975, test=0.863), total=   0.2s
# [CV] C=1.9612244897959183 ............................................
# [CV]  C=1.6673469387755102, score=(train=0.978, test=0.863), total=   0.2s
# [CV] C=2.010204081632653 .............................................
# [CV]  C=1.6183673469387756, score=(train=0.978, test=0.863), total=   0.2s
# [CV] C=2.059183673469388 .............................................
# [CV]  C=1.7653061224489797, score=(train=0.984, test=0.863), total=   0.2s
# [CV] C=2.1081632653061226 ............................................
# [CV]  C=1.7163265306122448, score=(train=0.984, test=0.863), total=   0.2s
# [CV] C=2.157142857142857 .............................................
# [CV]  C=1.8142857142857143, score=(train=0.984, test=0.863), total=   0.2s
# [CV] C=2.206122448979592 .............................................
# [CV]  C=1.863265306122449, score=(train=0.988, test=0.863), total=   0.2s
# [CV] C=2.2551020408163267 ............................................
# [CV]  C=1.9122448979591837, score=(train=0.988, test=0.863), total=   0.2s
# [CV] C=2.304081632653061 .............................................
# [CV]  C=1.9612244897959183, score=(train=0.991, test=0.863), total=   0.2s
# [CV] C=2.353061224489796 .............................................
# [CV]  C=2.157142857142857, score=(train=0.991, test=0.875), total=   0.2s
# [CV] C=2.4020408163265308 ............................................
# [CV]  C=2.1081632653061226, score=(train=0.991, test=0.875), total=   0.2s
# [CV] C=2.451020408163265 .............................................
# [CV]  C=2.010204081632653, score=(train=0.991, test=0.875), total=   0.2s
# [CV] C=2.5 ...........................................................[CV]  C=2.059183673469388, score=(train=0.991, test=0.875), total=   0.2s
#
# [CV] C=0.1 ...........................................................
# [CV]  C=2.2551020408163267, score=(train=0.991, test=0.875), total=   0.2s
# [CV] C=0.1489795918367347 ............................................
# [CV]  C=2.206122448979592, score=(train=0.991, test=0.875), total=   0.2s
# [CV] C=0.19795918367346937 ...........................................
# [CV]  C=2.304081632653061, score=(train=0.991, test=0.875), total=   0.2s
# [CV] C=0.24693877551020407 ...........................................
# [CV]  C=2.353061224489796, score=(train=0.991, test=0.875), total=   0.2s
# [CV] C=0.29591836734693877 ...........................................
# [CV]  C=2.4020408163265308, score=(train=0.991, test=0.875), total=   0.2s
# [CV] C=0.3448979591836735 ............................................
# [CV]  C=2.451020408163265, score=(train=0.991, test=0.875), total=   0.2s
# [CV] C=0.3938775510204081 ............................................
# [CV] ........... C=2.5, score=(train=0.991, test=0.875), total=   0.2s
# [CV] C=0.44285714285714284 ...........................................
# [CV]  C=0.1489795918367347, score=(train=0.497, test=0.350), total=   0.2s
# [CV] C=0.49183673469387756 ...........................................
# [CV] ........... C=0.1, score=(train=0.247, test=0.188), total=   0.2s
# [CV] C=0.5408163265306122 ............................................
# [CV]  C=0.19795918367346937, score=(train=0.675, test=0.500), total=   0.2s
# [CV] C=0.5897959183673469 ............................................
# [CV]  C=0.24693877551020407, score=(train=0.784, test=0.600), total=   0.2s
# [CV] C=0.6387755102040816 ............................................
# [CV]  C=0.29591836734693877, score=(train=0.831, test=0.662), total=   0.2s
# [CV] C=0.6877551020408162 ............................................
# [CV]  C=0.3938775510204081, score=(train=0.887, test=0.725), total=   0.2s
# [CV] C=0.736734693877551 .............................................
# [CV]  C=0.3448979591836735, score=(train=0.866, test=0.688), total=   0.2s
# [CV] C=0.7857142857142857 ............................................
# [CV]  C=0.49183673469387756, score=(train=0.909, test=0.762), total=   0.2s[CV]  C=0.44285714285714284, score=(train=0.903, test=0.738), total=   0.2s
# [CV] C=0.8346938775510203 ............................................
#
# [CV] C=0.883673469387755 .............................................
# [CV]  C=0.5408163265306122, score=(train=0.922, test=0.762), total=   0.2s
# [CV] C=0.9326530612244898 ............................................
# [CV]  C=0.6387755102040816, score=(train=0.941, test=0.750), total=   0.2s
# [CV] C=0.9816326530612244 ............................................
# [CV]  C=0.5897959183673469, score=(train=0.928, test=0.750), total=   0.2s
# [CV] C=1.030612244897959 .............................................
# [CV]  C=0.6877551020408162, score=(train=0.944, test=0.738), total=   0.2s
# [CV] C=1.079591836734694 .............................................
# [CV]  C=0.736734693877551, score=(train=0.953, test=0.762), total=   0.2s
# [CV] C=1.1285714285714286 ............................................
# [CV]  C=0.883673469387755, score=(train=0.966, test=0.775), total=   0.2s
# [CV] C=1.1775510204081634 ............................................
# [CV]  C=0.8346938775510203, score=(train=0.959, test=0.775), total=   0.2s
# [CV] C=1.226530612244898 .............................................
# [CV]  C=0.7857142857142857, score=(train=0.959, test=0.775), total=   0.2s
# [CV] C=1.2755102040816326 ............................................
# [CV]  C=0.9326530612244898, score=(train=0.966, test=0.775), total=   0.2s
# [CV] C=1.3244897959183675 ............................................[CV]  C=0.9816326530612244, score=(train=0.966, test=0.775), total=   0.2s
#
# [CV] C=1.373469387755102 .............................................
# [CV]  C=1.030612244897959, score=(train=0.966, test=0.787), total=   0.2s
# [CV] C=1.4224489795918367 ............................................
# [CV]  C=1.079591836734694, score=(train=0.963, test=0.800), total=   0.2s
# [CV] C=1.4714285714285715 ............................................
# [Parallel(n_jobs=-1)]: Done 167 out of 250 | elapsed:    7.0s remaining:    3.4s
# [CV]  C=1.1775510204081634, score=(train=0.966, test=0.812), total=   0.2s[CV]  C=1.226530612244898, score=(train=0.966, test=0.825), total=   0.2s
# [CV] C=1.5204081632653061 ............................................
#
# [CV] C=1.5693877551020408 ............................................
# [CV]  C=1.1285714285714286, score=(train=0.966, test=0.800), total=   0.2s
# [CV] C=1.6183673469387756 ............................................
# [CV]  C=1.2755102040816326, score=(train=0.966, test=0.825), total=   0.2s
# [CV] C=1.6673469387755102 ............................................
# [CV]  C=1.3244897959183675, score=(train=0.969, test=0.825), total=   0.2s
# [CV] C=1.7163265306122448 ............................................
# [CV]  C=1.373469387755102, score=(train=0.972, test=0.825), total=   0.2s
# [CV] C=1.7653061224489797 ............................................
# [CV]  C=1.4714285714285715, score=(train=0.975, test=0.838), total=   0.2s
# [CV] C=1.8142857142857143 ............................................
# [CV]  C=1.4224489795918367, score=(train=0.975, test=0.838), total=   0.2s
# [CV] C=1.863265306122449 .............................................
# [CV]  C=1.5204081632653061, score=(train=0.975, test=0.838), total=   0.2s
# [CV] C=1.9122448979591837 ............................................
# [CV]  C=1.5693877551020408, score=(train=0.975, test=0.838), total=   0.2s
# [CV] C=1.9612244897959183 ............................................
# [CV]  C=1.6183673469387756, score=(train=0.978, test=0.838), total=   0.2s
# [CV] C=2.010204081632653 .............................................
# [CV]  C=1.7163265306122448, score=(train=0.981, test=0.838), total=   0.2s
# [CV] C=2.059183673469388 .............................................
# [CV]  C=1.863265306122449, score=(train=0.981, test=0.838), total=   0.2s[CV]  C=1.6673469387755102, score=(train=0.981, test=0.838), total=   0.2s
# [CV] C=2.1081632653061226 ............................................
#
# [CV] C=2.157142857142857 .............................................
# [CV]  C=1.8142857142857143, score=(train=0.981, test=0.838), total=   0.2s
# [CV] C=2.206122448979592 .............................................
# [CV]  C=1.7653061224489797, score=(train=0.981, test=0.838), total=   0.2s
# [CV] C=2.2551020408163267 ............................................
# [CV]  C=1.9122448979591837, score=(train=0.984, test=0.838), total=   0.2s
# [CV] C=2.304081632653061 .............................................
# [CV]  C=1.9612244897959183, score=(train=0.988, test=0.838), total=   0.2s
# [CV] C=2.353061224489796 .............................................
# [CV]  C=2.010204081632653, score=(train=0.991, test=0.838), total=   0.2s
# [CV] C=2.4020408163265308 ............................................
# [CV]  C=2.059183673469388, score=(train=0.994, test=0.838), total=   0.2s
# [CV] C=2.451020408163265 .............................................
# [CV]  C=2.1081632653061226, score=(train=0.994, test=0.838), total=   0.2s
# [CV] C=2.5 ...........................................................
# [CV]  C=2.206122448979592, score=(train=0.994, test=0.838), total=   0.2s
# [CV] C=0.1 ...........................................................[CV]  C=2.157142857142857, score=(train=0.994, test=0.838), total=   0.2s
#
# [CV] C=0.1489795918367347 ............................................
# [CV]  C=2.2551020408163267, score=(train=0.994, test=0.838), total=   0.2s
# [CV] C=0.19795918367346937 ...........................................
# [CV]  C=2.304081632653061, score=(train=0.994, test=0.850), total=   0.2s
# [CV] C=0.24693877551020407 ...........................................
# [CV]  C=2.353061224489796, score=(train=0.994, test=0.850), total=   0.2s
# [CV] C=0.29591836734693877 ...........................................
# [CV]  C=2.4020408163265308, score=(train=0.994, test=0.850), total=   0.2s
# [CV] C=0.3448979591836735 ............................................
# [CV] ........... C=2.5, score=(train=0.994, test=0.850), total=   0.2s
# [CV] C=0.3938775510204081 ............................................
# [CV]  C=2.451020408163265, score=(train=0.994, test=0.850), total=   0.2s
# [CV] C=0.44285714285714284 ...........................................
# [CV]  C=0.19795918367346937, score=(train=0.637, test=0.600), total=   0.2s
# [CV] C=0.49183673469387756 ...........................................
# [CV] ........... C=0.1, score=(train=0.253, test=0.250), total=   0.2s
# [CV] C=0.5408163265306122 ............................................
# [CV]  C=0.1489795918367347, score=(train=0.512, test=0.537), total=   0.2s
# [CV] C=0.5897959183673469 ............................................
# [CV]  C=0.29591836734693877, score=(train=0.841, test=0.725), total=   0.2s
# [CV] C=0.6387755102040816 ............................................
# [CV]  C=0.3448979591836735, score=(train=0.856, test=0.750), total=   0.2s
# [CV] C=0.6877551020408162 ............................................
# [CV]  C=0.3938775510204081, score=(train=0.884, test=0.775), total=   0.2s
# [CV] C=0.736734693877551 .............................................
# [CV]  C=0.24693877551020407, score=(train=0.762, test=0.700), total=   0.3s
# [CV] C=0.7857142857142857 ............................................
# [CV]  C=0.49183673469387756, score=(train=0.903, test=0.787), total=   0.2s
# [CV] C=0.8346938775510203 ............................................
# [CV]  C=0.44285714285714284, score=(train=0.897, test=0.775), total=   0.2s
# [CV] C=0.883673469387755 .............................................
# [CV]  C=0.5897959183673469, score=(train=0.919, test=0.812), total=   0.2s
# [CV] C=0.9326530612244898 ............................................
# [CV]  C=0.5408163265306122, score=(train=0.909, test=0.800), total=   0.2s
# [CV] C=0.9816326530612244 ............................................
# [CV]  C=0.6387755102040816, score=(train=0.925, test=0.812), total=   0.2s
# [CV] C=1.030612244897959 .............................................
# [CV]  C=0.6877551020408162, score=(train=0.931, test=0.825), total=   0.2s
# [CV] C=1.079591836734694 .............................................
# [CV]  C=0.736734693877551, score=(train=0.938, test=0.838), total=   0.2s
# [CV] C=1.1285714285714286 ............................................
# [CV]  C=0.7857142857142857, score=(train=0.938, test=0.825), total=   0.2s
# [CV] C=1.1775510204081634 ............................................
# [CV]  C=0.8346938775510203, score=(train=0.941, test=0.838), total=   0.2s
# [CV] C=1.226530612244898 .............................................
# [CV]  C=0.883673469387755, score=(train=0.941, test=0.838), total=   0.2s
# [CV] C=1.2755102040816326 ............................................
# [CV]  C=1.030612244897959, score=(train=0.950, test=0.838), total=   0.2s
# [CV] C=1.3244897959183675 ............................................
# [CV]  C=0.9816326530612244, score=(train=0.947, test=0.838), total=   0.2s
# [CV] C=1.373469387755102 .............................................
# [CV]  C=0.9326530612244898, score=(train=0.947, test=0.838), total=   0.2s
# [CV] C=1.4224489795918367 ............................................
# [CV]  C=1.079591836734694, score=(train=0.950, test=0.838), total=   0.2s
# [CV] C=1.4714285714285715 ............................................
# [CV]  C=1.1285714285714286, score=(train=0.959, test=0.838), total=   0.2s
# [CV] C=1.5204081632653061 ............................................
# [CV]  C=1.1775510204081634, score=(train=0.963, test=0.838), total=   0.2s
# [CV] C=1.5693877551020408 ............................................
# [CV]  C=1.226530612244898, score=(train=0.966, test=0.838), total=   0.2s
# [CV] C=1.6183673469387756 ............................................
# [CV]  C=1.2755102040816326, score=(train=0.969, test=0.838), total=   0.2s
# [CV] C=1.6673469387755102 ............................................
# [CV]  C=1.3244897959183675, score=(train=0.972, test=0.838), total=   0.2s
# [CV] C=1.7163265306122448 ............................................
# [CV]  C=1.373469387755102, score=(train=0.972, test=0.838), total=   0.2s
# [CV] C=1.7653061224489797 ............................................
# [CV]  C=1.4224489795918367, score=(train=0.975, test=0.838), total=   0.2s
# [CV] C=1.8142857142857143 ............................................
# [CV]  C=1.5693877551020408, score=(train=0.978, test=0.838), total=   0.2s
# [CV] C=1.863265306122449 .............................................
# [CV]  C=1.5204081632653061, score=(train=0.978, test=0.838), total=   0.2s
# [CV] C=1.9122448979591837 ............................................
# [CV]  C=1.4714285714285715, score=(train=0.978, test=0.838), total=   0.2s
# [CV] C=1.9612244897959183 ............................................
# [CV]  C=1.6183673469387756, score=(train=0.978, test=0.863), total=   0.2s
# [CV] C=2.010204081632653 .............................................
# [CV]  C=1.6673469387755102, score=(train=0.981, test=0.863), total=   0.2s
# [CV] C=2.059183673469388 .............................................
# [CV]  C=1.7653061224489797, score=(train=0.981, test=0.863), total=   0.2s
# [CV] C=2.1081632653061226 ............................................
# [CV]  C=1.8142857142857143, score=(train=0.981, test=0.863), total=   0.2s
# [CV] C=2.157142857142857 .............................................
# [CV]  C=1.863265306122449, score=(train=0.984, test=0.850), total=   0.2s
# [CV] C=2.206122448979592 .............................................
# [CV]  C=1.7163265306122448, score=(train=0.981, test=0.863), total=   0.2s
# [CV] C=2.2551020408163267 ............................................
# [CV]  C=1.9122448979591837, score=(train=0.984, test=0.850), total=   0.2s
# [CV] C=2.304081632653061 .............................................
# [CV]  C=1.9612244897959183, score=(train=0.984, test=0.863), total=   0.2s
# [CV] C=2.353061224489796 .............................................
# [CV]  C=2.059183673469388, score=(train=0.991, test=0.887), total=   0.2s
# [CV] C=2.4020408163265308 ............................................
# [CV]  C=2.010204081632653, score=(train=0.991, test=0.875), total=   0.2s
# [CV] C=2.451020408163265 .............................................
# [CV]  C=2.1081632653061226, score=(train=0.991, test=0.887), total=   0.2s
# [CV] C=2.5 ...........................................................
# [CV]  C=2.157142857142857, score=(train=0.991, test=0.887), total=   0.2s
# [CV]  C=2.206122448979592, score=(train=0.994, test=0.887), total=   0.2s
# [CV]  C=2.2551020408163267, score=(train=0.994, test=0.887), total=   0.2s
# [CV]  C=2.353061224489796, score=(train=0.994, test=0.887), total=   0.2s
# [CV]  C=2.304081632653061, score=(train=0.994, test=0.887), total=   0.2s
# [CV]  C=2.4020408163265308, score=(train=0.994, test=0.887), total=   0.2s
# [CV]  C=2.451020408163265, score=(train=0.994, test=0.887), total=   0.2s
# [CV] ........... C=2.5, score=(train=0.994, test=0.887), total=   0.2s
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:   10.3s finished

# %%
with plt.style.context('ggplot'):
    svm_train_scores_mean = np.mean(svm_learning_curve_results["train_scores"], axis=1)
    svm_train_scores_std = np.std(svm_learning_curve_results["train_scores"], axis=1)
    svm_test_scores_mean = np.mean(svm_learning_curve_results["test_scores"], axis=1)
    svm_test_scores_std = np.std(svm_learning_curve_results["test_scores"], axis=1)
    
    fig0, ax0 = plt.subplots()
    ax0.set_xlabel("Percent of Training Set")
    ax0.set_ylabel("Accuracy (%)", color='tab:orange')
    ax0.set_title("{} {} Learning Curve".format(svm_segment, dataset))
    ax0.tick_params(axis='y', labelcolor="black")
    ax0.set_ylim(0, 1.1)
    lw = 2
    plt.plot([i for i in range(50)], svm_train_scores_mean, label="Training score",
                 color="darkorange", lw=lw)
    plt.fill_between([i for i in range(50)], svm_train_scores_mean - svm_train_scores_std,
                     svm_train_scores_mean + svm_train_scores_std, alpha=0.2,
                     color="darkorange", lw=lw)
    plt.plot([i for i in range(50)], svm_test_scores_mean, label="Testing score",
                 color="navy", lw=lw)
    plt.fill_between([i for i in range(50)], svm_test_scores_mean - svm_test_scores_std,
                     svm_test_scores_mean + svm_test_scores_std, alpha=0.2,
                     color="navy", lw=lw)
    plt.legend(loc="best")
    plt.savefig("{}_{}_Learning_Curve.png".format(svm_segment, dataset))
    plt.show()
    
plt.close("all")

# %%
with plt.style.context('ggplot'):
    svm_train_scores_mean = np.mean(svm_validation_curve_results["train_scores"], axis=1)
    svm_train_scores_std = np.std(svm_validation_curve_results["train_scores"], axis=1)
    svm_test_scores_mean = np.mean(svm_validation_curve_results["test_scores"], axis=1)
    svm_test_scores_std = np.std(svm_validation_curve_results["test_scores"], axis=1)

    plt.title("Validation Curve with {} \n {}".format(svm_segment, dataset))
    plt.xlabel("{}".format(svm_param_name))
    plt.ylabel("Score")
    plt.ylim(0.0, 1.1)
    lw = 2
    plt.plot([i for i in range(50)], svm_train_scores_mean, label="Training score",
                 color="darkorange", lw=lw)
    plt.fill_between([i for i in range(50)], svm_train_scores_mean - svm_train_scores_std,
                     svm_train_scores_mean + svm_train_scores_std, alpha=0.2,
                     color="darkorange", lw=lw)
    plt.plot([i for i in range(50)], svm_test_scores_mean, label="Cross-validation score",
                 color="navy", lw=lw)
    plt.fill_between([i for i in range(50)], svm_test_scores_mean - svm_test_scores_std,
                     svm_test_scores_mean + svm_test_scores_std, alpha=0.2,
                     color="navy", lw=lw)
    plt.legend(loc="best")
    plt.savefig("{}_{}_Validation_Curve.png".format(svm_segment, dataset))
    plt.show()
plt.close('all')

# %%
dt_segment = "Decision Tree"
dt_estimator = DecisionTreeClassifier()
dt_grid_search = GridSearchCV(dt_estimator, param_grid=decision_tree_params,  n_jobs=n_jobs, verbose=verbose_int)
dt_learning_curve_results = {"train_sizes": None, "train_scores": None, "test_scores": None, "fit_times": None}
dt_validation_curve_results = {"train_scores": None, "test_scores": None}

# %%
with parallel_backend('threading'):
    dt_grid_search.fit(X,y)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] criterion=gini, max_depth=50, min_samples_split=4 ...............
# [CV] criterion=gini, max_depth=50, min_samples_split=4 ...............
# [CV] criterion=gini, max_depth=50, min_samples_split=4 ...............[CV] criterion=gini, max_depth=50, min_samples_split=4 ...............
#
# [CV] criterion=gini, max_depth=50, min_samples_split=4 ...............
# [CV] criterion=gini, max_depth=50, min_samples_split=8 ...............
# [CV] criterion=gini, max_depth=50, min_samples_split=8 ...............
# [CV] criterion=gini, max_depth=50, min_samples_split=8 ...............
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [CV]  criterion=gini, max_depth=50, min_samples_split=4, score=0.720, total=   0.3s
# [CV] criterion=gini, max_depth=50, min_samples_split=8 ...............
# [CV]  criterion=gini, max_depth=50, min_samples_split=8, score=0.740, total=   0.3s
# [CV] criterion=gini, max_depth=50, min_samples_split=8 ...............
# [CV]  criterion=gini, max_depth=50, min_samples_split=4, score=0.730, total=   0.4s
# [CV] criterion=gini, max_depth=50, min_samples_split=12 ..............
# [CV]  criterion=gini, max_depth=50, min_samples_split=4, score=0.620, total=   0.4s
# [CV] criterion=gini, max_depth=50, min_samples_split=12 ..............
# [CV]  criterion=gini, max_depth=50, min_samples_split=8, score=0.705, total=   0.4s
# [CV] criterion=gini, max_depth=50, min_samples_split=12 ..............
# [CV]  criterion=gini, max_depth=50, min_samples_split=4, score=0.705, total=   0.4s
# [CV] criterion=gini, max_depth=50, min_samples_split=12 ..............
# [CV]  criterion=gini, max_depth=50, min_samples_split=8, score=0.698, total=   0.4s
# [CV] criterion=gini, max_depth=50, min_samples_split=12 ..............
# [CV]  criterion=gini, max_depth=50, min_samples_split=4, score=0.703, total=   0.4s
# [CV] criterion=gini, max_depth=100, min_samples_split=4 ..............
# [CV]  criterion=gini, max_depth=50, min_samples_split=8, score=0.708, total=   0.3s
# [CV] criterion=gini, max_depth=100, min_samples_split=4 ..............
# [CV]  criterion=gini, max_depth=50, min_samples_split=8, score=0.605, total=   0.4s[CV]  criterion=gini, max_depth=50, min_samples_split=12, score=0.748, total=   0.3s
# [CV] criterion=gini, max_depth=100, min_samples_split=4 ..............
#
# [CV] criterion=gini, max_depth=100, min_samples_split=4 ..............[CV]  criterion=gini, max_depth=50, min_samples_split=12, score=0.690, total=   0.3s
#
# [CV] criterion=gini, max_depth=100, min_samples_split=4 ..............
# [CV]  criterion=gini, max_depth=50, min_samples_split=12, score=0.700, total=   0.3s
# [CV] criterion=gini, max_depth=100, min_samples_split=8 ..............
# [CV]  criterion=gini, max_depth=100, min_samples_split=4, score=0.743, total=   0.3s
# [CV] criterion=gini, max_depth=100, min_samples_split=8 ..............
# [CV]  criterion=gini, max_depth=50, min_samples_split=12, score=0.613, total=   0.4s
# [CV] criterion=gini, max_depth=100, min_samples_split=8 ..............
# [CV]  criterion=gini, max_depth=50, min_samples_split=12, score=0.705, total=   0.3s
# [CV] criterion=gini, max_depth=100, min_samples_split=8 ..............
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    0.7s
# [CV]  criterion=gini, max_depth=100, min_samples_split=4, score=0.698, total=   0.3s
# [CV] criterion=gini, max_depth=100, min_samples_split=8 ..............
# [CV]  criterion=gini, max_depth=100, min_samples_split=8, score=0.755, total=   0.3s
# [CV] criterion=gini, max_depth=100, min_samples_split=12 .............
# [CV]  criterion=gini, max_depth=100, min_samples_split=4, score=0.728, total=   0.3s
# [CV] criterion=gini, max_depth=100, min_samples_split=12 .............
# [CV]  criterion=gini, max_depth=100, min_samples_split=4, score=0.690, total=   0.4s
# [CV] criterion=gini, max_depth=100, min_samples_split=12 .............
# [CV]  criterion=gini, max_depth=100, min_samples_split=4, score=0.637, total=   0.4s
# [CV] criterion=gini, max_depth=100, min_samples_split=12 .............
# [CV]  criterion=gini, max_depth=100, min_samples_split=8, score=0.698, total=   0.4s
# [CV] criterion=gini, max_depth=100, min_samples_split=12 .............
# [CV]  criterion=gini, max_depth=100, min_samples_split=8, score=0.635, total=   0.3s
# [CV] criterion=gini, max_depth=150, min_samples_split=4 ..............
# [CV]  criterion=gini, max_depth=100, min_samples_split=8, score=0.708, total=   0.4s
# [CV] criterion=gini, max_depth=150, min_samples_split=4 ..............
# [CV]  criterion=gini, max_depth=100, min_samples_split=12, score=0.743, total=   0.3s
# [CV] criterion=gini, max_depth=150, min_samples_split=4 ..............
# [CV]  criterion=gini, max_depth=100, min_samples_split=12, score=0.695, total=   0.3s
# [CV] criterion=gini, max_depth=150, min_samples_split=4 ..............
# [CV]  criterion=gini, max_depth=100, min_samples_split=12, score=0.610, total=   0.3s
# [CV] criterion=gini, max_depth=150, min_samples_split=4 ..............
# [CV]  criterion=gini, max_depth=100, min_samples_split=8, score=0.703, total=   0.4s
# [CV] criterion=gini, max_depth=150, min_samples_split=8 ..............
# [CV]  criterion=gini, max_depth=100, min_samples_split=12, score=0.705, total=   0.3s
# [CV] criterion=gini, max_depth=150, min_samples_split=8 ..............
# [CV]  criterion=gini, max_depth=100, min_samples_split=12, score=0.695, total=   0.4s
# [CV] criterion=gini, max_depth=150, min_samples_split=8 ..............
# [CV]  criterion=gini, max_depth=150, min_samples_split=4, score=0.740, total=   0.3s
# [CV] criterion=gini, max_depth=150, min_samples_split=8 ..............
# [CV]  criterion=gini, max_depth=150, min_samples_split=4, score=0.715, total=   0.3s
# [CV] criterion=gini, max_depth=150, min_samples_split=8 ..............
# [CV]  criterion=gini, max_depth=150, min_samples_split=4, score=0.635, total=   0.3s
# [CV] criterion=gini, max_depth=150, min_samples_split=12 .............
# [CV]  criterion=gini, max_depth=150, min_samples_split=8, score=0.738, total=   0.3s
# [CV]  criterion=gini, max_depth=150, min_samples_split=4, score=0.728, total=   0.3s
# [CV] criterion=gini, max_depth=150, min_samples_split=12 .............[CV] criterion=gini, max_depth=150, min_samples_split=12 .............
#
# [CV]  criterion=gini, max_depth=150, min_samples_split=4, score=0.705, total=   0.4s
# [CV] criterion=gini, max_depth=150, min_samples_split=12 .............
# [CV]  criterion=gini, max_depth=150, min_samples_split=8, score=0.695, total=   0.3s
# [CV] criterion=gini, max_depth=150, min_samples_split=12 .............
# [CV]  criterion=gini, max_depth=150, min_samples_split=8, score=0.713, total=   0.3s
# [CV] criterion=gini, max_depth=200, min_samples_split=4 ..............
# [CV]  criterion=gini, max_depth=150, min_samples_split=8, score=0.618, total=   0.4s
# [CV] criterion=gini, max_depth=200, min_samples_split=4 ..............
# [CV]  criterion=gini, max_depth=150, min_samples_split=8, score=0.703, total=   0.3s
# [CV] criterion=gini, max_depth=200, min_samples_split=4 ..............
# [CV]  criterion=gini, max_depth=150, min_samples_split=12, score=0.728, total=   0.3s
# [CV] criterion=gini, max_depth=200, min_samples_split=4 ..............
# [CV]  criterion=gini, max_depth=150, min_samples_split=12, score=0.705, total=   0.3s
# [CV] criterion=gini, max_depth=200, min_samples_split=4 ..............
# [CV]  criterion=gini, max_depth=150, min_samples_split=12, score=0.613, total=   0.3s
# [CV] criterion=gini, max_depth=200, min_samples_split=8 ..............
# [CV]  criterion=gini, max_depth=150, min_samples_split=12, score=0.708, total=   0.4s
# [CV] criterion=gini, max_depth=200, min_samples_split=8 ..............
# [CV]  criterion=gini, max_depth=200, min_samples_split=4, score=0.743, total=   0.3s
# [CV] criterion=gini, max_depth=200, min_samples_split=8 ..............
# [CV]  criterion=gini, max_depth=150, min_samples_split=12, score=0.713, total=   0.3s
# [CV] criterion=gini, max_depth=200, min_samples_split=8 ..............
# [CV]  criterion=gini, max_depth=200, min_samples_split=4, score=0.667, total=   0.3s
# [CV] criterion=gini, max_depth=200, min_samples_split=8 ..............
# [CV]  criterion=gini, max_depth=200, min_samples_split=4, score=0.688, total=   0.4s
# [CV] criterion=gini, max_depth=200, min_samples_split=12 .............
# [CV]  criterion=gini, max_depth=200, min_samples_split=8, score=0.752, total=   0.3s
# [CV] criterion=gini, max_depth=200, min_samples_split=12 .............
# [CV]  criterion=gini, max_depth=200, min_samples_split=4, score=0.640, total=   0.3s
# [CV] criterion=gini, max_depth=200, min_samples_split=12 .............
# [CV]  criterion=gini, max_depth=200, min_samples_split=4, score=0.705, total=   0.3s
# [CV] criterion=gini, max_depth=200, min_samples_split=12 .............
# [CV]  criterion=gini, max_depth=200, min_samples_split=8, score=0.708, total=   0.4s
# [CV] criterion=gini, max_depth=200, min_samples_split=12 .............
# [CV]  criterion=gini, max_depth=200, min_samples_split=8, score=0.605, total=   0.4s
# [CV] criterion=entropy, max_depth=50, min_samples_split=4 ............
# [CV]  criterion=gini, max_depth=200, min_samples_split=8, score=0.672, total=   0.4s
# [CV] criterion=entropy, max_depth=50, min_samples_split=4 ............
# [CV]  criterion=gini, max_depth=200, min_samples_split=8, score=0.710, total=   0.4s
# [CV] criterion=entropy, max_depth=50, min_samples_split=4 ............
# [CV]  criterion=gini, max_depth=200, min_samples_split=12, score=0.730, total=   0.3s
# [CV] criterion=entropy, max_depth=50, min_samples_split=4 ............
# [CV]  criterion=gini, max_depth=200, min_samples_split=12, score=0.700, total=   0.3s
# [CV] criterion=entropy, max_depth=50, min_samples_split=4 ............
# [CV]  criterion=gini, max_depth=200, min_samples_split=12, score=0.708, total=   0.3s
# [CV] criterion=entropy, max_depth=50, min_samples_split=8 ............
# [CV]  criterion=gini, max_depth=200, min_samples_split=12, score=0.700, total=   0.3s
# [CV] criterion=entropy, max_depth=50, min_samples_split=8 ............
# [CV]  criterion=gini, max_depth=200, min_samples_split=12, score=0.605, total=   0.4s
# [CV] criterion=entropy, max_depth=50, min_samples_split=8 ............
# [CV]  criterion=entropy, max_depth=50, min_samples_split=4, score=0.690, total=   0.8s
# [CV] criterion=entropy, max_depth=50, min_samples_split=8 ............
# [CV]  criterion=entropy, max_depth=50, min_samples_split=4, score=0.662, total=   0.9s
# [CV] criterion=entropy, max_depth=50, min_samples_split=8 ............
# [CV]  criterion=entropy, max_depth=50, min_samples_split=4, score=0.675, total=   0.9s
# [CV] criterion=entropy, max_depth=50, min_samples_split=12 ...........
# [CV]  criterion=entropy, max_depth=50, min_samples_split=4, score=0.733, total=   1.0s
# [CV] criterion=entropy, max_depth=50, min_samples_split=12 ...........
# [CV]  criterion=entropy, max_depth=50, min_samples_split=8, score=0.728, total=   0.7s
# [CV] criterion=entropy, max_depth=50, min_samples_split=12 ...........
# [CV]  criterion=entropy, max_depth=50, min_samples_split=8, score=0.650, total=   0.7s
# [CV] criterion=entropy, max_depth=50, min_samples_split=12 ...........
# [CV]  criterion=entropy, max_depth=50, min_samples_split=8, score=0.698, total=   0.7s
# [CV] criterion=entropy, max_depth=50, min_samples_split=12 ...........
# [CV]  criterion=entropy, max_depth=50, min_samples_split=4, score=0.735, total=   0.9s
# [CV] criterion=entropy, max_depth=100, min_samples_split=4 ...........
# [CV]  criterion=entropy, max_depth=50, min_samples_split=8, score=0.752, total=   0.8s
# [CV] criterion=entropy, max_depth=100, min_samples_split=4 ...........
# [CV]  criterion=entropy, max_depth=50, min_samples_split=8, score=0.677, total=   0.9s
# [CV] criterion=entropy, max_depth=100, min_samples_split=4 ...........
# [CV]  criterion=entropy, max_depth=50, min_samples_split=12, score=0.632, total=   0.7s
# [CV] criterion=entropy, max_depth=100, min_samples_split=4 ...........
# [CV]  criterion=entropy, max_depth=50, min_samples_split=12, score=0.743, total=   0.7s
# [CV] criterion=entropy, max_depth=100, min_samples_split=4 ...........
# [CV]  criterion=entropy, max_depth=50, min_samples_split=12, score=0.718, total=   0.9s
# [CV] criterion=entropy, max_depth=100, min_samples_split=8 ...........
# [CV]  criterion=entropy, max_depth=50, min_samples_split=12, score=0.700, total=   0.8s
# [CV] criterion=entropy, max_depth=100, min_samples_split=8 ...........
# [CV]  criterion=entropy, max_depth=100, min_samples_split=4, score=0.748, total=   0.7s
# [CV] criterion=entropy, max_depth=100, min_samples_split=8 ...........
# [CV]  criterion=entropy, max_depth=50, min_samples_split=12, score=0.657, total=   0.8s
# [CV] criterion=entropy, max_depth=100, min_samples_split=8 ...........
# [CV]  criterion=entropy, max_depth=100, min_samples_split=4, score=0.672, total=   0.7s
# [CV] criterion=entropy, max_depth=100, min_samples_split=8 ...........
# [CV]  criterion=entropy, max_depth=100, min_samples_split=4, score=0.765, total=   0.7s
# [CV] criterion=entropy, max_depth=100, min_samples_split=12 ..........
# [CV]  criterion=entropy, max_depth=100, min_samples_split=4, score=0.693, total=   0.8s
# [CV] criterion=entropy, max_depth=100, min_samples_split=12 ..........
# [CV]  criterion=entropy, max_depth=100, min_samples_split=4, score=0.660, total=   0.9s
# [CV] criterion=entropy, max_depth=100, min_samples_split=12 ..........
# [CV]  criterion=entropy, max_depth=100, min_samples_split=8, score=0.645, total=   0.7s
# [CV] criterion=entropy, max_depth=100, min_samples_split=12 ..........
# [CV]  criterion=entropy, max_depth=100, min_samples_split=8, score=0.728, total=   0.8s
# [CV] criterion=entropy, max_depth=100, min_samples_split=12 ..........
# [CV]  criterion=entropy, max_depth=100, min_samples_split=8, score=0.685, total=   0.8s
# [CV] criterion=entropy, max_depth=150, min_samples_split=4 ...........
# [CV]  criterion=entropy, max_depth=100, min_samples_split=8, score=0.650, total=   0.8s
# [CV] criterion=entropy, max_depth=150, min_samples_split=4 ...........
# [CV]  criterion=entropy, max_depth=100, min_samples_split=12, score=0.688, total=   0.6s
# [CV] criterion=entropy, max_depth=150, min_samples_split=4 ...........
# [CV]  criterion=entropy, max_depth=100, min_samples_split=12, score=0.708, total=   0.7s
# [CV] criterion=entropy, max_depth=150, min_samples_split=4 ...........
# [CV]  criterion=entropy, max_depth=100, min_samples_split=8, score=0.750, total=   0.7s
# [CV] criterion=entropy, max_depth=150, min_samples_split=4 ...........
# [CV]  criterion=entropy, max_depth=100, min_samples_split=12, score=0.635, total=   0.7s
# [CV] criterion=entropy, max_depth=150, min_samples_split=8 ...........
# [CV]  criterion=entropy, max_depth=100, min_samples_split=12, score=0.660, total=   0.7s
# [CV] criterion=entropy, max_depth=150, min_samples_split=8 ...........
# [CV]  criterion=entropy, max_depth=100, min_samples_split=12, score=0.748, total=   0.7s
# [CV] criterion=entropy, max_depth=150, min_samples_split=8 ...........
# [CV]  criterion=entropy, max_depth=150, min_samples_split=4, score=0.700, total=   0.7s
# [CV] criterion=entropy, max_depth=150, min_samples_split=8 ...........
# [CV]  criterion=entropy, max_depth=150, min_samples_split=4, score=0.720, total=   0.8s
# [CV] criterion=entropy, max_depth=150, min_samples_split=8 ...........
# [CV]  criterion=entropy, max_depth=150, min_samples_split=4, score=0.662, total=   0.7s
# [CV] criterion=entropy, max_depth=150, min_samples_split=12 ..........
# [CV]  criterion=entropy, max_depth=150, min_samples_split=4, score=0.660, total=   0.7s
# [CV] criterion=entropy, max_depth=150, min_samples_split=12 ..........
# [CV]  criterion=entropy, max_depth=150, min_samples_split=4, score=0.757, total=   0.7s
# [CV] criterion=entropy, max_depth=150, min_samples_split=12 ..........
# [CV]  criterion=entropy, max_depth=150, min_samples_split=8, score=0.680, total=   0.7s
# [CV] criterion=entropy, max_depth=150, min_samples_split=12 ..........
# [CV]  criterion=entropy, max_depth=150, min_samples_split=8, score=0.730, total=   0.7s
# [CV] criterion=entropy, max_depth=150, min_samples_split=12 ..........
# [CV]  criterion=entropy, max_depth=150, min_samples_split=8, score=0.657, total=   0.7s
# [CV] criterion=entropy, max_depth=200, min_samples_split=4 ...........
# [CV]  criterion=entropy, max_depth=150, min_samples_split=8, score=0.662, total=   0.7s
# [CV] criterion=entropy, max_depth=200, min_samples_split=4 ...........
# [CV]  criterion=entropy, max_depth=150, min_samples_split=8, score=0.750, total=   0.7s
# [CV] criterion=entropy, max_depth=200, min_samples_split=4 ...........
# [CV]  criterion=entropy, max_depth=150, min_samples_split=12, score=0.695, total=   0.6s
# [CV] criterion=entropy, max_depth=200, min_samples_split=4 ...........
# [CV]  criterion=entropy, max_depth=150, min_samples_split=12, score=0.725, total=   0.7s
# [CV] criterion=entropy, max_depth=200, min_samples_split=4 ...........
# [CV]  criterion=entropy, max_depth=150, min_samples_split=12, score=0.665, total=   0.7s
# [CV] criterion=entropy, max_depth=200, min_samples_split=8 ...........
# [CV]  criterion=entropy, max_depth=150, min_samples_split=12, score=0.632, total=   0.7s
# [CV] criterion=entropy, max_depth=200, min_samples_split=8 ...........
# [CV]  criterion=entropy, max_depth=150, min_samples_split=12, score=0.755, total=   0.7s
# [CV] criterion=entropy, max_depth=200, min_samples_split=8 ...........
# [CV]  criterion=entropy, max_depth=200, min_samples_split=4, score=0.690, total=   0.7s
# [CV] criterion=entropy, max_depth=200, min_samples_split=8 ...........
# [CV]  criterion=entropy, max_depth=200, min_samples_split=4, score=0.750, total=   0.7s
# [CV] criterion=entropy, max_depth=200, min_samples_split=8 ...........
# [CV]  criterion=entropy, max_depth=200, min_samples_split=4, score=0.642, total=   0.7s
# [CV] criterion=entropy, max_depth=200, min_samples_split=12 ..........
# [CV]  criterion=entropy, max_depth=200, min_samples_split=4, score=0.665, total=   0.7s
# [CV] criterion=entropy, max_depth=200, min_samples_split=12 ..........
# [CV]  criterion=entropy, max_depth=200, min_samples_split=4, score=0.745, total=   0.7s
# [CV] criterion=entropy, max_depth=200, min_samples_split=12 ..........
# [CV]  criterion=entropy, max_depth=200, min_samples_split=8, score=0.718, total=   0.7s
# [CV] criterion=entropy, max_depth=200, min_samples_split=12 ..........
# [CV]  criterion=entropy, max_depth=200, min_samples_split=8, score=0.688, total=   0.7s
# [CV] criterion=entropy, max_depth=200, min_samples_split=12 ..........
# [CV]  criterion=entropy, max_depth=200, min_samples_split=8, score=0.623, total=   0.7s
# [CV]  criterion=entropy, max_depth=200, min_samples_split=8, score=0.657, total=   0.7s
# [CV]  criterion=entropy, max_depth=200, min_samples_split=8, score=0.743, total=   0.7s
# [CV]  criterion=entropy, max_depth=200, min_samples_split=12, score=0.720, total=   0.6s
# [CV]  criterion=entropy, max_depth=200, min_samples_split=12, score=0.695, total=   0.5s
# [CV]  criterion=entropy, max_depth=200, min_samples_split=12, score=0.632, total=   0.5s
# [CV]  criterion=entropy, max_depth=200, min_samples_split=12, score=0.662, total=   0.5s
# [CV]  criterion=entropy, max_depth=200, min_samples_split=12, score=0.752, total=   0.5s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    8.2s finished

# %%
with parallel_backend('threading'):    
    dt_learning_curve_results["train_sizes"], dt_learning_curve_results["train_scores"], dt_learning_curve_results["test_scores"], dt_learning_curve_results["fit_times"], _ = learning_curve(dt_grid_search.best_estimator_, X, y, cv=cross_validation, n_jobs=n_jobs, verbose=3, train_sizes=train_sizes, return_times=True)

# %%
with parallel_backend('threading'):    
    dt_validation_curve_results["train_scores"], dt_validation_curve_results["test_scores"] = validation_curve(dt_grid_search.best_estimator_, X=Validation_X, y=validation_y, n_jobs=n_jobs, cv=cross_validation, verbose=3, param_name='min_samples_leaf', param_range=[i for i in range(1, 51)])

plt.close("all")

# %%
with plt.style.context('ggplot'):
    dt_train_scores_mean = np.mean(dt_learning_curve_results["train_scores"], axis=1)
    dt_train_scores_std = np.std(dt_learning_curve_results["train_scores"], axis=1)
    dt_test_scores_mean = np.mean(dt_learning_curve_results["test_scores"], axis=1)
    dt_test_scores_std = np.std(dt_learning_curve_results["test_scores"], axis=1)
    
    fig0, ax0 = plt.subplots()
    ax0.set_xlabel("Percent of Training Set")
    ax0.set_ylabel("Accuracy (%)", color='tab:orange')
    ax0.set_title("Decision_Tree Learning Curve")
    ax0.tick_params(axis='y', labelcolor="black")
    ax0.set_ylim(0, 1.1)

    lw = 2
    plt.plot([i for i in range(50)], dt_train_scores_mean, label="Training score",
                 color="darkorange", lw=lw)
    
    plt.fill_between([i for i in range(50)], dt_train_scores_mean - dt_train_scores_std,
                     dt_train_scores_mean + dt_train_scores_std, alpha=0.2,
                     color="darkorange", lw=lw)
    plt.plot([i for i in range(50)], dt_test_scores_mean, label="Testing score",
                 color="navy", lw=lw)
    plt.fill_between([i for i in range(50)], dt_test_scores_mean - dt_test_scores_std,
                     dt_test_scores_mean + dt_test_scores_std, alpha=0.2,
                     color="navy", lw=lw)
    plt.legend(loc="best")
    plt.savefig("{}_{}_Learning_Curve.png".format(dt_segment, dataset))
    plt.show()
    
plt.close("all")

# %%
with plt.style.context('ggplot'):
    dt_train_scores_mean = np.mean(dt_validation_curve_results["train_scores"], axis=1)
    dt_train_scores_std = np.std(dt_validation_curve_results["train_scores"], axis=1)
    dt_test_scores_mean = np.mean(dt_validation_curve_results["test_scores"], axis=1)
    dt_test_scores_std = np.std(dt_validation_curve_results["test_scores"], axis=1)

    plt.title("Validation Curve with {} \n {}".format(dt_segment, dataset))
    plt.xlabel("{}".format('min_samples_leaf'))
    plt.ylabel("Score")
    plt.ylim(0.0, 1.1)
    lw = 2
    plt.plot([i for i in range(50)], dt_train_scores_mean, label="Training score",
                 color="darkorange", lw=lw)
    plt.fill_between([i for i in range(50)], dt_train_scores_mean - dt_train_scores_std,
                     dt_train_scores_mean + dt_train_scores_std, alpha=0.2,
                     color="darkorange", lw=lw)
    plt.plot([i for i in range(50)], dt_test_scores_mean, label="Cross-validation score",
                 color="navy", lw=lw)
    plt.fill_between([i for i in range(50)], dt_test_scores_mean - dt_test_scores_std,
                     dt_test_scores_mean + dt_test_scores_std, alpha=0.2,
                     color="navy", lw=lw)
    plt.legend(loc="best")
    plt.savefig("{}_{}_Validation_Curve.png".format(dt_segment, dataset))
    plt.show()

# %%
nn_segment = "Neural Network"
nn_estimator = MLPClassifier()
nn_grid_search = GridSearchCV(nn_estimator, param_grid=neural_network_params, n_jobs=n_jobs, verbose=verbose_int)
nn_learning_curve_results = {"train_sizes": None, "train_scores": None, "test_scores": None, "fit_times": None}
nn_validation_curve_results = {"train_scores": None, "test_scores": None}

# %%
with parallel_backend('threading'):
    nn_grid_search.fit(X,y)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] activation=identity, alpha=0.0001, max_iter=1000, solver=lbfgs ..
# [CV] activation=identity, alpha=0.0001, max_iter=1000, solver=lbfgs ..
# [CV] activation=identity, alpha=0.0001, max_iter=1000, solver=lbfgs ..
# [CV] activation=identity, alpha=0.0001, max_iter=1000, solver=lbfgs ..[CV] activation=identity, alpha=0.0001, max_iter=1000, solver=lbfgs ..
#
# [CV] activation=identity, alpha=0.0001, max_iter=1000, solver=sgd ....
# [CV] activation=identity, alpha=0.0001, max_iter=1000, solver=sgd ....
# [CV] activation=identity, alpha=0.0001, max_iter=1000, solver=sgd ....
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [CV]  activation=identity, alpha=0.0001, max_iter=1000, solver=lbfgs, score=0.807, total=   2.0s
# [CV] activation=identity, alpha=0.0001, max_iter=1000, solver=sgd ....
# [CV]  activation=identity, alpha=0.0001, max_iter=1000, solver=lbfgs, score=0.815, total=   2.1s
# [CV] activation=identity, alpha=0.0001, max_iter=1000, solver=sgd ....
# [CV]  activation=identity, alpha=0.0001, max_iter=1000, solver=lbfgs, score=0.892, total=   2.1s
# [CV] activation=identity, alpha=0.0001, max_iter=1000, solver=adam ...
# [CV]  activation=identity, alpha=0.0001, max_iter=1000, solver=lbfgs, score=0.875, total=   2.1s
# [CV] activation=identity, alpha=0.0001, max_iter=1000, solver=adam ...
# [CV]  activation=identity, alpha=0.0001, max_iter=1000, solver=lbfgs, score=0.828, total=   2.2s
# [CV] activation=identity, alpha=0.0001, max_iter=1000, solver=adam ...
# [CV]  activation=identity, alpha=0.0001, max_iter=1000, solver=adam, score=0.807, total=  15.7s
# [CV] activation=identity, alpha=0.0001, max_iter=1000, solver=adam ...
# [CV]  activation=identity, alpha=0.0001, max_iter=1000, solver=adam, score=0.812, total=  16.2s
# [CV] activation=identity, alpha=0.0001, max_iter=1000, solver=adam ...
# [CV]  activation=identity, alpha=0.0001, max_iter=1000, solver=adam, score=0.865, total=  16.3s
# [CV] activation=identity, alpha=0.001, max_iter=1000, solver=lbfgs ...
# [CV]  activation=identity, alpha=0.001, max_iter=1000, solver=lbfgs, score=0.850, total=   1.0s
# [CV] activation=identity, alpha=0.001, max_iter=1000, solver=lbfgs ...
# [CV]  activation=identity, alpha=0.001, max_iter=1000, solver=lbfgs, score=0.805, total=   1.0s
# [CV] activation=identity, alpha=0.001, max_iter=1000, solver=lbfgs ...
# [CV]  activation=identity, alpha=0.001, max_iter=1000, solver=lbfgs, score=0.810, total=   0.9s
# [CV] activation=identity, alpha=0.001, max_iter=1000, solver=lbfgs ...
# [CV]  activation=identity, alpha=0.001, max_iter=1000, solver=lbfgs, score=0.833, total=   0.9s
# [CV] activation=identity, alpha=0.001, max_iter=1000, solver=lbfgs ...
# [CV]  activation=identity, alpha=0.001, max_iter=1000, solver=lbfgs, score=0.885, total=   0.9s
# [CV] activation=identity, alpha=0.001, max_iter=1000, solver=sgd .....
# [CV]  activation=identity, alpha=0.0001, max_iter=1000, solver=adam, score=0.853, total=  16.0s
# [CV] activation=identity, alpha=0.001, max_iter=1000, solver=sgd .....
# [CV]  activation=identity, alpha=0.0001, max_iter=1000, solver=adam, score=0.895, total=  17.4s
# [CV] activation=identity, alpha=0.001, max_iter=1000, solver=sgd .....
# [CV]  activation=identity, alpha=0.0001, max_iter=1000, solver=sgd, score=0.815, total= 1.2min
# [CV] activation=identity, alpha=0.001, max_iter=1000, solver=sgd .....
# [CV]  activation=identity, alpha=0.0001, max_iter=1000, solver=sgd, score=0.850, total= 1.1min
# [CV] activation=identity, alpha=0.001, max_iter=1000, solver=sgd .....
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  1.2min
# [CV]  activation=identity, alpha=0.0001, max_iter=1000, solver=sgd, score=0.875, total= 1.2min
# [CV] activation=identity, alpha=0.001, max_iter=1000, solver=adam ....
# [CV]  activation=identity, alpha=0.0001, max_iter=1000, solver=sgd, score=0.830, total= 1.3min
# [CV] activation=identity, alpha=0.001, max_iter=1000, solver=adam ....
# [CV]  activation=identity, alpha=0.0001, max_iter=1000, solver=sgd, score=0.900, total= 1.3min
# [CV] activation=identity, alpha=0.001, max_iter=1000, solver=adam ....
# [CV]  activation=identity, alpha=0.001, max_iter=1000, solver=adam, score=0.858, total=  16.8s
# [CV] activation=identity, alpha=0.001, max_iter=1000, solver=adam ....
# [CV]  activation=identity, alpha=0.001, max_iter=1000, solver=adam, score=0.812, total=  17.8s
# [CV] activation=identity, alpha=0.001, max_iter=1000, solver=adam ....
# [CV]  activation=identity, alpha=0.001, max_iter=1000, solver=adam, score=0.818, total=  16.6s
# [CV] activation=identity, alpha=0.01, max_iter=1000, solver=lbfgs ....
# [CV]  activation=identity, alpha=0.001, max_iter=1000, solver=sgd, score=0.870, total= 1.2min
# [CV] activation=identity, alpha=0.01, max_iter=1000, solver=lbfgs ....
# [CV]  activation=identity, alpha=0.01, max_iter=1000, solver=lbfgs, score=0.865, total=   1.2s
# [CV] activation=identity, alpha=0.01, max_iter=1000, solver=lbfgs ....
# [CV]  activation=identity, alpha=0.01, max_iter=1000, solver=lbfgs, score=0.812, total=   1.1s
# [CV] activation=identity, alpha=0.01, max_iter=1000, solver=lbfgs ....
# [CV]  activation=identity, alpha=0.01, max_iter=1000, solver=lbfgs, score=0.825, total=   1.2s
# [CV] activation=identity, alpha=0.01, max_iter=1000, solver=lbfgs ....
# [CV]  activation=identity, alpha=0.01, max_iter=1000, solver=lbfgs, score=0.828, total=   1.1s
# [CV] activation=identity, alpha=0.01, max_iter=1000, solver=sgd ......
# [CV]  activation=identity, alpha=0.01, max_iter=1000, solver=lbfgs, score=0.897, total=   1.0s
# [CV] activation=identity, alpha=0.01, max_iter=1000, solver=sgd ......
# [CV]  activation=identity, alpha=0.001, max_iter=1000, solver=sgd, score=0.830, total= 1.2min
# [CV] activation=identity, alpha=0.01, max_iter=1000, solver=sgd ......
# [CV]  activation=identity, alpha=0.001, max_iter=1000, solver=adam, score=0.855, total=  17.7s
# [CV] activation=identity, alpha=0.01, max_iter=1000, solver=sgd ......
# [CV]  activation=identity, alpha=0.001, max_iter=1000, solver=sgd, score=0.843, total= 1.2min
# [CV] activation=identity, alpha=0.01, max_iter=1000, solver=sgd ......
# [CV]  activation=identity, alpha=0.001, max_iter=1000, solver=adam, score=0.890, total=  18.7s
# [CV] activation=identity, alpha=0.01, max_iter=1000, solver=adam .....
# [CV]  activation=identity, alpha=0.01, max_iter=1000, solver=adam, score=0.868, total=  15.6s
# [CV] activation=identity, alpha=0.01, max_iter=1000, solver=adam .....
# [CV]  activation=identity, alpha=0.001, max_iter=1000, solver=sgd, score=0.845, total= 1.2min
# [CV] activation=identity, alpha=0.01, max_iter=1000, solver=adam .....
# [CV]  activation=identity, alpha=0.01, max_iter=1000, solver=adam, score=0.820, total=  16.2s
# [CV] activation=identity, alpha=0.01, max_iter=1000, solver=adam .....
# [CV]  activation=identity, alpha=0.001, max_iter=1000, solver=sgd, score=0.907, total= 1.4min
# [CV] activation=identity, alpha=0.01, max_iter=1000, solver=adam .....
# [CV]  activation=identity, alpha=0.01, max_iter=1000, solver=adam, score=0.825, total=  15.0s
# [CV] activation=identity, alpha=0.1, max_iter=1000, solver=lbfgs .....
# [CV]  activation=identity, alpha=0.1, max_iter=1000, solver=lbfgs, score=0.877, total=   1.0s
# [CV] activation=identity, alpha=0.1, max_iter=1000, solver=lbfgs .....
# [CV]  activation=identity, alpha=0.1, max_iter=1000, solver=lbfgs, score=0.805, total=   1.6s
# [CV] activation=identity, alpha=0.1, max_iter=1000, solver=lbfgs .....
# [CV]  activation=identity, alpha=0.1, max_iter=1000, solver=lbfgs, score=0.825, total=   0.9s
# [CV] activation=identity, alpha=0.1, max_iter=1000, solver=lbfgs .....
# [CV]  activation=identity, alpha=0.1, max_iter=1000, solver=lbfgs, score=0.845, total=   1.3s
# [CV] activation=identity, alpha=0.1, max_iter=1000, solver=lbfgs .....
# [CV]  activation=identity, alpha=0.1, max_iter=1000, solver=lbfgs, score=0.902, total=   1.3s
# [CV] activation=identity, alpha=0.1, max_iter=1000, solver=sgd .......
# [CV]  activation=identity, alpha=0.01, max_iter=1000, solver=adam, score=0.853, total=  18.2s
# [CV] activation=identity, alpha=0.1, max_iter=1000, solver=sgd .......
# [CV]  activation=identity, alpha=0.01, max_iter=1000, solver=adam, score=0.890, total=  18.5s
# [CV] activation=identity, alpha=0.1, max_iter=1000, solver=sgd .......
# [CV]  activation=identity, alpha=0.01, max_iter=1000, solver=sgd, score=0.873, total= 1.2min
# [CV] activation=identity, alpha=0.1, max_iter=1000, solver=sgd .......
# [CV]  activation=identity, alpha=0.01, max_iter=1000, solver=sgd, score=0.828, total= 1.2min
# [CV] activation=identity, alpha=0.1, max_iter=1000, solver=sgd .......
# [CV]  activation=identity, alpha=0.01, max_iter=1000, solver=sgd, score=0.848, total= 1.2min
# [CV] activation=identity, alpha=0.1, max_iter=1000, solver=adam ......
# [CV]  activation=identity, alpha=0.01, max_iter=1000, solver=sgd, score=0.850, total= 1.2min
# [CV] activation=identity, alpha=0.1, max_iter=1000, solver=adam ......
# [CV]  activation=identity, alpha=0.01, max_iter=1000, solver=sgd, score=0.907, total= 1.4min
# [CV] activation=identity, alpha=0.1, max_iter=1000, solver=adam ......
# [CV]  activation=identity, alpha=0.1, max_iter=1000, solver=adam, score=0.868, total=  37.5s
# [CV] activation=identity, alpha=0.1, max_iter=1000, solver=adam ......
# [CV]  activation=identity, alpha=0.1, max_iter=1000, solver=adam, score=0.823, total=  38.3s
# [CV] activation=identity, alpha=0.1, max_iter=1000, solver=adam ......
# [CV]  activation=identity, alpha=0.1, max_iter=1000, solver=adam, score=0.833, total=  39.8s
# [CV] activation=relu, alpha=0.0001, max_iter=1000, solver=lbfgs ......
# [CV]  activation=relu, alpha=0.0001, max_iter=1000, solver=lbfgs, score=0.900, total=   0.9s
# [CV] activation=relu, alpha=0.0001, max_iter=1000, solver=lbfgs ......
# [CV]  activation=relu, alpha=0.0001, max_iter=1000, solver=lbfgs, score=0.875, total=   0.9s
# [CV] activation=relu, alpha=0.0001, max_iter=1000, solver=lbfgs ......
# [CV]  activation=identity, alpha=0.1, max_iter=1000, solver=sgd, score=0.823, total= 1.2min
# [CV] activation=relu, alpha=0.0001, max_iter=1000, solver=lbfgs ......
# [CV]  activation=relu, alpha=0.0001, max_iter=1000, solver=lbfgs, score=0.870, total=   1.0s
# [CV] activation=relu, alpha=0.0001, max_iter=1000, solver=lbfgs ......
# [CV]  activation=relu, alpha=0.0001, max_iter=1000, solver=lbfgs, score=0.873, total=   1.1s
# [CV] activation=relu, alpha=0.0001, max_iter=1000, solver=sgd ........
# [CV]  activation=relu, alpha=0.0001, max_iter=1000, solver=lbfgs, score=0.927, total=   1.1s
# [CV] activation=relu, alpha=0.0001, max_iter=1000, solver=sgd ........
# [CV]  activation=identity, alpha=0.1, max_iter=1000, solver=sgd, score=0.865, total= 1.2min
# [CV] activation=relu, alpha=0.0001, max_iter=1000, solver=sgd ........
# [CV]  activation=identity, alpha=0.1, max_iter=1000, solver=sgd, score=0.835, total= 1.2min
# [CV] activation=relu, alpha=0.0001, max_iter=1000, solver=sgd ........
# [CV]  activation=identity, alpha=0.1, max_iter=1000, solver=sgd, score=0.845, total= 1.2min
# [CV] activation=relu, alpha=0.0001, max_iter=1000, solver=sgd ........
# [CV]  activation=identity, alpha=0.1, max_iter=1000, solver=adam, score=0.863, total=  39.6s
# [CV] activation=relu, alpha=0.0001, max_iter=1000, solver=adam .......
# [CV]  activation=identity, alpha=0.1, max_iter=1000, solver=sgd, score=0.905, total= 1.4min
# [CV] activation=relu, alpha=0.0001, max_iter=1000, solver=adam .......
# [CV]  activation=identity, alpha=0.1, max_iter=1000, solver=adam, score=0.897, total=  40.7s
# [CV] activation=relu, alpha=0.0001, max_iter=1000, solver=adam .......
# [CV]  activation=relu, alpha=0.0001, max_iter=1000, solver=adam, score=0.897, total=  14.4s
# [CV] activation=relu, alpha=0.0001, max_iter=1000, solver=adam .......
# [CV]  activation=relu, alpha=0.0001, max_iter=1000, solver=adam, score=0.863, total=  13.8s
# [CV] activation=relu, alpha=0.0001, max_iter=1000, solver=adam .......
# [CV]  activation=relu, alpha=0.0001, max_iter=1000, solver=adam, score=0.863, total=  13.9s
# [CV] activation=relu, alpha=0.001, max_iter=1000, solver=lbfgs .......
# [CV]  activation=relu, alpha=0.001, max_iter=1000, solver=lbfgs, score=0.892, total=   1.0s
# [CV] activation=relu, alpha=0.001, max_iter=1000, solver=lbfgs .......
# [CV]  activation=relu, alpha=0.001, max_iter=1000, solver=lbfgs, score=0.860, total=   1.0s
# [CV] activation=relu, alpha=0.001, max_iter=1000, solver=lbfgs .......
# [CV]  activation=relu, alpha=0.001, max_iter=1000, solver=lbfgs, score=0.880, total=   1.1s
# [CV] activation=relu, alpha=0.001, max_iter=1000, solver=lbfgs .......
# [CV]  activation=relu, alpha=0.001, max_iter=1000, solver=lbfgs, score=0.880, total=   1.0s
# [CV] activation=relu, alpha=0.001, max_iter=1000, solver=lbfgs .......
# [CV]  activation=relu, alpha=0.001, max_iter=1000, solver=lbfgs, score=0.925, total=   0.9s
# [CV] activation=relu, alpha=0.001, max_iter=1000, solver=sgd .........
# [CV]  activation=relu, alpha=0.0001, max_iter=1000, solver=adam, score=0.900, total=  15.7s
# [CV] activation=relu, alpha=0.001, max_iter=1000, solver=sgd .........
# [CV]  activation=relu, alpha=0.0001, max_iter=1000, solver=adam, score=0.920, total=  16.4s
# [CV] activation=relu, alpha=0.001, max_iter=1000, solver=sgd .........
# [CV]  activation=relu, alpha=0.0001, max_iter=1000, solver=sgd, score=0.855, total= 1.2min
# [CV] activation=relu, alpha=0.001, max_iter=1000, solver=sgd .........
# [CV]  activation=relu, alpha=0.0001, max_iter=1000, solver=sgd, score=0.900, total= 1.2min
# [CV] activation=relu, alpha=0.001, max_iter=1000, solver=sgd .........
# [CV]  activation=relu, alpha=0.0001, max_iter=1000, solver=sgd, score=0.877, total= 1.2min
# [CV] activation=relu, alpha=0.001, max_iter=1000, solver=adam ........
# [CV]  activation=relu, alpha=0.0001, max_iter=1000, solver=sgd, score=0.875, total= 1.2min
# [CV] activation=relu, alpha=0.001, max_iter=1000, solver=adam ........
# [CV]  activation=relu, alpha=0.0001, max_iter=1000, solver=sgd, score=0.930, total= 1.3min
# [CV] activation=relu, alpha=0.001, max_iter=1000, solver=adam ........
# [CV]  activation=relu, alpha=0.001, max_iter=1000, solver=adam, score=0.897, total=  13.6s
# [CV] activation=relu, alpha=0.001, max_iter=1000, solver=adam ........
# [CV]  activation=relu, alpha=0.001, max_iter=1000, solver=adam, score=0.868, total=  14.4s
# [CV] activation=relu, alpha=0.001, max_iter=1000, solver=adam ........
# [CV]  activation=relu, alpha=0.001, max_iter=1000, solver=adam, score=0.863, total=  14.0s
# [CV] activation=relu, alpha=0.01, max_iter=1000, solver=lbfgs ........
# [CV]  activation=relu, alpha=0.01, max_iter=1000, solver=lbfgs, score=0.890, total=   0.9s
# [CV] activation=relu, alpha=0.01, max_iter=1000, solver=lbfgs ........
# [CV]  activation=relu, alpha=0.01, max_iter=1000, solver=lbfgs, score=0.863, total=   1.0s
# [CV] activation=relu, alpha=0.01, max_iter=1000, solver=lbfgs ........
# [CV]  activation=relu, alpha=0.01, max_iter=1000, solver=lbfgs, score=0.868, total=   0.9s
# [CV] activation=relu, alpha=0.01, max_iter=1000, solver=lbfgs ........
# [CV]  activation=relu, alpha=0.01, max_iter=1000, solver=lbfgs, score=0.880, total=   0.9s
# [CV] activation=relu, alpha=0.01, max_iter=1000, solver=lbfgs ........
# [CV]  activation=relu, alpha=0.001, max_iter=1000, solver=adam, score=0.897, total=  16.1s
# [CV] activation=relu, alpha=0.01, max_iter=1000, solver=sgd ..........
# [CV]  activation=relu, alpha=0.01, max_iter=1000, solver=lbfgs, score=0.920, total=   1.0s
# [CV] activation=relu, alpha=0.01, max_iter=1000, solver=sgd ..........
# [CV]  activation=relu, alpha=0.001, max_iter=1000, solver=adam, score=0.917, total=  15.9s
# [CV] activation=relu, alpha=0.01, max_iter=1000, solver=sgd ..........
# [CV]  activation=relu, alpha=0.001, max_iter=1000, solver=sgd, score=0.892, total= 1.3min
# [CV] activation=relu, alpha=0.01, max_iter=1000, solver=sgd ..........
# [CV]  activation=relu, alpha=0.001, max_iter=1000, solver=sgd, score=0.855, total= 1.2min
# [CV] activation=relu, alpha=0.01, max_iter=1000, solver=sgd ..........
# [CV]  activation=relu, alpha=0.001, max_iter=1000, solver=sgd, score=0.863, total= 1.2min
# [CV] activation=relu, alpha=0.01, max_iter=1000, solver=adam .........
# [CV]  activation=relu, alpha=0.01, max_iter=1000, solver=adam, score=0.895, total=  13.9s
# [CV] activation=relu, alpha=0.01, max_iter=1000, solver=adam .........
# [CV]  activation=relu, alpha=0.001, max_iter=1000, solver=sgd, score=0.887, total= 1.1min
# [CV] activation=relu, alpha=0.01, max_iter=1000, solver=adam .........
# [CV]  activation=relu, alpha=0.01, max_iter=1000, solver=adam, score=0.882, total=  13.2s
# [CV] activation=relu, alpha=0.01, max_iter=1000, solver=adam .........
# [CV]  activation=relu, alpha=0.001, max_iter=1000, solver=sgd, score=0.912, total= 1.3min
# [CV] activation=relu, alpha=0.01, max_iter=1000, solver=adam .........
# [CV]  activation=relu, alpha=0.01, max_iter=1000, solver=adam, score=0.873, total=  13.0s
# [CV] activation=relu, alpha=0.1, max_iter=1000, solver=lbfgs .........
# [CV]  activation=relu, alpha=0.1, max_iter=1000, solver=lbfgs, score=0.900, total=   0.9s
# [CV] activation=relu, alpha=0.1, max_iter=1000, solver=lbfgs .........
# [CV]  activation=relu, alpha=0.1, max_iter=1000, solver=lbfgs, score=0.877, total=   1.3s
# [CV] activation=relu, alpha=0.1, max_iter=1000, solver=lbfgs .........
# [CV]  activation=relu, alpha=0.1, max_iter=1000, solver=lbfgs, score=0.863, total=   1.5s
# [CV] activation=relu, alpha=0.1, max_iter=1000, solver=lbfgs .........
# [CV]  activation=relu, alpha=0.1, max_iter=1000, solver=lbfgs, score=0.892, total=   1.5s
# [CV] activation=relu, alpha=0.1, max_iter=1000, solver=lbfgs .........
# [CV]  activation=relu, alpha=0.1, max_iter=1000, solver=lbfgs, score=0.922, total=   1.5s
# [CV] activation=relu, alpha=0.1, max_iter=1000, solver=sgd ...........
# [CV]  activation=relu, alpha=0.01, max_iter=1000, solver=adam, score=0.907, total=  15.6s
# [CV] activation=relu, alpha=0.1, max_iter=1000, solver=sgd ...........
# [CV]  activation=relu, alpha=0.01, max_iter=1000, solver=adam, score=0.920, total=  15.9s
# [CV] activation=relu, alpha=0.1, max_iter=1000, solver=sgd ...........
# [CV]  activation=relu, alpha=0.01, max_iter=1000, solver=sgd, score=0.880, total= 1.2min
# [CV] activation=relu, alpha=0.1, max_iter=1000, solver=sgd ...........
# [CV]  activation=relu, alpha=0.01, max_iter=1000, solver=sgd, score=0.895, total= 1.2min
# [CV] activation=relu, alpha=0.1, max_iter=1000, solver=sgd ...........
# [CV]  activation=relu, alpha=0.01, max_iter=1000, solver=sgd, score=0.850, total= 1.2min
# [CV] activation=relu, alpha=0.1, max_iter=1000, solver=adam ..........
# [CV]  activation=relu, alpha=0.01, max_iter=1000, solver=sgd, score=0.890, total= 1.2min
# [CV] activation=relu, alpha=0.1, max_iter=1000, solver=adam ..........
# [CV]  activation=relu, alpha=0.01, max_iter=1000, solver=sgd, score=0.920, total= 1.2min
# [CV] activation=relu, alpha=0.1, max_iter=1000, solver=adam ..........
# [CV]  activation=relu, alpha=0.1, max_iter=1000, solver=adam, score=0.912, total=  33.9s
# [CV] activation=relu, alpha=0.1, max_iter=1000, solver=adam ..........
# [CV]  activation=relu, alpha=0.1, max_iter=1000, solver=adam, score=0.885, total=  35.1s
# [CV] activation=relu, alpha=0.1, max_iter=1000, solver=adam ..........
# [CV]  activation=relu, alpha=0.1, max_iter=1000, solver=sgd, score=0.897, total= 1.1min
# [CV]  activation=relu, alpha=0.1, max_iter=1000, solver=adam, score=0.875, total=  34.3s
# [CV]  activation=relu, alpha=0.1, max_iter=1000, solver=sgd, score=0.850, total= 1.1min
# [CV]  activation=relu, alpha=0.1, max_iter=1000, solver=sgd, score=0.860, total= 1.1min
# [CV]  activation=relu, alpha=0.1, max_iter=1000, solver=sgd, score=0.897, total= 1.1min
# [CV]  activation=relu, alpha=0.1, max_iter=1000, solver=adam, score=0.910, total=  25.2s
# [CV]  activation=relu, alpha=0.1, max_iter=1000, solver=sgd, score=0.927, total= 1.1min
# [CV]  activation=relu, alpha=0.1, max_iter=1000, solver=adam, score=0.930, total=  20.3s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:  8.0min finished

# %%
with parallel_backend('threading'):    
    nn_learning_curve_results["train_sizes"], nn_learning_curve_results["train_scores"], nn_learning_curve_results["test_scores"], nn_learning_curve_results["fit_times"], _ = learning_curve(nn_grid_search.best_estimator_, X, y, cv=cross_validation, verbose=3, n_jobs=n_jobs, train_sizes=train_sizes, return_times=True)

# %%
with parallel_backend('threading'):
    nn_validation_curve_results["train_scores"], nn_validation_curve_results["test_scores"] = validation_curve(nn_grid_search.best_estimator_, X=Validation_X, y=validation_y, n_jobs=n_jobs, verbose=3, cv=cross_validation, param_name="batch_size", param_range=[i for i in range(1, 50)])
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [CV] batch_size=1 ....................................................[CV] batch_size=2 ....................................................
# [CV] batch_size=3 ....................................................
#
# [CV] batch_size=4 ....................................................
# [CV] batch_size=5 ....................................................
# [CV] batch_size=6 ....................................................
# [CV] batch_size=7 ....................................................[CV] batch_size=8 ....................................................
#
# [CV] .... batch_size=6, score=(train=1.000, test=0.787), total=  50.4s
# [CV] batch_size=9 ....................................................
# [CV] .... batch_size=8, score=(train=1.000, test=0.750), total=  54.1s
# [CV] batch_size=10 ...................................................
# [CV] .... batch_size=4, score=(train=1.000, test=0.787), total=  56.8s
# [CV] batch_size=11 ...................................................
# [CV] .... batch_size=7, score=(train=1.000, test=0.800), total=  57.2s
# [CV] batch_size=12 ...................................................
# [CV] .... batch_size=5, score=(train=1.000, test=0.838), total= 1.1min
# [CV] batch_size=13 ...................................................
# [CV] .... batch_size=2, score=(train=0.988, test=0.812), total= 1.4min
# [CV] batch_size=14 ...................................................
# [CV] ... batch_size=11, score=(train=1.000, test=0.800), total=  38.4s
# [CV] batch_size=15 ...................................................
# [CV] ... batch_size=10, score=(train=1.000, test=0.800), total=  50.5s
# [CV] batch_size=16 ...................................................
# [CV] .... batch_size=9, score=(train=1.000, test=0.787), total=  54.7s
# [CV] batch_size=17 ...................................................
# [CV] ... batch_size=12, score=(train=1.000, test=0.800), total=  48.0s
# [CV] batch_size=18 ...................................................
# [CV] ... batch_size=13, score=(train=1.000, test=0.800), total=  57.4s
# [CV] batch_size=19 ...................................................
# [CV] .... batch_size=3, score=(train=1.000, test=0.825), total= 2.1min
# [CV] batch_size=20 ...................................................
# [CV] ... batch_size=14, score=(train=1.000, test=0.775), total=  47.9s
# [CV] batch_size=21 ...................................................
# [CV] ... batch_size=18, score=(train=1.000, test=0.812), total=  41.7s
# [CV] batch_size=22 ...................................................
# [CV] ... batch_size=17, score=(train=1.000, test=0.812), total=  42.8s
# [CV] batch_size=23 ...................................................
# [CV] ... batch_size=15, score=(train=0.997, test=0.787), total=  54.2s
# [CV] batch_size=24 ...................................................
# [CV] ... batch_size=16, score=(train=1.000, test=0.787), total=  53.1s
# [CV] batch_size=25 ...................................................
# [CV] ... batch_size=20, score=(train=1.000, test=0.812), total=  47.8s
# [CV] batch_size=26 ...................................................
# [CV] ... batch_size=21, score=(train=1.000, test=0.812), total=  41.9s
# [CV] batch_size=27 ...................................................
# [CV] ... batch_size=19, score=(train=1.000, test=0.812), total=  54.4s
# [CV] batch_size=28 ...................................................
# [CV] ... batch_size=22, score=(train=1.000, test=0.825), total=  43.3s
# [CV] batch_size=29 ...................................................
# [CV] ... batch_size=25, score=(train=1.000, test=0.800), total=  38.4s
# [CV] batch_size=30 ...................................................
# [CV] ... batch_size=24, score=(train=1.000, test=0.812), total=  47.2s
# [CV] batch_size=31 ...................................................
# [CV] ... batch_size=23, score=(train=1.000, test=0.800), total=  52.1s
# [CV] batch_size=32 ...................................................
# [CV] ... batch_size=26, score=(train=1.000, test=0.825), total=  42.8s
# [CV] batch_size=33 ...................................................
# [CV] ... batch_size=29, score=(train=1.000, test=0.800), total=  25.9s
# [CV] batch_size=34 ...................................................
# [CV] ... batch_size=28, score=(train=1.000, test=0.800), total=  38.6s
# [CV] batch_size=35 ...................................................
# [CV] ... batch_size=27, score=(train=1.000, test=0.825), total=  45.5s
# [CV] batch_size=36 ...................................................
# [CV] ... batch_size=32, score=(train=1.000, test=0.825), total=  32.6s
# [CV] batch_size=37 ...................................................
# [CV] ... batch_size=30, score=(train=1.000, test=0.812), total=  38.3s
# [CV] batch_size=38 ...................................................
# [CV] ... batch_size=31, score=(train=1.000, test=0.825), total=  42.8s
# [CV] batch_size=39 ...................................................
# [CV] ... batch_size=34, score=(train=1.000, test=0.812), total=  32.9s
# [CV] batch_size=40 ...................................................
# [CV] ... batch_size=33, score=(train=1.000, test=0.812), total=  36.3s
# [CV] batch_size=41 ...................................................
# [CV] ... batch_size=36, score=(train=1.000, test=0.812), total=  34.0s
# [CV] batch_size=42 ...................................................
# [CV] ... batch_size=35, score=(train=1.000, test=0.787), total=  41.9s
# [CV] batch_size=43 ...................................................
# [CV] ... batch_size=37, score=(train=1.000, test=0.800), total=  33.1s
# [CV] batch_size=44 ...................................................
# [CV] ... batch_size=38, score=(train=1.000, test=0.812), total=  32.5s
# [CV] batch_size=45 ...................................................
# [CV] ... batch_size=39, score=(train=1.000, test=0.812), total=  33.1s
# [CV] batch_size=46 ...................................................
# [CV] ... batch_size=40, score=(train=1.000, test=0.825), total=  29.4s
# [CV] batch_size=47 ...................................................
# [CV] ... batch_size=41, score=(train=1.000, test=0.825), total=  30.4s
# [CV] batch_size=48 ...................................................
# [CV] ... batch_size=42, score=(train=1.000, test=0.800), total=  29.1s
# [CV] batch_size=49 ...................................................
# [CV] ... batch_size=43, score=(train=1.000, test=0.825), total=  29.3s
# [CV] batch_size=1 ....................................................
# [CV] ... batch_size=44, score=(train=1.000, test=0.787), total=  28.0s
# [CV] batch_size=2 ....................................................
# [CV] ... batch_size=45, score=(train=1.000, test=0.812), total=  31.9s
# [CV] batch_size=3 ....................................................
# [CV] .... batch_size=1, score=(train=0.981, test=0.787), total= 5.0min
# [CV] batch_size=4 ....................................................
# [CV] ... batch_size=46, score=(train=1.000, test=0.812), total=  28.3s
# [CV] batch_size=5 ....................................................
# [CV] ... batch_size=47, score=(train=1.000, test=0.812), total=  28.2s
# [CV] batch_size=6 ....................................................
# [CV] ... batch_size=48, score=(train=1.000, test=0.825), total=  29.2s
# [CV] batch_size=7 ....................................................
# [CV] ... batch_size=49, score=(train=1.000, test=0.812), total=  30.1s
# [CV] batch_size=8 ....................................................
# [CV] .... batch_size=5, score=(train=1.000, test=0.900), total=  40.4s
# [CV] batch_size=9 ....................................................
# [CV] .... batch_size=4, score=(train=1.000, test=0.887), total=  42.8s
# [CV] batch_size=10 ...................................................
# [CV] .... batch_size=6, score=(train=1.000, test=0.887), total=  47.5s
# [CV] batch_size=11 ...................................................
# [CV] .... batch_size=8, score=(train=1.000, test=0.912), total=  44.6s
# [CV] batch_size=12 ...................................................
# [CV] .... batch_size=3, score=(train=1.000, test=0.850), total=  59.7s
# [CV] batch_size=13 ...................................................
# [CV] .... batch_size=7, score=(train=1.000, test=0.887), total=  50.9s
# [CV] batch_size=14 ...................................................
# [CV] .... batch_size=9, score=(train=1.000, test=0.900), total=  43.0s
# [CV] batch_size=15 ...................................................
# [CV] ... batch_size=10, score=(train=1.000, test=0.912), total=  50.4s
# [CV] batch_size=16 ...................................................
# [CV] ... batch_size=11, score=(train=1.000, test=0.900), total=  51.9s
# [CV] batch_size=17 ...................................................
# [CV] ... batch_size=14, score=(train=1.000, test=0.887), total=  47.9s
# [CV] batch_size=18 ...................................................
# [CV] ... batch_size=12, score=(train=0.997, test=0.887), total=  54.4s
# [CV] batch_size=19 ...................................................
# [CV] ... batch_size=13, score=(train=1.000, test=0.887), total= 1.0min
# [CV] batch_size=20 ...................................................
# [CV] ... batch_size=15, score=(train=1.000, test=0.887), total=  36.4s
# [CV] batch_size=21 ...................................................
# [CV] .... batch_size=2, score=(train=0.997, test=0.875), total= 2.2min
# [CV] batch_size=22 ...................................................
# [CV] ... batch_size=16, score=(train=1.000, test=0.887), total=  52.6s
# [CV] batch_size=23 ...................................................
# [CV] ... batch_size=17, score=(train=1.000, test=0.887), total=  53.7s
# [CV] batch_size=24 ...................................................
# [CV] ... batch_size=20, score=(train=1.000, test=0.900), total=  42.4s
# [CV] batch_size=25 ...................................................
# [CV] ... batch_size=18, score=(train=1.000, test=0.887), total=  51.4s
# [CV] batch_size=26 ...................................................
# [CV] ... batch_size=19, score=(train=1.000, test=0.887), total=  51.3s
# [CV] batch_size=27 ...................................................
# [CV] ... batch_size=22, score=(train=1.000, test=0.912), total=  41.8s
# [CV] batch_size=28 ...................................................
# [CV] ... batch_size=21, score=(train=1.000, test=0.887), total=  54.4s
# [CV] batch_size=29 ...................................................
# [CV] ... batch_size=23, score=(train=1.000, test=0.900), total=  43.2s
# [CV] batch_size=30 ...................................................
# [CV] ... batch_size=29, score=(train=1.000, test=0.887), total=  25.1s
# [CV] batch_size=31 ...................................................
# [CV] ... batch_size=27, score=(train=1.000, test=0.900), total=  39.8s
# [CV] batch_size=32 ...................................................
# [CV] ... batch_size=26, score=(train=1.000, test=0.900), total=  41.2s
# [CV] batch_size=33 ...................................................
# [CV] ... batch_size=25, score=(train=1.000, test=0.912), total=  44.2s
# [CV] batch_size=34 ...................................................
# [CV] ... batch_size=24, score=(train=1.000, test=0.887), total=  49.5s
# [CV] batch_size=35 ...................................................
# [CV] ... batch_size=28, score=(train=1.000, test=0.912), total=  41.1s
# [CV] batch_size=36 ...................................................
# [CV] ... batch_size=30, score=(train=1.000, test=0.900), total=  39.0s
# [CV] batch_size=37 ...................................................
# [CV] ... batch_size=33, score=(train=1.000, test=0.900), total=  31.3s
# [CV] batch_size=38 ...................................................
# [CV] ... batch_size=31, score=(train=1.000, test=0.900), total=  36.6s
# [CV] batch_size=39 ...................................................
# [CV] ... batch_size=34, score=(train=1.000, test=0.912), total=  31.7s
# [CV] batch_size=40 ...................................................
# [CV] ... batch_size=32, score=(train=1.000, test=0.887), total=  35.9s
# [CV] batch_size=41 ...................................................
# [Parallel(n_jobs=-1)]: Done  82 out of 245 | elapsed:  9.0min remaining: 17.9min
# [CV] ... batch_size=36, score=(train=1.000, test=0.900), total=  32.2s
# [CV] batch_size=42 ...................................................
# [CV] ... batch_size=35, score=(train=1.000, test=0.900), total=  35.5s
# [CV] batch_size=43 ...................................................
# [CV] ... batch_size=37, score=(train=1.000, test=0.887), total=  30.0s
# [CV] batch_size=44 ...................................................
# [CV] ... batch_size=40, score=(train=1.000, test=0.912), total=  28.9s
# [CV] batch_size=45 ...................................................
# [CV] ... batch_size=39, score=(train=1.000, test=0.900), total=  30.5s
# [CV] batch_size=46 ...................................................
# [CV] ... batch_size=41, score=(train=1.000, test=0.912), total=  29.0s
# [CV] batch_size=47 ...................................................
# [CV] ... batch_size=38, score=(train=1.000, test=0.912), total=  34.7s
# [CV] batch_size=48 ...................................................
# [CV] ... batch_size=43, score=(train=1.000, test=0.900), total=  28.1s
# [CV] batch_size=49 ...................................................
# [CV] ... batch_size=42, score=(train=1.000, test=0.887), total=  30.5s
# [CV] batch_size=1 ....................................................
# [CV] ... batch_size=44, score=(train=1.000, test=0.912), total=  31.2s
# [CV] batch_size=2 ....................................................
# [CV] ... batch_size=46, score=(train=1.000, test=0.900), total=  27.7s
# [CV] batch_size=3 ....................................................
# [CV] ... batch_size=47, score=(train=1.000, test=0.912), total=  28.8s
# [CV] batch_size=4 ....................................................
# [CV] ... batch_size=48, score=(train=1.000, test=0.887), total=  27.6s
# [CV] batch_size=5 ....................................................
# [CV] ... batch_size=45, score=(train=1.000, test=0.912), total=  31.9s
# [CV] batch_size=6 ....................................................
# [CV] ... batch_size=49, score=(train=1.000, test=0.887), total=  29.9s
# [CV] batch_size=7 ....................................................
# [CV] .... batch_size=6, score=(train=1.000, test=0.900), total=  44.0s
# [CV] batch_size=8 ....................................................
# [CV] .... batch_size=4, score=(train=0.997, test=0.887), total=  46.6s
# [CV] batch_size=9 ....................................................
# [CV] .... batch_size=5, score=(train=1.000, test=0.887), total=  46.8s
# [CV] batch_size=10 ...................................................
# [CV] .... batch_size=3, score=(train=1.000, test=0.875), total=  56.1s
# [CV] batch_size=11 ...................................................
# [CV] .... batch_size=7, score=(train=1.000, test=0.887), total=  59.7s
# [CV] batch_size=12 ...................................................
# [CV] .... batch_size=1, score=(train=0.988, test=0.875), total= 6.3min
# [CV] batch_size=13 ...................................................
# [CV] .... batch_size=9, score=(train=1.000, test=0.875), total=  39.8s
# [CV] batch_size=14 ...................................................
# [CV] ... batch_size=10, score=(train=0.991, test=0.875), total=  42.1s
# [CV] batch_size=15 ...................................................
# [CV] .... batch_size=8, score=(train=1.000, test=0.887), total=  47.9s
# [CV] batch_size=16 ...................................................
# [CV] ... batch_size=11, score=(train=1.000, test=0.887), total=  50.6s
# [CV] batch_size=17 ...................................................
# [CV] ... batch_size=12, score=(train=1.000, test=0.887), total=  40.9s
# [CV] batch_size=18 ...................................................
# [CV] .... batch_size=2, score=(train=0.997, test=0.887), total= 1.9min
# [CV] batch_size=19 ...................................................
# [CV] ... batch_size=13, score=(train=1.000, test=0.887), total=  47.3s
# [CV] batch_size=20 ...................................................
# [CV] ... batch_size=15, score=(train=1.000, test=0.887), total=  41.8s
# [CV] batch_size=21 ...................................................
# [CV] ... batch_size=14, score=(train=1.000, test=0.887), total=  47.7s
# [CV] batch_size=22 ...................................................
# [CV] ... batch_size=16, score=(train=1.000, test=0.887), total=  51.3s
# [CV] batch_size=23 ...................................................
# [CV] ... batch_size=18, score=(train=1.000, test=0.887), total=  46.5s
# [CV] batch_size=24 ...................................................
# [CV] ... batch_size=17, score=(train=1.000, test=0.887), total=  50.1s
# [CV] batch_size=25 ...................................................
# [CV] ... batch_size=19, score=(train=1.000, test=0.887), total=  48.4s
# [CV] batch_size=26 ...................................................
# [CV] ... batch_size=20, score=(train=1.000, test=0.887), total=  43.8s
# [CV] batch_size=27 ...................................................
# [CV] ... batch_size=21, score=(train=1.000, test=0.887), total=  45.6s
# [CV] batch_size=28 ...................................................
# [CV] ... batch_size=22, score=(train=1.000, test=0.887), total=  48.7s
# [CV] batch_size=29 ...................................................
# [CV] ... batch_size=24, score=(train=1.000, test=0.887), total=  38.7s
# [CV] batch_size=30 ...................................................
# [CV] ... batch_size=26, score=(train=1.000, test=0.887), total=  38.8s
# [CV] batch_size=31 ...................................................
# [CV] ... batch_size=23, score=(train=1.000, test=0.887), total=  51.1s
# [CV] batch_size=32 ...................................................
# [CV] ... batch_size=25, score=(train=1.000, test=0.887), total=  42.5s
# [CV] batch_size=33 ...................................................
# [CV] ... batch_size=27, score=(train=1.000, test=0.875), total=  39.0s
# [CV] batch_size=34 ...................................................
# [CV] ... batch_size=29, score=(train=1.000, test=0.887), total=  20.7s
# [CV] batch_size=35 ...................................................
# [CV] ... batch_size=28, score=(train=1.000, test=0.887), total=  37.7s
# [CV] batch_size=36 ...................................................
# [CV] .... batch_size=1, score=(train=0.981, test=0.875), total= 4.1min
# [CV] batch_size=37 ...................................................
# [CV] ... batch_size=32, score=(train=1.000, test=0.887), total=  30.6s
# [CV] batch_size=38 ...................................................
# [CV] ... batch_size=31, score=(train=1.000, test=0.887), total=  32.2s
# [CV] batch_size=39 ...................................................
# [CV] ... batch_size=33, score=(train=1.000, test=0.887), total=  30.8s
# [CV] batch_size=40 ...................................................
# [CV] ... batch_size=30, score=(train=1.000, test=0.887), total=  37.0s
# [CV] batch_size=41 ...................................................
# [CV] ... batch_size=34, score=(train=1.000, test=0.887), total=  33.4s
# [CV] batch_size=42 ...................................................
# [CV] ... batch_size=35, score=(train=1.000, test=0.887), total=  34.7s
# [CV] batch_size=43 ...................................................
# [CV] ... batch_size=36, score=(train=1.000, test=0.887), total=  31.4s
# [CV] batch_size=44 ...................................................
# [CV] ... batch_size=37, score=(train=1.000, test=0.875), total=  30.4s
# [CV] batch_size=45 ...................................................
# [CV] ... batch_size=40, score=(train=1.000, test=0.875), total=  28.5s
# [CV] batch_size=46 ...................................................
# [CV] ... batch_size=38, score=(train=1.000, test=0.887), total=  31.8s
# [CV] batch_size=47 ...................................................
# [CV] ... batch_size=41, score=(train=1.000, test=0.887), total=  28.9s
# [CV] batch_size=48 ...................................................
# [CV] ... batch_size=39, score=(train=1.000, test=0.887), total=  34.4s
# [CV] batch_size=49 ...................................................
# [CV] ... batch_size=42, score=(train=1.000, test=0.887), total=  29.7s
# [CV] batch_size=1 ....................................................
# [CV] ... batch_size=43, score=(train=1.000, test=0.887), total=  27.8s
# [CV] batch_size=2 ....................................................
# [CV] ... batch_size=44, score=(train=1.000, test=0.887), total=  30.8s
# [CV] batch_size=3 ....................................................
# [CV] ... batch_size=45, score=(train=1.000, test=0.887), total=  27.9s
# [CV] batch_size=4 ....................................................
# [CV] ... batch_size=46, score=(train=1.000, test=0.887), total=  28.0s
# [CV] batch_size=5 ....................................................
# [CV] ... batch_size=47, score=(train=1.000, test=0.900), total=  28.1s
# [CV] batch_size=6 ....................................................
# [CV] ... batch_size=48, score=(train=1.000, test=0.900), total=  29.5s
# [CV] batch_size=7 ....................................................
# [CV] ... batch_size=49, score=(train=1.000, test=0.887), total=  29.5s
# [CV] batch_size=8 ....................................................
# [CV] .... batch_size=3, score=(train=0.997, test=0.850), total=  43.2s
# [CV] batch_size=9 ....................................................
# [CV] .... batch_size=4, score=(train=1.000, test=0.863), total=  45.2s
# [CV] batch_size=10 ...................................................
# [CV] .... batch_size=8, score=(train=1.000, test=0.838), total=  42.9s
# [CV] batch_size=11 ...................................................
# [CV] .... batch_size=7, score=(train=1.000, test=0.863), total=  51.7s
# [CV] batch_size=12 ...................................................
# [CV] .... batch_size=6, score=(train=1.000, test=0.863), total= 1.0min
# [CV] batch_size=13 ...................................................
# [CV] .... batch_size=9, score=(train=1.000, test=0.863), total=  38.5s
# [CV] batch_size=14 ...................................................
# [CV] .... batch_size=5, score=(train=1.000, test=0.887), total= 1.3min
# [CV] batch_size=15 ...................................................
# [CV] ... batch_size=10, score=(train=1.000, test=0.887), total=  44.5s
# [CV] batch_size=16 ...................................................
# [CV] ... batch_size=11, score=(train=1.000, test=0.838), total=  38.9s
# [CV] batch_size=17 ...................................................
# [CV] ... batch_size=12, score=(train=1.000, test=0.825), total=  50.0s
# [CV] batch_size=18 ...................................................
# [CV] ... batch_size=13, score=(train=1.000, test=0.850), total=  44.9s
# [CV] batch_size=19 ...................................................
# [CV] ... batch_size=15, score=(train=1.000, test=0.850), total=  45.1s
# [CV] batch_size=20 ...................................................
# [CV] ... batch_size=14, score=(train=1.000, test=0.825), total=  51.3s
# [CV] batch_size=21 ...................................................
# [CV] ... batch_size=17, score=(train=1.000, test=0.838), total=  50.1s
# [CV] batch_size=22 ...................................................
# [CV] ... batch_size=16, score=(train=1.000, test=0.850), total=  56.4s
# [CV] batch_size=23 ...................................................
# [CV] ... batch_size=18, score=(train=1.000, test=0.875), total=  57.4s
# [CV] batch_size=24 ...................................................
# [CV] ... batch_size=19, score=(train=1.000, test=0.825), total=  56.6s
# [CV] batch_size=25 ...................................................
# [Parallel(n_jobs=-1)]: Done 164 out of 245 | elapsed: 17.4min remaining:  8.6min
# [CV] .... batch_size=2, score=(train=0.997, test=0.825), total= 3.1min
# [CV] batch_size=26 ...................................................
# [CV] ... batch_size=21, score=(train=1.000, test=0.875), total=  49.0s
# [CV] batch_size=27 ...................................................
# [CV] ... batch_size=20, score=(train=1.000, test=0.825), total=  51.1s
# [CV] batch_size=28 ...................................................
# [CV] ... batch_size=22, score=(train=1.000, test=0.863), total=  42.5s
# [CV] batch_size=29 ...................................................
# [CV] ... batch_size=23, score=(train=1.000, test=0.863), total=  43.5s
# [CV] batch_size=30 ...................................................
# [CV] ... batch_size=24, score=(train=1.000, test=0.850), total=  41.0s
# [CV] batch_size=31 ...................................................
# [CV] ... batch_size=29, score=(train=1.000, test=0.850), total=  24.5s
# [CV] batch_size=32 ...................................................
# [CV] ... batch_size=26, score=(train=1.000, test=0.863), total=  41.6s
# [CV] batch_size=33 ...................................................
# [CV] ... batch_size=28, score=(train=1.000, test=0.875), total=  33.5s
# [CV] batch_size=34 ...................................................
# [CV] ... batch_size=25, score=(train=1.000, test=0.850), total=  44.0s
# [CV] batch_size=35 ...................................................
# [CV] ... batch_size=27, score=(train=1.000, test=0.863), total=  37.0s
# [CV] batch_size=36 ...................................................
# [CV] ... batch_size=30, score=(train=1.000, test=0.838), total=  40.1s
# [CV] batch_size=37 ...................................................
# [CV] ... batch_size=32, score=(train=1.000, test=0.850), total=  30.3s
# [CV] batch_size=38 ...................................................
# [CV] ... batch_size=31, score=(train=1.000, test=0.838), total=  35.4s
# [CV] batch_size=39 ...................................................
# [CV] ... batch_size=33, score=(train=1.000, test=0.838), total=  32.8s
# [CV] batch_size=40 ...................................................
# [CV] ... batch_size=36, score=(train=1.000, test=0.863), total=  30.2s
# [CV] batch_size=41 ...................................................
# [CV] ... batch_size=35, score=(train=1.000, test=0.838), total=  36.0s
# [CV] batch_size=42 ...................................................
# [CV] ... batch_size=34, score=(train=1.000, test=0.875), total=  37.6s
# [CV] batch_size=43 ...................................................
# [CV] ... batch_size=37, score=(train=1.000, test=0.850), total=  29.0s
# [CV] batch_size=44 ...................................................
# [CV] ... batch_size=38, score=(train=1.000, test=0.838), total=  31.4s
# [CV] batch_size=45 ...................................................
# [CV] ... batch_size=40, score=(train=1.000, test=0.863), total=  28.9s
# [CV] batch_size=46 ...................................................
# [CV] ... batch_size=41, score=(train=1.000, test=0.838), total=  28.8s
# [CV] batch_size=47 ...................................................
# [CV] ... batch_size=39, score=(train=1.000, test=0.850), total=  32.6s
# [CV] batch_size=48 ...................................................
# [CV] ... batch_size=42, score=(train=1.000, test=0.825), total=  28.4s
# [CV] batch_size=49 ...................................................
# [CV] ... batch_size=43, score=(train=1.000, test=0.875), total=  28.3s
# [CV] batch_size=1 ....................................................
# [CV] ... batch_size=44, score=(train=1.000, test=0.850), total=  30.7s
# [CV] batch_size=2 ....................................................
# [CV] ... batch_size=45, score=(train=1.000, test=0.875), total=  30.4s
# [CV] batch_size=3 ....................................................
# [CV] ... batch_size=46, score=(train=1.000, test=0.863), total=  29.2s
# [CV] batch_size=4 ....................................................
# [CV] ... batch_size=48, score=(train=1.000, test=0.838), total=  28.1s
# [CV] batch_size=5 ....................................................
# [CV] ... batch_size=47, score=(train=1.000, test=0.850), total=  29.7s
# [CV] batch_size=6 ....................................................
# [CV] ... batch_size=49, score=(train=1.000, test=0.838), total=  27.3s
# [CV] batch_size=7 ....................................................
# [CV] .... batch_size=7, score=(train=1.000, test=0.850), total=  52.2s
# [CV] batch_size=8 ....................................................
# [CV] .... batch_size=4, score=(train=1.000, test=0.850), total=  55.8s
# [CV] batch_size=9 ....................................................
# [CV] .... batch_size=3, score=(train=0.988, test=0.863), total=  58.3s
# [CV] batch_size=10 ...................................................
# [CV] .... batch_size=6, score=(train=1.000, test=0.863), total=  56.8s
# [CV] batch_size=11 ...................................................
# [CV] .... batch_size=5, score=(train=1.000, test=0.850), total= 1.1min
# [CV] batch_size=12 ...................................................
# [CV] .... batch_size=1, score=(train=0.988, test=0.812), total= 6.8min
# [CV] batch_size=13 ...................................................
# [CV] .... batch_size=8, score=(train=1.000, test=0.850), total=  38.3s
# [CV] batch_size=14 ...................................................
# [CV] ... batch_size=10, score=(train=1.000, test=0.863), total=  42.3s
# [CV] batch_size=15 ...................................................
# [CV] ... batch_size=11, score=(train=1.000, test=0.863), total=  42.1s
# [CV] batch_size=16 ...................................................
# [CV] .... batch_size=2, score=(train=0.991, test=0.863), total= 1.9min
# [CV] batch_size=17 ...................................................
# [CV] .... batch_size=9, score=(train=0.994, test=0.863), total=  51.3s
# [CV] batch_size=18 ...................................................
# [CV] ... batch_size=12, score=(train=1.000, test=0.887), total=  40.9s
# [CV] batch_size=19 ...................................................
# [CV] ... batch_size=13, score=(train=1.000, test=0.863), total=  47.9s
# [CV] batch_size=20 ...................................................
# [CV] ... batch_size=15, score=(train=0.997, test=0.850), total=  43.9s
# [CV] batch_size=21 ...................................................
# [CV] ... batch_size=16, score=(train=1.000, test=0.850), total=  45.7s
# [CV] batch_size=22 ...................................................
# [CV] ... batch_size=17, score=(train=1.000, test=0.863), total=  48.1s
# [CV] batch_size=23 ...................................................
# [CV] ... batch_size=14, score=(train=1.000, test=0.850), total=  59.3s
# [CV] batch_size=24 ...................................................
# [CV] ... batch_size=18, score=(train=1.000, test=0.863), total=  53.1s
# [CV] batch_size=25 ...................................................
# [CV] ... batch_size=19, score=(train=1.000, test=0.863), total=  51.7s
# [CV] batch_size=26 ...................................................
# [CV] ... batch_size=22, score=(train=1.000, test=0.850), total=  40.8s
# [CV] batch_size=27 ...................................................
# [CV] ... batch_size=21, score=(train=1.000, test=0.887), total=  45.6s
# [CV] batch_size=28 ...................................................
# [CV] ... batch_size=20, score=(train=1.000, test=0.850), total=  56.1s
# [CV] batch_size=29 ...................................................
# [CV] ... batch_size=23, score=(train=1.000, test=0.863), total=  44.6s
# [CV] batch_size=30 ...................................................
# [CV] ... batch_size=24, score=(train=1.000, test=0.863), total=  44.2s
# [CV] batch_size=31 ...................................................
# [CV] ... batch_size=25, score=(train=1.000, test=0.850), total=  42.2s
# [CV] batch_size=32 ...................................................
# [CV] ... batch_size=26, score=(train=1.000, test=0.850), total=  52.4s
# [CV] batch_size=33 ...................................................
# [CV] ... batch_size=29, score=(train=1.000, test=0.850), total=  33.4s
# [CV] batch_size=34 ...................................................
# [CV] ... batch_size=27, score=(train=1.000, test=0.875), total=  43.4s
# [CV] batch_size=35 ...................................................
# [CV] ... batch_size=30, score=(train=1.000, test=0.850), total=  37.0s
# [CV] batch_size=36 ...................................................
# [CV] ... batch_size=32, score=(train=1.000, test=0.863), total=  32.5s
# [CV] batch_size=37 ...................................................
# [CV] ... batch_size=31, score=(train=1.000, test=0.875), total=  40.1s
# [CV] batch_size=38 ...................................................
# [CV] ... batch_size=28, score=(train=1.000, test=0.850), total=  48.6s
# [CV] batch_size=39 ...................................................
# [CV] ... batch_size=33, score=(train=1.000, test=0.850), total=  34.6s
# [CV] batch_size=40 ...................................................
# [CV] ... batch_size=34, score=(train=1.000, test=0.875), total=  36.4s
# [CV] batch_size=41 ...................................................
# [CV] ... batch_size=36, score=(train=1.000, test=0.887), total=  32.9s
# [CV] batch_size=42 ...................................................
# [CV] ... batch_size=37, score=(train=1.000, test=0.850), total=  31.3s
# [CV] batch_size=43 ...................................................
# [CV] ... batch_size=38, score=(train=1.000, test=0.863), total=  32.3s
# [CV] batch_size=44 ...................................................
# [CV] ... batch_size=39, score=(train=1.000, test=0.850), total=  31.8s
# [CV] batch_size=45 ...................................................
# [CV] ... batch_size=35, score=(train=1.000, test=0.875), total=  41.5s
# [CV] batch_size=46 ...................................................
# [CV] .... batch_size=1, score=(train=0.984, test=0.875), total= 5.0min
# [CV] batch_size=47 ...................................................
# [CV] ... batch_size=40, score=(train=1.000, test=0.863), total=  29.0s
# [CV] batch_size=48 ...................................................
# [CV] ... batch_size=41, score=(train=1.000, test=0.850), total=  31.9s
# [CV] batch_size=49 ...................................................
# [CV] ... batch_size=42, score=(train=1.000, test=0.875), total=  29.4s
# [CV] ... batch_size=43, score=(train=1.000, test=0.825), total=  30.6s
# [CV] ... batch_size=44, score=(train=1.000, test=0.863), total=  28.2s
# [CV] ... batch_size=45, score=(train=1.000, test=0.863), total=  27.6s
# [CV] ... batch_size=46, score=(train=1.000, test=0.850), total=  26.1s
# [CV] ... batch_size=47, score=(train=1.000, test=0.850), total=  24.3s
# [CV] ... batch_size=48, score=(train=1.000, test=0.863), total=  22.0s
# [CV] ... batch_size=49, score=(train=1.000, test=0.850), total=  10.0s
# [Parallel(n_jobs=-1)]: Done 245 out of 245 | elapsed: 24.7min finished

# %%
plt.close("all")

with plt.style.context('ggplot'):
    nn_train_scores_mean = np.mean(nn_learning_curve_results["train_scores"], axis=1)
    nn_train_scores_std = np.std(nn_learning_curve_results["train_scores"], axis=1)
    nn_test_scores_mean = np.mean(nn_learning_curve_results["test_scores"], axis=1)
    nn_test_scores_std = np.std(nn_learning_curve_results["test_scores"], axis=1)
    
    fig0, ax0 = plt.subplots()
    ax0.set_xlabel("Percent of Training Set")
    ax0.set_ylabel("Accuracy (%)", color='tab:orange')
    ax0.set_title("{} {} Learning Curve".format(nn_segment, dataset))
    ax0.tick_params(axis='y', labelcolor="black")
    ax0.set_ylim(0, 1.1)

    lw = 2
    plt.plot([i for i in range(50)], nn_train_scores_mean, label="Training score",
                 color="darkorange", lw=lw)
    plt.fill_between([i for i in range(50)], nn_train_scores_mean - nn_train_scores_std,
                     nn_train_scores_mean + nn_train_scores_std, alpha=0.2,
                     color="darkorange", lw=lw)
    plt.plot([i for i in range(50)], nn_test_scores_mean, label="Testing score",
                 color="navy", lw=lw)
    plt.fill_between([i for i in range(50)], nn_test_scores_mean - nn_test_scores_std,
                     nn_test_scores_mean + nn_test_scores_std, alpha=0.2,
                     color="navy", lw=lw)
    plt.legend(loc="best")
    plt.savefig("{}_{}_Learning_Curve.png".format(nn_segment, dataset))
    plt.show()

# %%
with plt.style.context('ggplot'):
    nn_train_scores_mean = np.mean(nn_validation_curve_results["train_scores"], axis=1)
    nn_train_scores_std = np.std(nn_validation_curve_results["train_scores"], axis=1)
    nn_test_scores_mean = np.mean(nn_validation_curve_results["test_scores"], axis=1)
    nn_test_scores_std = np.std(nn_validation_curve_results["test_scores"], axis=1)

    plt.title("Validation Curve with {} \n {}".format(nn_segment, dataset))
    plt.xlabel("{}".format("batch_size"))
    plt.ylabel("Score")
    plt.ylim(0.0, 1.1)
    lw = 2
    plt.plot([i for i in range(49)], nn_train_scores_mean, label="Training score",
                 color="darkorange", lw=lw)
    plt.fill_between([i for i in range(49)], nn_train_scores_mean - nn_train_scores_std,
                     nn_train_scores_mean + nn_train_scores_std, alpha=0.2,
                     color="darkorange", lw=lw)
    plt.plot([i for i in range(49)], nn_test_scores_mean, label="Cross-validation score",
                 color="navy", lw=lw)
    plt.fill_between([i for i in range(49)], nn_test_scores_mean - nn_test_scores_std,
                     nn_test_scores_mean + nn_test_scores_std, alpha=0.2,
                     color="navy", lw=lw)
    plt.legend(loc="best")
    plt.savefig("{}_{}_Validation_Curve.png".format(nn_segment, dataset))
    plt.show()

# %%
knn_segment = "K-Nearest Neighbors"
knn_estimator = KNeighborsClassifier()
knn_grid_search = GridSearchCV(knn_estimator, param_grid=knn_params, n_jobs=n_jobs, verbose=verbose_int)
knn_learning_curve_results = {"train_sizes": None, "train_scores": None, "test_scores": None, 
                              "fit_times": None}
knn_validation_curve_results = {"train_scores": None, "test_scores": None}

# %%
with parallel_backend('threading'):
    knn_grid_search.fit(X,y)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV] algorithm=ball_tree, n_neighbors=3 ..............................[CV] algorithm=ball_tree, n_neighbors=3 ..............................
#
# [CV] algorithm=ball_tree, n_neighbors=3 ..............................
# [CV] algorithm=ball_tree, n_neighbors=3 ..............................
# [CV] algorithm=ball_tree, n_neighbors=3 ..............................
# [CV] algorithm=ball_tree, n_neighbors=5 ..............................[CV] algorithm=ball_tree, n_neighbors=5 ..............................
#
# [CV] algorithm=ball_tree, n_neighbors=5 ..............................
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [CV] .. algorithm=ball_tree, n_neighbors=3, score=0.838, total=   1.5s
# [CV] algorithm=ball_tree, n_neighbors=5 ..............................
# [CV] .. algorithm=ball_tree, n_neighbors=3, score=0.853, total=   1.5s
# [CV] algorithm=ball_tree, n_neighbors=5 ..............................
# [CV] .. algorithm=ball_tree, n_neighbors=3, score=0.843, total=   1.5s
# [CV] algorithm=ball_tree, n_neighbors=7 ..............................
# [CV] .. algorithm=ball_tree, n_neighbors=5, score=0.853, total=   2.3s
# [CV] algorithm=ball_tree, n_neighbors=7 ..............................
# [CV] .. algorithm=ball_tree, n_neighbors=5, score=0.812, total=   2.3s
# [CV] algorithm=ball_tree, n_neighbors=7 ..............................
# [CV] .. algorithm=ball_tree, n_neighbors=3, score=0.870, total=   3.1s[CV] .. algorithm=ball_tree, n_neighbors=3, score=0.782, total=   3.1s
# [CV] algorithm=ball_tree, n_neighbors=7 ..............................
#
# [CV] algorithm=ball_tree, n_neighbors=7 ..............................
# [CV] .. algorithm=ball_tree, n_neighbors=5, score=0.845, total=   1.6s
# [CV] algorithm=ball_tree, n_neighbors=9 ..............................[CV] .. algorithm=ball_tree, n_neighbors=5, score=0.868, total=   1.6s
# [CV] algorithm=ball_tree, n_neighbors=9 ..............................
#
# [CV] .. algorithm=ball_tree, n_neighbors=5, score=0.833, total=   3.5s
# [CV] algorithm=ball_tree, n_neighbors=9 ..............................
# [CV] .. algorithm=ball_tree, n_neighbors=7, score=0.853, total=   2.5s
# [CV] algorithm=ball_tree, n_neighbors=9 ..............................
# [CV] .. algorithm=ball_tree, n_neighbors=7, score=0.812, total=   2.0s
# [CV] algorithm=ball_tree, n_neighbors=9 ..............................
# [CV] .. algorithm=ball_tree, n_neighbors=7, score=0.790, total=   2.6s
# [CV] algorithm=ball_tree, n_neighbors=11 .............................
# [CV] .. algorithm=ball_tree, n_neighbors=7, score=0.838, total=   2.1s
# [CV] algorithm=ball_tree, n_neighbors=11 .............................
# [CV] .. algorithm=ball_tree, n_neighbors=7, score=0.845, total=   2.1s
# [CV] algorithm=ball_tree, n_neighbors=11 .............................
# [CV] .. algorithm=ball_tree, n_neighbors=9, score=0.850, total=   2.6s
# [CV] algorithm=ball_tree, n_neighbors=11 .............................
# [CV] .. algorithm=ball_tree, n_neighbors=9, score=0.807, total=   2.7s
# [CV] algorithm=ball_tree, n_neighbors=11 .............................
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    5.7s
# [CV] .. algorithm=ball_tree, n_neighbors=9, score=0.812, total=   2.3s
# [CV] algorithm=kd_tree, n_neighbors=3 ................................
# [CV] .. algorithm=ball_tree, n_neighbors=9, score=0.848, total=   2.4s[CV] .. algorithm=ball_tree, n_neighbors=9, score=0.843, total=   2.4s
# [CV] algorithm=kd_tree, n_neighbors=3 ................................
#
# [CV] algorithm=kd_tree, n_neighbors=3 ................................
# [CV] . algorithm=ball_tree, n_neighbors=11, score=0.865, total=   2.3s
# [CV] algorithm=kd_tree, n_neighbors=3 ................................
# [CV] . algorithm=ball_tree, n_neighbors=11, score=0.790, total=   2.4s
# [CV] algorithm=kd_tree, n_neighbors=3 ................................
# [CV] . algorithm=ball_tree, n_neighbors=11, score=0.835, total=   2.3s
# [CV] algorithm=kd_tree, n_neighbors=5 ................................
# [CV] . algorithm=ball_tree, n_neighbors=11, score=0.805, total=   3.2s
# [CV] algorithm=kd_tree, n_neighbors=5 ................................
# [CV] . algorithm=ball_tree, n_neighbors=11, score=0.850, total=   2.7s
# [CV] algorithm=kd_tree, n_neighbors=5 ................................
# [CV] .... algorithm=kd_tree, n_neighbors=3, score=0.853, total=   2.5s
# [CV] algorithm=kd_tree, n_neighbors=5 ................................
# [CV] .... algorithm=kd_tree, n_neighbors=3, score=0.838, total=   1.8s[CV] .... algorithm=kd_tree, n_neighbors=3, score=0.782, total=   2.7s
# [CV] algorithm=kd_tree, n_neighbors=5 ................................
#
# [CV] algorithm=kd_tree, n_neighbors=7 ................................
# [CV] .... algorithm=kd_tree, n_neighbors=3, score=0.843, total=   2.7s
# [CV] algorithm=kd_tree, n_neighbors=7 ................................
# [CV] .... algorithm=kd_tree, n_neighbors=3, score=0.870, total=   2.1s
# [CV] algorithm=kd_tree, n_neighbors=7 ................................
# [CV] .... algorithm=kd_tree, n_neighbors=5, score=0.853, total=   2.7s[CV] .... algorithm=kd_tree, n_neighbors=5, score=0.833, total=   2.0s
# [CV] algorithm=kd_tree, n_neighbors=7 ................................
#
# [CV] algorithm=kd_tree, n_neighbors=7 ................................
# [CV] .... algorithm=kd_tree, n_neighbors=5, score=0.812, total=   2.3s
# [CV] algorithm=kd_tree, n_neighbors=9 ................................
# [CV] .... algorithm=kd_tree, n_neighbors=5, score=0.845, total=   2.0s
# [CV] algorithm=kd_tree, n_neighbors=9 ................................
# [CV] .... algorithm=kd_tree, n_neighbors=7, score=0.853, total=   2.7s
# [CV] algorithm=kd_tree, n_neighbors=9 ................................
# [CV] .... algorithm=kd_tree, n_neighbors=5, score=0.868, total=   3.0s
# [CV] algorithm=kd_tree, n_neighbors=9 ................................
# [CV] .... algorithm=kd_tree, n_neighbors=7, score=0.790, total=   3.0s
# [CV] algorithm=kd_tree, n_neighbors=9 ................................
# [CV] .... algorithm=kd_tree, n_neighbors=7, score=0.812, total=   2.5s
# [CV] algorithm=kd_tree, n_neighbors=11 ...............................
# [CV] .... algorithm=kd_tree, n_neighbors=7, score=0.845, total=   2.7s
# [CV] algorithm=kd_tree, n_neighbors=11 ...............................
# [CV] .... algorithm=kd_tree, n_neighbors=7, score=0.838, total=   2.7s
# [CV] algorithm=kd_tree, n_neighbors=11 ...............................
# [CV] .... algorithm=kd_tree, n_neighbors=9, score=0.850, total=   2.7s
# [CV] algorithm=kd_tree, n_neighbors=11 ...............................
# [CV] .... algorithm=kd_tree, n_neighbors=9, score=0.812, total=   1.7s
# [CV] algorithm=kd_tree, n_neighbors=11 ...............................
# [CV] .... algorithm=kd_tree, n_neighbors=9, score=0.807, total=   3.0s
# [CV] algorithm=brute, n_neighbors=3 ..................................
# [CV] .... algorithm=kd_tree, n_neighbors=9, score=0.843, total=   2.2s
# [CV] algorithm=brute, n_neighbors=3 ..................................
# [CV] .... algorithm=kd_tree, n_neighbors=9, score=0.848, total=   2.2s
# [CV] algorithm=brute, n_neighbors=3 ..................................
# [CV] ... algorithm=kd_tree, n_neighbors=11, score=0.865, total=   2.3s
# [CV] algorithm=brute, n_neighbors=3 ..................................
# [CV] ... algorithm=kd_tree, n_neighbors=11, score=0.790, total=   1.3s
# [CV] algorithm=brute, n_neighbors=3 ..................................
# [CV] ...... algorithm=brute, n_neighbors=3, score=0.782, total=   0.2s[CV] ...... algorithm=brute, n_neighbors=3, score=0.853, total=   1.0s
# [CV] algorithm=brute, n_neighbors=5 ..................................
# [CV] algorithm=brute, n_neighbors=5 ..................................
#
# [CV] ...... algorithm=brute, n_neighbors=3, score=0.843, total=   0.2s
# [CV] algorithm=brute, n_neighbors=5 ..................................
# [CV] ...... algorithm=brute, n_neighbors=3, score=0.870, total=   0.1s
# [CV] algorithm=brute, n_neighbors=5 ..................................
# [CV] ...... algorithm=brute, n_neighbors=3, score=0.838, total=   0.2s
# [CV] algorithm=brute, n_neighbors=5 ..................................
# [CV] ... algorithm=kd_tree, n_neighbors=11, score=0.805, total=   1.6s
# [CV] algorithm=brute, n_neighbors=7 ..................................
# [CV] ...... algorithm=brute, n_neighbors=5, score=0.853, total=   0.2s
# [CV] algorithm=brute, n_neighbors=7 ..................................
# [CV] ...... algorithm=brute, n_neighbors=5, score=0.812, total=   0.3s
# [CV] algorithm=brute, n_neighbors=7 ..................................
# [CV] ...... algorithm=brute, n_neighbors=5, score=0.845, total=   0.2s
# [CV] algorithm=brute, n_neighbors=7 ..................................
# [CV] ...... algorithm=brute, n_neighbors=5, score=0.833, total=   0.3s
# [CV] algorithm=brute, n_neighbors=7 ..................................
# [CV] ...... algorithm=brute, n_neighbors=5, score=0.868, total=   0.2s
# [CV] algorithm=brute, n_neighbors=9 ..................................
# [CV] ...... algorithm=brute, n_neighbors=7, score=0.853, total=   0.2s
# [CV] algorithm=brute, n_neighbors=9 ..................................
# [CV] ...... algorithm=brute, n_neighbors=7, score=0.790, total=   0.2s
# [CV] algorithm=brute, n_neighbors=9 ..................................
# [CV] ...... algorithm=brute, n_neighbors=7, score=0.812, total=   0.3s
# [CV] algorithm=brute, n_neighbors=9 ..................................
# [CV] ...... algorithm=brute, n_neighbors=7, score=0.845, total=   0.3s
# [CV] algorithm=brute, n_neighbors=9 ..................................
# [CV] ...... algorithm=brute, n_neighbors=7, score=0.838, total=   0.3s
# [CV] algorithm=brute, n_neighbors=11 .................................
# [CV] ...... algorithm=brute, n_neighbors=9, score=0.850, total=   0.3s
# [CV] algorithm=brute, n_neighbors=11 .................................
# [CV] ...... algorithm=brute, n_neighbors=9, score=0.807, total=   0.2s
# [CV] algorithm=brute, n_neighbors=11 .................................
# [CV] ...... algorithm=brute, n_neighbors=9, score=0.812, total=   0.2s
# [CV] algorithm=brute, n_neighbors=11 .................................
# [CV] ...... algorithm=brute, n_neighbors=9, score=0.843, total=   0.2s
# [CV] algorithm=brute, n_neighbors=11 .................................
# [CV] ...... algorithm=brute, n_neighbors=9, score=0.848, total=   0.2s
# [CV] ..... algorithm=brute, n_neighbors=11, score=0.790, total=   0.3s
# [CV] ..... algorithm=brute, n_neighbors=11, score=0.865, total=   0.3s
# [CV] ..... algorithm=brute, n_neighbors=11, score=0.805, total=   0.3s
# [CV] ... algorithm=kd_tree, n_neighbors=11, score=0.850, total=   2.0s
# [CV] ..... algorithm=brute, n_neighbors=11, score=0.835, total=   0.2s
# [CV] ..... algorithm=brute, n_neighbors=11, score=0.850, total=   0.2s
# [CV] ... algorithm=kd_tree, n_neighbors=11, score=0.835, total=   2.1s
# [Parallel(n_jobs=-1)]: Done  75 out of  75 | elapsed:   15.8s finished

# %%
with parallel_backend('threading'):
        knn_learning_curve_results["train_sizes"], knn_learning_curve_results["train_scores"], knn_learning_curve_results["test_scores"], knn_learning_curve_results["fit_times"], _ = learning_curve(knn_grid_search.best_estimator_, X, y, cv=3, verbose=3, n_jobs=n_jobs, train_sizes=train_sizes, return_times=True)
# Out:
# [learning_curve] Training set sizes: [ 133  157  182  206  231  255  280  304  329  353  378  402  427  451
#   476  500  525  549  574  598  622  647  671  696  720  745  769  794
#   818  843  867  892  916  941  965  990 1014 1039 1063 1088 1112 1137
#  1161 1186 1210 1235 1259 1284 1308 1333]
# [CV]  ................................................................
# [CV]  ................................................................
# [CV]  ................................................................[CV]  ................................................................
#
# [CV]  ................................................................[CV]  ................................................................
# [CV]  ................................................................
# [CV]  ................................................................
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [CV] ................ , score=(train=0.714, test=0.552), total=   0.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.777, test=0.616), total=   0.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.796, test=0.661), total=   0.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.786, test=0.666), total=   0.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.808, test=0.714), total=   0.6s
# [CV]  ................................................................[CV] ................ , score=(train=0.814, test=0.696), total=   0.6s
# [CV]  ................................................................
#
# [CV] ................ , score=(train=0.811, test=0.724), total=   0.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.819, test=0.736), total=   0.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.839, test=0.747), total=   0.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.836, test=0.757), total=   0.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.810, test=0.766), total=   0.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.823, test=0.768), total=   0.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.843, test=0.784), total=   0.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.834, test=0.772), total=   1.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.851, test=0.784), total=   1.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.854, test=0.781), total=   1.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.855, test=0.786), total=   1.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.863, test=0.792), total=   1.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.864, test=0.795), total=   1.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.866, test=0.799), total=   1.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.862, test=0.802), total=   1.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.862, test=0.799), total=   0.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.861, test=0.798), total=   1.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.866, test=0.804), total=   1.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.871, test=0.804), total=   1.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.871, test=0.807), total=   1.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.874, test=0.811), total=   1.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.874, test=0.813), total=   1.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.873, test=0.811), total=   1.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.875, test=0.813), total=   1.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.874, test=0.811), total=   1.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.880, test=0.814), total=   1.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.881, test=0.819), total=   2.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.887, test=0.820), total=   1.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.886, test=0.822), total=   2.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.889, test=0.822), total=   2.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.876), total= 1.9min
# [CV] ................ , score=(train=0.887, test=0.825), total=   2.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.889, test=0.823), total=   2.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.889, test=0.826), total=   2.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.887, test=0.825), total=   2.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.888, test=0.823), total=   3.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.886, test=0.825), total=   2.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.885, test=0.825), total=   2.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.797, test=0.561), total=   0.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.809, test=0.589), total=   0.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.886, test=0.822), total=   2.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.808, test=0.612), total=   0.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.811, test=0.610), total=   0.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.801, test=0.640), total=   0.3s
# [CV]  ................................................................
# [Parallel(n_jobs=-1)]: Done  49 out of 150 | elapsed:   18.5s remaining:   38.3s
# [CV] ................ , score=(train=0.812, test=0.648), total=   0.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.884, test=0.820), total=   2.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.825, test=0.652), total=   0.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.887, test=0.823), total=   2.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.839, test=0.661), total=   0.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.848, test=0.684), total=   0.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.861, test=0.700), total=   0.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.886, test=0.828), total=   2.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.862, test=0.708), total=   0.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.886, test=0.832), total=   2.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.861, test=0.709), total=   0.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.857, test=0.705), total=   0.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.860, test=0.706), total=   0.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.857, test=0.712), total=   0.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.862, test=0.718), total=   0.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.883, test=0.831), total=   2.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.855, test=0.721), total=   1.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.856, test=0.729), total=   1.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.866, test=0.726), total=   1.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.889, test=0.831), total=   2.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.868, test=0.729), total=   1.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.857, test=0.735), total=   1.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.867, test=0.741), total=   1.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.872, test=0.756), total=   1.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.866, test=0.760), total=   1.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.868, test=0.766), total=   1.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.870, test=0.763), total=   1.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.871, test=0.766), total=   1.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.878, test=0.759), total=   1.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.880, test=0.762), total=   1.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.884, test=0.769), total=   1.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.882, test=0.771), total=   1.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.888, test=0.769), total=   1.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.889, test=0.778), total=   1.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.886, test=0.775), total=   1.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.888, test=0.777), total=   1.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.892, test=0.778), total=   1.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.890, test=0.780), total=   1.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.890, test=0.777), total=   2.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.893, test=0.775), total=   2.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.895, test=0.775), total=   2.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.895, test=0.783), total=   2.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.896, test=0.787), total=   2.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.899, test=0.780), total=   2.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.797, test=0.569), total=   0.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.900, test=0.778), total=   2.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.809, test=0.604), total=   0.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.808, test=0.628), total=   0.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.811, test=0.635), total=   0.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.801, test=0.664), total=   0.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.812, test=0.697), total=   0.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.897, test=0.781), total=   2.9s
# [CV]  ................................................................
# [Parallel(n_jobs=-1)]: Done 100 out of 150 | elapsed:   38.8s remaining:   19.4s
# [CV] ................ , score=(train=0.825, test=0.710), total=   0.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.901, test=0.781), total=   2.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.839, test=0.709), total=   0.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.848, test=0.724), total=   0.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.902, test=0.786), total=   2.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.861, test=0.733), total=   0.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.862, test=0.743), total=   0.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.857, test=0.748), total=   0.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.861, test=0.748), total=   0.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.860, test=0.752), total=   0.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.900, test=0.787), total=   2.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.857, test=0.751), total=   1.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.901, test=0.784), total=   2.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.862, test=0.761), total=   1.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.902, test=0.786), total=   2.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.855, test=0.776), total=   1.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.856, test=0.773), total=   1.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.871, test=0.769), total=   0.8s[CV] ................ , score=(train=0.868, test=0.770), total=   1.0s
# [CV]  ................................................................
#
# [CV]  ................................................................
# [CV] ................ , score=(train=0.860, test=0.766), total=   1.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.867, test=0.782), total=   1.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.867, test=0.782), total=   1.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.866, test=0.796), total=   1.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.868, test=0.806), total=   1.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.870, test=0.809), total=   1.4s
# [CV]  ................................................................[CV] ................ , score=(train=0.874, test=0.817), total=   1.2s
# [CV]  ................................................................
#
# [CV] ................ , score=(train=0.874, test=0.820), total=   1.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.879, test=0.829), total=   2.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.880, test=0.830), total=   2.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.880, test=0.838), total=   1.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.880, test=0.839), total=   1.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.878, test=0.836), total=   1.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.880, test=0.832), total=   2.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.878, test=0.838), total=   2.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.881, test=0.835), total=   2.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.881, test=0.830), total=   2.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.879, test=0.833), total=   1.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.878, test=0.836), total=   2.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.878, test=0.841), total=   2.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.883, test=0.838), total=   2.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.884, test=0.841), total=   2.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=0.883, test=0.839), total=   2.5s
# [CV] ................ , score=(train=0.883, test=0.838), total=   2.3s
# [CV] ................ , score=(train=0.885, test=0.844), total=   2.3s
# [CV] ................ , score=(train=0.887, test=0.842), total=   2.7s
# [CV] ................ , score=(train=0.887, test=0.839), total=   3.0s
# [CV] ................ , score=(train=0.888, test=0.844), total=   2.6s
# [CV] ................ , score=(train=0.888, test=0.848), total=   2.7s
# [CV] ................ , score=(train=0.887, test=0.848), total=   2.5s
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:  1.0min finished
# [CV] ................ , score=(train=1.000, test=0.868), total= 2.4min
# [CV] ................ , score=(train=1.000, test=0.883), total= 2.3min
# [CV] ................ , score=(train=1.000, test=0.888), total= 2.2min

# %%
with parallel_backend('threading'):
        knn_validation_curve_results["train_scores"], knn_validation_curve_results["test_scores"] = validation_curve(knn_grid_search.best_estimator_, X=Validation_X, y=validation_y, n_jobs=n_jobs, cv=3, verbose=3, param_name="leaf_size", param_range=[i for i in range(2, 52)])

plt.close("all")
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [CV] leaf_size=2 .....................................................
# [CV] leaf_size=3 .....................................................
# [CV] leaf_size=4 .....................................................
# [CV] leaf_size=5 .....................................................
# [CV] leaf_size=6 .....................................................
# [CV] leaf_size=7 .....................................................
# [CV] leaf_size=8 .....................................................
# [CV] leaf_size=9 .....................................................
# [CV] ..... leaf_size=9, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=10 ....................................................
# [CV] ..... leaf_size=3, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=11 ....................................................
# [CV] ..... leaf_size=7, score=(train=0.831, test=0.701), total=   0.3s
# [CV] leaf_size=12 ....................................................
# [CV] ..... leaf_size=4, score=(train=0.831, test=0.701), total=   0.3s
# [CV] leaf_size=13 ....................................................
# [CV] ..... leaf_size=6, score=(train=0.831, test=0.701), total=   0.3s
# [CV] leaf_size=14 ....................................................
# [CV] ..... leaf_size=8, score=(train=0.831, test=0.701), total=   0.3s[CV] ..... leaf_size=5, score=(train=0.831, test=0.701), total=   0.3s
# [CV] leaf_size=15 ....................................................
#
# [CV] leaf_size=16 ....................................................
# [CV] .... leaf_size=10, score=(train=0.831, test=0.701), total=   0.2s[CV] ..... leaf_size=2, score=(train=0.831, test=0.701), total=   0.3s
#
# [CV] leaf_size=17 ....................................................
# [CV] leaf_size=18 ....................................................
# [CV] .... leaf_size=11, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=19 ....................................................
# [CV] .... leaf_size=12, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=20 ....................................................
# [CV] .... leaf_size=15, score=(train=0.831, test=0.701), total=   0.2s[CV] .... leaf_size=14, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=21 ....................................................
#
# [CV] leaf_size=22 ....................................................
# [CV] .... leaf_size=16, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=23 ....................................................
# [CV] .... leaf_size=13, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=24 ....................................................
# [CV] .... leaf_size=17, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=25 ....................................................
# [CV] .... leaf_size=23, score=(train=0.831, test=0.701), total=   0.1s
# [CV] leaf_size=26 ....................................................[CV] .... leaf_size=19, score=(train=0.831, test=0.701), total=   0.1s
#
# [CV] leaf_size=27 ....................................................
# [CV] .... leaf_size=20, score=(train=0.831, test=0.701), total=   0.1s
# [CV] leaf_size=28 ....................................................
# [CV] .... leaf_size=18, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=29 ....................................................
# [CV] .... leaf_size=22, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=30 ....................................................
# [CV] .... leaf_size=21, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=31 ....................................................
# [CV] .... leaf_size=24, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=32 ....................................................
# [CV] .... leaf_size=25, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=33 ....................................................
# [CV] .... leaf_size=28, score=(train=0.831, test=0.701), total=   0.1s
# [CV] leaf_size=34 ....................................................
# [CV] .... leaf_size=26, score=(train=0.831, test=0.701), total=   0.1s
# [CV] leaf_size=35 ....................................................
# [CV] .... leaf_size=27, score=(train=0.831, test=0.701), total=   0.1s[CV] .... leaf_size=29, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=36 ....................................................
#
# [CV] leaf_size=37 ....................................................
# [CV] .... leaf_size=30, score=(train=0.831, test=0.701), total=   0.1s
# [CV] .... leaf_size=31, score=(train=0.831, test=0.701), total=   0.1s[CV] leaf_size=38 ....................................................
#
# [CV] leaf_size=39 ....................................................
# [CV] .... leaf_size=33, score=(train=0.831, test=0.701), total=   0.1s[CV] .... leaf_size=32, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=40 ....................................................
#
# [CV] leaf_size=41 ....................................................
# [CV] .... leaf_size=34, score=(train=0.831, test=0.701), total=   0.1s
# [CV] leaf_size=42 ....................................................
# [CV] .... leaf_size=35, score=(train=0.831, test=0.701), total=   0.1s
# [CV] leaf_size=43 ....................................................
# [CV] .... leaf_size=39, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=44 ....................................................
# [CV] .... leaf_size=36, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=45 ....................................................
# [CV] .... leaf_size=37, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=46 ....................................................
# [CV] .... leaf_size=38, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=47 ....................................................
# [CV] .... leaf_size=41, score=(train=0.831, test=0.701), total=   0.1s
# [CV] leaf_size=48 ....................................................
# [CV] .... leaf_size=40, score=(train=0.831, test=0.701), total=   0.1s
# [CV] leaf_size=49 ....................................................
# [CV] .... leaf_size=42, score=(train=0.831, test=0.701), total=   0.1s
# [CV] leaf_size=50 ....................................................
# [CV] .... leaf_size=43, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=51 ....................................................
# [CV] .... leaf_size=44, score=(train=0.831, test=0.701), total=   0.1s
# [CV] leaf_size=2 .....................................................
# [CV] .... leaf_size=47, score=(train=0.831, test=0.701), total=   0.1s
# [CV] leaf_size=3 .....................................................
# [CV] .... leaf_size=48, score=(train=0.831, test=0.701), total=   0.1s
# [CV] leaf_size=4 .....................................................
# [CV] .... leaf_size=45, score=(train=0.831, test=0.701), total=   0.1s
# [CV] leaf_size=5 .....................................................
# [CV] .... leaf_size=46, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=6 .....................................................
# [CV] .... leaf_size=50, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=7 .....................................................
# [CV] .... leaf_size=51, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=8 .....................................................
# [CV] .... leaf_size=49, score=(train=0.831, test=0.701), total=   0.2s
# [CV] leaf_size=9 .....................................................
# [Parallel(n_jobs=-1)]: Done  49 out of 150 | elapsed:    2.6s remaining:    5.5s
# [CV] ..... leaf_size=4, score=(train=0.831, test=0.752), total=   0.1s
# [CV] leaf_size=10 ....................................................
# [CV] ..... leaf_size=5, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=11 ....................................................
# [CV] ..... leaf_size=3, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=12 ....................................................[CV] ..... leaf_size=6, score=(train=0.831, test=0.752), total=   0.2s
#
# [CV] leaf_size=13 ....................................................
# [CV] ..... leaf_size=2, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=14 ....................................................
# [CV] ..... leaf_size=9, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=15 ....................................................
# [CV] ..... leaf_size=8, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=16 ....................................................
# [CV] ..... leaf_size=7, score=(train=0.831, test=0.752), total=   0.3s
# [CV] leaf_size=17 ....................................................
# [CV] .... leaf_size=10, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=18 ....................................................
# [CV] .... leaf_size=14, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=19 ....................................................
# [CV] .... leaf_size=11, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=20 ....................................................
# [CV] .... leaf_size=15, score=(train=0.831, test=0.752), total=   0.1s
# [CV] leaf_size=21 ....................................................
# [CV] .... leaf_size=13, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=22 ....................................................
# [CV] .... leaf_size=17, score=(train=0.831, test=0.752), total=   0.1s
# [CV] leaf_size=23 ....................................................
# [CV] .... leaf_size=16, score=(train=0.831, test=0.752), total=   0.1s
# [CV] leaf_size=24 ....................................................
# [CV] .... leaf_size=12, score=(train=0.831, test=0.752), total=   0.3s
# [CV] leaf_size=25 ....................................................
# [CV] .... leaf_size=19, score=(train=0.831, test=0.752), total=   0.1s
# [CV] leaf_size=26 ....................................................
# [CV] .... leaf_size=18, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=27 ....................................................
# [CV] .... leaf_size=21, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=28 ....................................................
# [CV] .... leaf_size=22, score=(train=0.831, test=0.752), total=   0.2s[CV] .... leaf_size=20, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=29 ....................................................
#
# [CV] leaf_size=30 ....................................................
# [CV] .... leaf_size=23, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=31 ....................................................
# [CV] .... leaf_size=24, score=(train=0.831, test=0.752), total=   0.1s
# [CV] leaf_size=32 ....................................................
# [CV] .... leaf_size=27, score=(train=0.831, test=0.752), total=   0.2s[CV] .... leaf_size=26, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=33 ....................................................
# [CV] leaf_size=34 ....................................................
#
# [CV] .... leaf_size=25, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=35 ....................................................
# [CV] .... leaf_size=30, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=36 ....................................................
# [CV] .... leaf_size=28, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=37 ....................................................
# [CV] .... leaf_size=31, score=(train=0.831, test=0.752), total=   0.2s[CV] .... leaf_size=29, score=(train=0.831, test=0.752), total=   0.2s
#
# [CV] leaf_size=38 ....................................................
# [CV] leaf_size=39 ....................................................
# [CV] .... leaf_size=32, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=40 ....................................................
# [CV] .... leaf_size=34, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=41 ....................................................
# [CV] .... leaf_size=35, score=(train=0.831, test=0.752), total=   0.1s
# [CV] leaf_size=42 ....................................................
# [CV] .... leaf_size=33, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=43 ....................................................
# [CV] .... leaf_size=39, score=(train=0.831, test=0.752), total=   0.1s
# [CV] leaf_size=44 ....................................................
# [CV] .... leaf_size=36, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=45 ....................................................
# [CV] .... leaf_size=40, score=(train=0.831, test=0.752), total=   0.1s
# [CV] leaf_size=46 ....................................................
# [CV] .... leaf_size=38, score=(train=0.831, test=0.752), total=   0.1s
# [CV] leaf_size=47 ....................................................
# [CV] .... leaf_size=37, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=48 ....................................................
# [CV] .... leaf_size=41, score=(train=0.831, test=0.752), total=   0.1s
# [CV] leaf_size=49 ....................................................
# [CV] .... leaf_size=42, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=50 ....................................................
# [CV] .... leaf_size=43, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=51 ....................................................
# [CV] .... leaf_size=45, score=(train=0.831, test=0.752), total=   0.1s
# [CV] leaf_size=2 .....................................................
# [CV] .... leaf_size=44, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=3 .....................................................
# [CV] .... leaf_size=47, score=(train=0.831, test=0.752), total=   0.1s
# [CV] leaf_size=4 .....................................................
# [CV] .... leaf_size=49, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=5 .....................................................
# [CV] .... leaf_size=46, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=6 .....................................................
# [CV] .... leaf_size=48, score=(train=0.831, test=0.752), total=   0.1s
# [CV] leaf_size=7 .....................................................
# [CV] .... leaf_size=50, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=8 .....................................................
# [CV] .... leaf_size=51, score=(train=0.831, test=0.752), total=   0.2s
# [CV] leaf_size=9 .....................................................
# [CV] ..... leaf_size=2, score=(train=0.828, test=0.744), total=   0.2s
# [CV] leaf_size=10 ....................................................
# [CV] ..... leaf_size=4, score=(train=0.828, test=0.744), total=   0.2s
# [CV] leaf_size=11 ....................................................
# [CV] ..... leaf_size=3, score=(train=0.828, test=0.744), total=   0.1s
# [CV] leaf_size=12 ....................................................
# [CV] ..... leaf_size=5, score=(train=0.828, test=0.744), total=   0.2s
# [Parallel(n_jobs=-1)]: Done 100 out of 150 | elapsed:    5.2s remaining:    2.6s
# [CV] leaf_size=13 ....................................................
# [CV] ..... leaf_size=7, score=(train=0.828, test=0.744), total=   0.2s
# [CV] leaf_size=14 ....................................................
# [CV] ..... leaf_size=6, score=(train=0.828, test=0.744), total=   0.2s
# [CV] leaf_size=15 ....................................................
# [CV] ..... leaf_size=8, score=(train=0.828, test=0.744), total=   0.2s
# [CV] leaf_size=16 ....................................................
# [CV] ..... leaf_size=9, score=(train=0.828, test=0.744), total=   0.2s
# [CV] leaf_size=17 ....................................................
# [CV] .... leaf_size=11, score=(train=0.828, test=0.744), total=   0.2s
# [CV] leaf_size=18 ....................................................
# [CV] .... leaf_size=12, score=(train=0.828, test=0.744), total=   0.1s[CV] .... leaf_size=10, score=(train=0.828, test=0.744), total=   0.2s[CV] .... leaf_size=13, score=(train=0.828, test=0.744), total=   0.1s
#
# [CV] leaf_size=19 ....................................................
#
# [CV] leaf_size=20 ....................................................[CV] leaf_size=21 ....................................................
#
# [CV] .... leaf_size=14, score=(train=0.828, test=0.744), total=   0.2s
# [CV] leaf_size=22 ....................................................
# [CV] .... leaf_size=15, score=(train=0.828, test=0.744), total=   0.2s
# [CV] leaf_size=23 ....................................................
# [CV] .... leaf_size=16, score=(train=0.828, test=0.744), total=   0.2s
# [CV] leaf_size=24 ....................................................
# [CV] .... leaf_size=17, score=(train=0.828, test=0.744), total=   0.1s
# [CV] leaf_size=25 ....................................................
# [CV] .... leaf_size=20, score=(train=0.828, test=0.744), total=   0.2s
# [CV] leaf_size=26 ....................................................
# [CV] .... leaf_size=19, score=(train=0.828, test=0.744), total=   0.2s[CV] .... leaf_size=18, score=(train=0.828, test=0.744), total=   0.2s[CV] .... leaf_size=22, score=(train=0.828, test=0.744), total=   0.2s[CV] .... leaf_size=23, score=(train=0.828, test=0.744), total=   0.1s
# [CV] leaf_size=27 ....................................................
#
#
# [CV] leaf_size=28 ....................................................
#
# [CV] leaf_size=29 ....................................................
# [CV] leaf_size=30 ....................................................
# [CV] .... leaf_size=21, score=(train=0.828, test=0.744), total=   0.2s
# [CV] leaf_size=31 ....................................................
# [CV] .... leaf_size=24, score=(train=0.828, test=0.744), total=   0.1s
# [CV] leaf_size=32 ....................................................
# [CV] .... leaf_size=25, score=(train=0.828, test=0.744), total=   0.1s
# [CV] leaf_size=33 ....................................................
# [CV] .... leaf_size=29, score=(train=0.828, test=0.744), total=   0.1s
# [CV] leaf_size=34 ....................................................
# [CV] .... leaf_size=30, score=(train=0.828, test=0.744), total=   0.1s
# [CV] leaf_size=35 ....................................................
# [CV] .... leaf_size=27, score=(train=0.828, test=0.744), total=   0.2s
# [CV] leaf_size=36 ....................................................
# [CV] .... leaf_size=26, score=(train=0.828, test=0.744), total=   0.2s
# [CV] leaf_size=37 ....................................................
# [CV] .... leaf_size=28, score=(train=0.828, test=0.744), total=   0.1s
# [CV] leaf_size=38 ....................................................
# [CV] .... leaf_size=31, score=(train=0.828, test=0.744), total=   0.1s
# [CV] leaf_size=39 ....................................................
# [CV] .... leaf_size=32, score=(train=0.828, test=0.744), total=   0.1s
# [CV] leaf_size=40 ....................................................
# [CV] .... leaf_size=35, score=(train=0.828, test=0.744), total=   0.1s
# [CV] leaf_size=41 ....................................................
# [CV] .... leaf_size=33, score=(train=0.828, test=0.744), total=   0.1s
# [CV] leaf_size=42 ....................................................
# [CV] .... leaf_size=36, score=(train=0.828, test=0.744), total=   0.1s
# [CV] leaf_size=43 ....................................................
# [CV] .... leaf_size=34, score=(train=0.828, test=0.744), total=   0.1s
# [CV] leaf_size=44 ....................................................
# [CV] .... leaf_size=38, score=(train=0.828, test=0.744), total=   0.1s
# [CV] leaf_size=45 ....................................................
# [CV] .... leaf_size=37, score=(train=0.828, test=0.744), total=   0.2s[CV] .... leaf_size=39, score=(train=0.828, test=0.744), total=   0.2s
#
# [CV] leaf_size=46 ....................................................
# [CV] leaf_size=47 ....................................................
# [CV] .... leaf_size=40, score=(train=0.828, test=0.744), total=   0.1s
# [CV] leaf_size=48 ....................................................
# [CV] .... leaf_size=41, score=(train=0.828, test=0.744), total=   0.2s
# [CV] leaf_size=49 ....................................................
# [CV] .... leaf_size=42, score=(train=0.828, test=0.744), total=   0.1s
# [CV] leaf_size=50 ....................................................
# [CV] .... leaf_size=43, score=(train=0.828, test=0.744), total=   0.2s
# [CV] leaf_size=51 ....................................................
# [CV] .... leaf_size=44, score=(train=0.828, test=0.744), total=   0.2s
# [CV] .... leaf_size=46, score=(train=0.828, test=0.744), total=   0.1s
# [CV] .... leaf_size=47, score=(train=0.828, test=0.744), total=   0.1s
# [CV] .... leaf_size=48, score=(train=0.828, test=0.744), total=   0.1s
# [CV] .... leaf_size=45, score=(train=0.828, test=0.744), total=   0.1s
# [CV] .... leaf_size=49, score=(train=0.828, test=0.744), total=   0.1s
# [CV] .... leaf_size=50, score=(train=0.828, test=0.744), total=   0.1s
# [CV] .... leaf_size=51, score=(train=0.828, test=0.744), total=   0.1s
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:    7.3s finished

# %%
with plt.style.context('ggplot'):
    knn_train_scores_mean = np.mean(knn_learning_curve_results["train_scores"], axis=1)
    knn_train_scores_std = np.std(knn_learning_curve_results["train_scores"], axis=1)
    knn_test_scores_mean = np.mean(knn_learning_curve_results["test_scores"], axis=1)
    knn_test_scores_std = np.std(knn_learning_curve_results["test_scores"], axis=1)
    
    fig0, ax0 = plt.subplots()
    ax0.set_xlabel("Percent of Training Set")
    ax0.set_ylabel("Accuracy (%)", color='tab:orange')
    ax0.set_title("{} {} Learning Curve".format(knn_segment, dataset))
    ax0.tick_params(axis='y', labelcolor="black")
    ax0.set_ylim(0, 1.1)

    lw = 2
    plt.plot([i for i in range(50)], knn_train_scores_mean, label="Training score",
                 color="darkorange", lw=lw)
    plt.fill_between([i for i in range(50)], knn_train_scores_mean - knn_train_scores_std,
                     knn_train_scores_mean + knn_train_scores_std, alpha=0.2,
                     color="darkorange", lw=lw)
    plt.plot([i for i in range(50)], knn_test_scores_mean, label="Testing score",
                 color="navy", lw=lw)
    plt.fill_between([i for i in range(50)], knn_test_scores_mean - knn_test_scores_std,
                     knn_test_scores_mean + knn_test_scores_std, alpha=0.2,
                     color="navy", lw=lw)
    plt.legend(loc="best")
    plt.savefig("{}_{}_Learning_Curve.png".format(knn_segment, dataset))
    plt.show()
    
plt.close("all")

# %%
with plt.style.context('ggplot'):
    knn_train_scores_mean = np.mean(knn_validation_curve_results["train_scores"], axis=1)
    knn_train_scores_std = np.std(knn_validation_curve_results["train_scores"], axis=1)
    knn_test_scores_mean = np.mean(knn_validation_curve_results["test_scores"], axis=1)
    knn_test_scores_std = np.std(knn_validation_curve_results["test_scores"], axis=1)

    plt.title("Validation Curve with {} \n {}".format(knn_segment, dataset))
    plt.xlabel("{}".format("leaf_size"))
    plt.ylabel("Score")
    plt.ylim(0.0, 1.1)
    lw = 2
    plt.plot([i for i in range(50)], knn_train_scores_mean, label="Training score",
                 color="darkorange", lw=lw)
    plt.fill_between([i for i in range(50)], knn_train_scores_mean - knn_train_scores_std,
                     knn_train_scores_mean + knn_train_scores_std, alpha=0.2,
                     color="darkorange", lw=lw)
    plt.plot([i for i in range(50)], knn_test_scores_mean, label="Cross-validation score",
                 color="navy", lw=lw)
    plt.fill_between([i for i in range(50)], knn_test_scores_mean - knn_test_scores_std,
                     knn_test_scores_mean + knn_test_scores_std, alpha=0.2,
                     color="navy", lw=lw)
    plt.legend(loc="best")
    plt.savefig("{}_{}_Validation_Curve.png".format(knn_segment, dataset))
    plt.show()

# %%
boost_segment = "Gradient Boosted Decision Trees"
boost_estimator = GradientBoostingClassifier()
boost_grid_search = GridSearchCV(boost_estimator, param_grid=boosting_params, n_jobs=n_jobs, verbose=verbose_int)
boost_learning_curve_results = {"train_sizes": None, "train_scores": None, "test_scores": None, 
                                "fit_times": None}
boost_validation_curve_results = {"train_scores": None, "test_scores": None}

# %%
with parallel_backend('threading'):
    boost_grid_search.fit(X,y)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV] learning_rate=0.1, max_depth=1, n_estimators=50 .................[CV] learning_rate=0.1, max_depth=1, n_estimators=50 .................
# [CV] learning_rate=0.1, max_depth=1, n_estimators=50 .................
# [CV] learning_rate=0.1, max_depth=1, n_estimators=50 .................
# [CV] learning_rate=0.1, max_depth=1, n_estimators=50 .................
#
# [CV] learning_rate=0.1, max_depth=1, n_estimators=100 ................
# [CV] learning_rate=0.1, max_depth=1, n_estimators=100 ................
# [CV] learning_rate=0.1, max_depth=1, n_estimators=100 ................
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [CV]  learning_rate=0.1, max_depth=1, n_estimators=50, score=0.762, total=  26.1s
# [CV] learning_rate=0.1, max_depth=1, n_estimators=100 ................
# [CV]  learning_rate=0.1, max_depth=1, n_estimators=50, score=0.802, total=  26.4s
# [CV] learning_rate=0.1, max_depth=1, n_estimators=100 ................
# [CV]  learning_rate=0.1, max_depth=1, n_estimators=50, score=0.828, total=  26.4s
# [CV] learning_rate=0.1, max_depth=1, n_estimators=150 ................
# [CV]  learning_rate=0.1, max_depth=1, n_estimators=50, score=0.762, total=  27.1s
# [CV] learning_rate=0.1, max_depth=1, n_estimators=150 ................
# [CV]  learning_rate=0.1, max_depth=1, n_estimators=50, score=0.743, total=  27.3s
# [CV] learning_rate=0.1, max_depth=1, n_estimators=150 ................
# [CV]  learning_rate=0.1, max_depth=1, n_estimators=100, score=0.750, total=  51.6s
# [CV] learning_rate=0.1, max_depth=1, n_estimators=150 ................
# [CV]  learning_rate=0.1, max_depth=1, n_estimators=100, score=0.792, total=  53.1s
# [CV] learning_rate=0.1, max_depth=1, n_estimators=150 ................
# [CV]  learning_rate=0.1, max_depth=1, n_estimators=100, score=0.848, total=  53.2s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=50 .................
# [CV]  learning_rate=0.1, max_depth=1, n_estimators=100, score=0.795, total=  51.1s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=50 .................
# [CV]  learning_rate=0.1, max_depth=1, n_estimators=100, score=0.855, total=  51.4s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=50 .................
# [CV]  learning_rate=0.1, max_depth=2, n_estimators=50, score=0.845, total=  48.5s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=50 .................
# [CV]  learning_rate=0.1, max_depth=1, n_estimators=150, score=0.855, total= 1.3min
# [CV] learning_rate=0.1, max_depth=2, n_estimators=50 .................
# [CV]  learning_rate=0.1, max_depth=1, n_estimators=150, score=0.818, total= 1.3min
# [CV] learning_rate=0.1, max_depth=2, n_estimators=100 ................
# [CV]  learning_rate=0.1, max_depth=1, n_estimators=150, score=0.782, total= 1.3min
# [CV] learning_rate=0.1, max_depth=2, n_estimators=100 ................
# [CV]  learning_rate=0.1, max_depth=2, n_estimators=50, score=0.838, total=  46.2s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=100 ................
# [CV]  learning_rate=0.1, max_depth=2, n_estimators=50, score=0.805, total=  46.1s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=100 ................
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  2.1min
# [CV]  learning_rate=0.1, max_depth=1, n_estimators=150, score=0.802, total= 1.3min
# [CV] learning_rate=0.1, max_depth=2, n_estimators=100 ................
# [CV]  learning_rate=0.1, max_depth=1, n_estimators=150, score=0.873, total= 1.3min
# [CV] learning_rate=0.1, max_depth=2, n_estimators=150 ................
# [CV]  learning_rate=0.1, max_depth=2, n_estimators=50, score=0.812, total=  46.8s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=150 ................
# [CV]  learning_rate=0.1, max_depth=2, n_estimators=50, score=0.853, total=  45.9s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=150 ................
# [CV]  learning_rate=0.1, max_depth=2, n_estimators=100, score=0.868, total= 1.5min
# [CV] learning_rate=0.1, max_depth=2, n_estimators=150 ................
# [CV]  learning_rate=0.1, max_depth=2, n_estimators=100, score=0.873, total= 1.6min
# [CV] learning_rate=0.1, max_depth=2, n_estimators=150 ................
# [CV]  learning_rate=0.1, max_depth=2, n_estimators=100, score=0.820, total= 1.5min
# [CV] learning_rate=0.1, max_depth=3, n_estimators=50 .................
# [CV]  learning_rate=0.1, max_depth=2, n_estimators=100, score=0.838, total= 1.5min
# [CV] learning_rate=0.1, max_depth=3, n_estimators=50 .................
# [CV]  learning_rate=0.1, max_depth=2, n_estimators=100, score=0.882, total= 1.5min
# [CV] learning_rate=0.1, max_depth=3, n_estimators=50 .................
# [CV]  learning_rate=0.1, max_depth=2, n_estimators=150, score=0.875, total= 2.3min
# [CV] learning_rate=0.1, max_depth=3, n_estimators=50 .................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=50, score=0.892, total= 1.1min
# [CV] learning_rate=0.1, max_depth=3, n_estimators=50 .................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=50, score=0.850, total= 1.1min
# [CV] learning_rate=0.1, max_depth=3, n_estimators=100 ................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=50, score=0.810, total= 1.1min
# [CV] learning_rate=0.1, max_depth=3, n_estimators=100 ................
# [CV]  learning_rate=0.1, max_depth=2, n_estimators=150, score=0.818, total= 2.3min
# [CV] learning_rate=0.1, max_depth=3, n_estimators=100 ................
# [CV]  learning_rate=0.1, max_depth=2, n_estimators=150, score=0.870, total= 2.3min
# [CV] learning_rate=0.1, max_depth=3, n_estimators=100 ................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=50, score=0.830, total= 1.2min
# [CV] learning_rate=0.1, max_depth=3, n_estimators=100 ................
# [CV]  learning_rate=0.1, max_depth=2, n_estimators=150, score=0.835, total= 2.4min
# [CV] learning_rate=0.1, max_depth=3, n_estimators=150 ................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=50, score=0.863, total= 1.1min
# [CV] learning_rate=0.1, max_depth=3, n_estimators=150 ................
# [CV]  learning_rate=0.1, max_depth=2, n_estimators=150, score=0.885, total= 2.4min
# [CV] learning_rate=0.1, max_depth=3, n_estimators=150 ................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=100, score=0.895, total= 2.2min
# [CV] learning_rate=0.1, max_depth=3, n_estimators=150 ................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=100, score=0.873, total= 2.2min
# [CV] learning_rate=0.1, max_depth=3, n_estimators=150 ................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=100, score=0.840, total= 2.2min
# [CV] learning_rate=0.01, max_depth=1, n_estimators=50 ................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=100, score=0.853, total= 2.3min
# [CV] learning_rate=0.01, max_depth=1, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=1, n_estimators=50, score=0.590, total=  24.7s
# [CV] learning_rate=0.01, max_depth=1, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=1, n_estimators=50, score=0.485, total=  24.9s
# [CV] learning_rate=0.01, max_depth=1, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=1, n_estimators=50, score=0.475, total=  24.6s
# [CV] learning_rate=0.01, max_depth=1, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=1, n_estimators=50, score=0.545, total=  24.7s
# [CV] learning_rate=0.01, max_depth=1, n_estimators=100 ...............
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=100, score=0.895, total= 2.2min
# [CV] learning_rate=0.01, max_depth=1, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=1, n_estimators=50, score=0.557, total=  24.6s
# [CV] learning_rate=0.01, max_depth=1, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=1, n_estimators=100, score=0.642, total=  49.7s
# [CV] learning_rate=0.01, max_depth=1, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=1, n_estimators=100, score=0.552, total=  49.8s
# [CV] learning_rate=0.01, max_depth=1, n_estimators=100 ...............
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=150, score=0.882, total= 3.2min
# [CV] learning_rate=0.01, max_depth=1, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=1, n_estimators=100, score=0.575, total=  49.3s
# [CV] learning_rate=0.01, max_depth=1, n_estimators=150 ...............
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=150, score=0.848, total= 3.3min
# [CV] learning_rate=0.01, max_depth=1, n_estimators=150 ...............
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=150, score=0.897, total= 3.3min
# [CV] learning_rate=0.01, max_depth=1, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=1, n_estimators=100, score=0.620, total=  50.9s
# [CV] learning_rate=0.01, max_depth=1, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=1, n_estimators=100, score=0.637, total=  51.2s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=50 ................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=150, score=0.858, total= 3.2min
# [CV] learning_rate=0.01, max_depth=2, n_estimators=50 ................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=150, score=0.910, total= 3.2min
# [CV] learning_rate=0.01, max_depth=2, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=1, n_estimators=150, score=0.690, total= 1.3min
# [CV] learning_rate=0.01, max_depth=2, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=1, n_estimators=150, score=0.623, total= 1.2min
# [CV] learning_rate=0.01, max_depth=2, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=1, n_estimators=150, score=0.642, total= 1.3min
# [CV] learning_rate=0.01, max_depth=2, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=1, n_estimators=150, score=0.688, total= 1.3min
# [CV] learning_rate=0.01, max_depth=2, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=50, score=0.695, total=  46.0s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=50, score=0.645, total=  45.0s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=1, n_estimators=150, score=0.670, total= 1.3min
# [CV] learning_rate=0.01, max_depth=2, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=50, score=0.632, total=  44.9s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=50, score=0.650, total=  44.8s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=50, score=0.725, total=  45.2s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=100, score=0.733, total= 1.5min
# [CV] learning_rate=0.01, max_depth=2, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=100, score=0.710, total= 1.5min
# [CV] learning_rate=0.01, max_depth=2, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=100, score=0.708, total= 1.5min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=100, score=0.710, total= 1.5min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=100, score=0.780, total= 1.6min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=50, score=0.757, total= 1.1min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=150, score=0.767, total= 2.3min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=150, score=0.760, total= 2.3min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=150, score=0.730, total= 2.3min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=50, score=0.705, total= 1.1min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=50, score=0.703, total= 1.1min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=50, score=0.720, total= 1.1min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=150, score=0.738, total= 2.3min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=150, score=0.792, total= 2.3min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=50, score=0.797, total= 1.1min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=100, score=0.797, total= 2.1min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=100, score=0.775, total= 2.1min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=100, score=0.750, total= 2.1min
# [CV] learning_rate=0.001, max_depth=1, n_estimators=50 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=100, score=0.757, total= 2.1min
# [CV] learning_rate=0.001, max_depth=1, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=1, n_estimators=50, score=0.390, total=  24.6s
# [CV] learning_rate=0.001, max_depth=1, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=1, n_estimators=50, score=0.365, total=  25.1s
# [CV] learning_rate=0.001, max_depth=1, n_estimators=50 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=100, score=0.820, total= 2.1min
# [CV] learning_rate=0.001, max_depth=1, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=1, n_estimators=50, score=0.383, total=  24.6s
# [CV] learning_rate=0.001, max_depth=1, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=1, n_estimators=50, score=0.393, total=  25.4s
# [CV] learning_rate=0.001, max_depth=1, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=1, n_estimators=50, score=0.388, total=  25.4s
# [CV] learning_rate=0.001, max_depth=1, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=1, n_estimators=100, score=0.485, total=  49.0s
# [CV] learning_rate=0.001, max_depth=1, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=1, n_estimators=100, score=0.380, total=  48.2s
# [CV] learning_rate=0.001, max_depth=1, n_estimators=100 ..............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=150, score=0.825, total= 3.2min
# [CV] learning_rate=0.001, max_depth=1, n_estimators=150 ..............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=150, score=0.838, total= 3.2min
# [CV] learning_rate=0.001, max_depth=1, n_estimators=150 ..............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=150, score=0.775, total= 3.1min
# [CV] learning_rate=0.001, max_depth=1, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=1, n_estimators=100, score=0.405, total=  47.3s
# [CV] learning_rate=0.001, max_depth=1, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=1, n_estimators=100, score=0.460, total=  49.4s
# [CV] learning_rate=0.001, max_depth=1, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=1, n_estimators=100, score=0.453, total=  50.4s
# [CV] learning_rate=0.001, max_depth=2, n_estimators=50 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=150, score=0.792, total= 3.1min
# [CV] learning_rate=0.001, max_depth=2, n_estimators=50 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=150, score=0.838, total= 3.1min
# [CV] learning_rate=0.001, max_depth=2, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=1, n_estimators=150, score=0.497, total= 1.3min
# [CV] learning_rate=0.001, max_depth=2, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=1, n_estimators=150, score=0.405, total= 1.3min
# [CV] learning_rate=0.001, max_depth=2, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=1, n_estimators=150, score=0.410, total= 1.2min
# [CV] learning_rate=0.001, max_depth=2, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=1, n_estimators=150, score=0.470, total= 1.3min
# [CV] learning_rate=0.001, max_depth=2, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=2, n_estimators=50, score=0.568, total=  45.8s
# [CV] learning_rate=0.001, max_depth=2, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=2, n_estimators=50, score=0.505, total=  45.0s
# [CV] learning_rate=0.001, max_depth=2, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=1, n_estimators=150, score=0.507, total= 1.2min
# [CV] learning_rate=0.001, max_depth=2, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=2, n_estimators=50, score=0.510, total=  45.2s
# [CV] learning_rate=0.001, max_depth=2, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=2, n_estimators=50, score=0.490, total=  45.5s
# [CV] learning_rate=0.001, max_depth=2, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=2, n_estimators=50, score=0.502, total=  45.7s
# [CV] learning_rate=0.001, max_depth=2, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=2, n_estimators=100, score=0.575, total= 1.5min
# [CV] learning_rate=0.001, max_depth=2, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=2, n_estimators=100, score=0.540, total= 1.5min
# [CV] learning_rate=0.001, max_depth=2, n_estimators=150 ..............
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed: 20.2min
# [CV]  learning_rate=0.001, max_depth=2, n_estimators=100, score=0.530, total= 1.5min
# [CV] learning_rate=0.001, max_depth=3, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=2, n_estimators=100, score=0.542, total= 1.5min
# [CV] learning_rate=0.001, max_depth=3, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=2, n_estimators=100, score=0.603, total= 1.5min
# [CV] learning_rate=0.001, max_depth=3, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=50, score=0.620, total= 1.1min
# [CV] learning_rate=0.001, max_depth=3, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=2, n_estimators=150, score=0.600, total= 2.3min
# [CV] learning_rate=0.001, max_depth=3, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=2, n_estimators=150, score=0.540, total= 2.3min
# [CV] learning_rate=0.001, max_depth=3, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=2, n_estimators=150, score=0.552, total= 2.3min
# [CV] learning_rate=0.001, max_depth=3, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=50, score=0.562, total= 1.1min
# [CV] learning_rate=0.001, max_depth=3, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=50, score=0.552, total= 1.1min
# [CV] learning_rate=0.001, max_depth=3, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=2, n_estimators=150, score=0.562, total= 2.2min
# [CV] learning_rate=0.001, max_depth=3, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=2, n_estimators=150, score=0.642, total= 2.3min
# [CV] learning_rate=0.001, max_depth=3, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=50, score=0.615, total= 1.1min
# [CV] learning_rate=0.001, max_depth=3, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=50, score=0.632, total= 1.1min
# [CV] learning_rate=0.001, max_depth=3, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=100, score=0.598, total= 2.1min
# [CV] learning_rate=0.001, max_depth=3, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=100, score=0.657, total= 2.2min
# [CV] learning_rate=0.001, max_depth=3, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=100, score=0.583, total= 2.1min
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=100, score=0.640, total= 2.1min
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=100, score=0.693, total= 2.1min
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=150, score=0.608, total= 2.7min
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=150, score=0.610, total= 2.8min
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=150, score=0.672, total= 2.8min
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=150, score=0.735, total= 2.2min
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=150, score=0.667, total= 2.2min
# [Parallel(n_jobs=-1)]: Done 135 out of 135 | elapsed: 25.9min finished

# %%
with parallel_backend('threading'):    
    boost_learning_curve_results["train_sizes"], boost_learning_curve_results["train_scores"], boost_learning_curve_results["test_scores"], boost_learning_curve_results["fit_times"], _ = learning_curve(boost_grid_search.best_estimator_, X, y, cv=2, verbose=3, n_jobs=n_jobs, train_sizes=train_sizes, return_times=True)
# Out:
# [learning_curve] Training set sizes: [ 100  118  136  155  173  191  210  228  246  265  283  302  320  338
#   357  375  393  412  430  448  467  485  504  522  540  559  577  595
#   614  632  651  669  687  706  724  742  761  779  797  816  834  853
#   871  889  908  926  944  963  981 1000]
# [CV]  ................................................................
# [CV]  ................................................................
# [CV]  ................................................................
# [CV]  ................................................................
# [CV]  ................................................................
# [CV]  ................................................................
# [CV]  ................................................................
# [CV]  ................................................................
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [CV] ................ , score=(train=1.000, test=0.445), total=   4.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.493), total=   6.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.480), total=   7.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.513), total=   9.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.551), total=  10.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.569), total=  11.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.610), total=  14.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.632), total=  14.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.652), total=  15.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.682), total=  18.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.690), total=  20.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.710), total=  21.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.725), total=  24.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.721), total=  26.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.757), total=  27.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.747), total=  30.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.751), total=  33.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.765), total=  34.9s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.788), total=  40.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.791), total=  42.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.790), total=  47.2s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.814), total=  50.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.811), total=  56.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.822), total= 1.0min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.814), total= 1.1min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.816), total= 1.2min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.824), total= 1.2min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.819), total= 1.2min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.831), total= 1.3min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.832), total= 1.3min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.821), total= 1.2min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.827), total= 1.3min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.822), total= 1.4min
# [CV]  ................................................................
# [Parallel(n_jobs=-1)]: Done  33 out of 100 | elapsed:  3.3min remaining:  6.8min
# [CV] ................ , score=(train=1.000, test=0.823), total= 1.4min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.825), total= 1.4min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.818), total= 1.5min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.824), total= 1.5min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.840), total= 1.6min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.837), total= 1.8min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.844), total= 1.8min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.846), total= 1.8min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.850), total= 1.8min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.850), total= 1.9min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.494), total=   5.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.524), total=   4.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.850), total= 2.0min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.517), total=   6.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.569), total=   8.1s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.592), total=   9.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.590), total=  11.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.851), total= 2.1min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.614), total=  13.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.854), total= 2.1min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.635), total=  14.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.646), total=  14.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.671), total=  17.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.853), total= 2.2min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.691), total=  20.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.686), total=  22.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.701), total=  25.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.717), total=  26.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.853), total= 2.2min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.722), total=  28.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.727), total=  30.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.747), total=  31.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.852), total= 2.3min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.739), total=  33.5s
# [CV]  ................................................................
# [Parallel(n_jobs=-1)]: Done  67 out of 100 | elapsed:  7.5min remaining:  3.7min
# [CV] ................ , score=(train=1.000, test=0.757), total=  36.8s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.860), total= 2.3min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.759), total=  40.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.760), total=  40.4s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.767), total=  42.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.792), total=  48.0s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.787), total=  50.3s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.788), total=  51.5s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.783), total=  58.6s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.795), total=  58.7s
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.807), total= 1.1min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.797), total= 1.1min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.805), total= 1.2min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.821), total= 1.2min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.821), total= 1.3min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.822), total= 1.3min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.817), total= 1.5min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.811), total= 1.4min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.810), total= 1.5min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.817), total= 1.6min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.817), total= 1.6min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.823), total= 1.7min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.819), total= 1.7min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.830), total= 1.8min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.825), total= 1.8min
# [CV]  ................................................................
# [CV] ................ , score=(train=1.000, test=0.825), total= 1.9min
# [CV] ................ , score=(train=1.000, test=0.830), total= 1.9min
# [CV] ................ , score=(train=1.000, test=0.841), total= 1.8min
# [CV] ................ , score=(train=1.000, test=0.844), total= 1.8min
# [CV] ................ , score=(train=1.000, test=0.834), total= 1.8min
# [CV] ................ , score=(train=1.000, test=0.838), total= 1.7min
# [CV] ................ , score=(train=1.000, test=0.840), total= 1.6min
# [CV] ................ , score=(train=1.000, test=0.842), total= 1.4min
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed: 13.3min finished

# %%
with parallel_backend('threading'):    
    boost_validation_curve_results["train_scores"], boost_validation_curve_results["test_scores"] = validation_curve(boost_grid_search.best_estimator_, X=Validation_X, y=validation_y, n_jobs=n_jobs, cv=2, param_name="max_leaf_nodes", verbose=3, param_range=[i for i in range(1, 50)])

plt.close("all")
# Out:
# [CV] max_leaf_nodes=1 ................................................
# [CV] max_leaf_nodes=2 ................................................
# [CV] max_leaf_nodes=3 ................................................[CV] max_leaf_nodes=4 ................................................
# [CV] max_leaf_nodes=5 ................................................
# [CV] max_leaf_nodes=6 ................................................
# [CV] max_leaf_nodes=7 ................................................
# [CV] max_leaf_nodes=8 ................................................
#
# [CV] .... max_leaf_nodes=1, score=(train=nan, test=nan), total=   0.0s
# [CV] max_leaf_nodes=9 ................................................
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# C:\Users\joshu\Anaconda3\envs\CS7641\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: max_leaf_nodes 1 must be either None or larger than 1
#
#   FitFailedWarning)
# [CV]  max_leaf_nodes=7, score=(train=1.000, test=0.570), total=  10.2s
# [CV] max_leaf_nodes=10 ...............................................
# [CV]  max_leaf_nodes=8, score=(train=1.000, test=0.585), total=  10.3s
# [CV] max_leaf_nodes=11 ...............................................
# [CV]  max_leaf_nodes=9, score=(train=1.000, test=0.560), total=  10.5s
# [CV] max_leaf_nodes=12 ...............................................
# [CV]  max_leaf_nodes=6, score=(train=1.000, test=0.565), total=  10.5s
# [CV] max_leaf_nodes=13 ...............................................
# [CV]  max_leaf_nodes=5, score=(train=1.000, test=0.575), total=  10.8s
# [CV] max_leaf_nodes=14 ...............................................
# [CV]  max_leaf_nodes=4, score=(train=1.000, test=0.620), total=  11.5s
# [CV] max_leaf_nodes=15 ...............................................
# [CV]  max_leaf_nodes=2, score=(train=1.000, test=0.625), total=  13.1s
# [CV] max_leaf_nodes=16 ...............................................
# [CV]  max_leaf_nodes=3, score=(train=1.000, test=0.660), total=  14.6s
# [CV] max_leaf_nodes=17 ...............................................
# [CV]  max_leaf_nodes=10, score=(train=1.000, test=0.575), total=  10.3s
# [CV] max_leaf_nodes=18 ...............................................
# [CV]  max_leaf_nodes=11, score=(train=1.000, test=0.600), total=  10.5s
# [CV] max_leaf_nodes=19 ...............................................
# [CV]  max_leaf_nodes=12, score=(train=1.000, test=0.560), total=  10.7s
# [CV] max_leaf_nodes=20 ...............................................
# [CV]  max_leaf_nodes=13, score=(train=1.000, test=0.565), total=  10.7s
# [CV] max_leaf_nodes=21 ...............................................
# [CV]  max_leaf_nodes=14, score=(train=1.000, test=0.585), total=  10.7s
# [CV] max_leaf_nodes=22 ...............................................
# [CV]  max_leaf_nodes=15, score=(train=1.000, test=0.575), total=  10.5s
# [CV] max_leaf_nodes=23 ...............................................
# [CV]  max_leaf_nodes=16, score=(train=1.000, test=0.575), total=  10.4s
# [CV] max_leaf_nodes=24 ...............................................
# [CV]  max_leaf_nodes=17, score=(train=1.000, test=0.575), total=  10.1s
# [CV] max_leaf_nodes=25 ...............................................
# [CV]  max_leaf_nodes=18, score=(train=1.000, test=0.585), total=  10.2s
# [CV] max_leaf_nodes=26 ...............................................
# [CV]  max_leaf_nodes=19, score=(train=1.000, test=0.565), total=  10.5s
# [CV] max_leaf_nodes=27 ...............................................
# [CV]  max_leaf_nodes=21, score=(train=1.000, test=0.555), total=  10.5s
# [CV] max_leaf_nodes=28 ...............................................
# [CV]  max_leaf_nodes=20, score=(train=1.000, test=0.580), total=  10.7s
# [CV] max_leaf_nodes=29 ...............................................
# [CV]  max_leaf_nodes=22, score=(train=1.000, test=0.580), total=  10.7s
# [CV] max_leaf_nodes=30 ...............................................
# [CV]  max_leaf_nodes=23, score=(train=1.000, test=0.570), total=  10.7s
# [CV] max_leaf_nodes=31 ...............................................
# [CV]  max_leaf_nodes=24, score=(train=1.000, test=0.560), total=  10.3s
# [CV] max_leaf_nodes=32 ...............................................
# [CV]  max_leaf_nodes=25, score=(train=1.000, test=0.560), total=  10.0s
# [CV] max_leaf_nodes=33 ...............................................
# [CV]  max_leaf_nodes=26, score=(train=1.000, test=0.575), total=  10.2s
# [CV] max_leaf_nodes=34 ...............................................
# [CV]  max_leaf_nodes=27, score=(train=1.000, test=0.590), total=  10.5s
# [CV] max_leaf_nodes=35 ...............................................
# [CV]  max_leaf_nodes=28, score=(train=1.000, test=0.560), total=  10.5s
# [CV] max_leaf_nodes=36 ...............................................
# [CV]  max_leaf_nodes=29, score=(train=1.000, test=0.580), total=  10.7s
# [CV] max_leaf_nodes=37 ...............................................
# [CV]  max_leaf_nodes=30, score=(train=1.000, test=0.560), total=  10.6s
# [CV] max_leaf_nodes=38 ...............................................
# [CV]  max_leaf_nodes=31, score=(train=1.000, test=0.590), total=  10.6s
# [CV] max_leaf_nodes=39 ...............................................
# [CV]  max_leaf_nodes=32, score=(train=1.000, test=0.580), total=  10.5s
# [CV] max_leaf_nodes=40 ...............................................
# [CV]  max_leaf_nodes=33, score=(train=1.000, test=0.590), total=  10.1s
# [CV] max_leaf_nodes=41 ...............................................
# [Parallel(n_jobs=-1)]: Done  33 out of  98 | elapsed:   44.9s remaining:  1.5min
# [CV]  max_leaf_nodes=34, score=(train=1.000, test=0.590), total=  10.1s
# [CV] max_leaf_nodes=42 ...............................................
# [CV]  max_leaf_nodes=35, score=(train=1.000, test=0.580), total=  10.7s
# [CV] max_leaf_nodes=43 ...............................................
# [CV]  max_leaf_nodes=36, score=(train=1.000, test=0.575), total=  10.7s
# [CV] max_leaf_nodes=44 ...............................................
# [CV]  max_leaf_nodes=38, score=(train=1.000, test=0.580), total=  10.7s
# [CV] max_leaf_nodes=45 ...............................................
# [CV]  max_leaf_nodes=37, score=(train=1.000, test=0.590), total=  10.9s
# [CV] max_leaf_nodes=46 ...............................................
# [CV]  max_leaf_nodes=39, score=(train=1.000, test=0.575), total=  10.6s
# [CV] max_leaf_nodes=47 ...............................................
# [CV]  max_leaf_nodes=40, score=(train=1.000, test=0.585), total=  10.8s
# [CV] max_leaf_nodes=48 ...............................................
# [CV]  max_leaf_nodes=41, score=(train=1.000, test=0.580), total=  10.5s
# [CV] max_leaf_nodes=49 ...............................................
# [CV]  max_leaf_nodes=42, score=(train=1.000, test=0.580), total=  10.2s
# [CV] max_leaf_nodes=1 ................................................
# [CV] .... max_leaf_nodes=1, score=(train=nan, test=nan), total=   0.0s
# [CV] max_leaf_nodes=2 ................................................
# C:\Users\joshu\Anaconda3\envs\CS7641\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: max_leaf_nodes 1 must be either None or larger than 1
#
#   FitFailedWarning)
# [CV]  max_leaf_nodes=43, score=(train=1.000, test=0.555), total=  11.7s
# [CV] max_leaf_nodes=3 ................................................
# [CV]  max_leaf_nodes=44, score=(train=1.000, test=0.570), total=  11.6s
# [CV] max_leaf_nodes=4 ................................................
# [CV]  max_leaf_nodes=46, score=(train=1.000, test=0.565), total=  12.0s
# [CV] max_leaf_nodes=5 ................................................
# [CV]  max_leaf_nodes=45, score=(train=1.000, test=0.590), total=  12.2s
# [CV] max_leaf_nodes=6 ................................................
# [CV]  max_leaf_nodes=47, score=(train=1.000, test=0.580), total=  12.1s
# [CV] max_leaf_nodes=7 ................................................
# [CV]  max_leaf_nodes=48, score=(train=1.000, test=0.570), total=  11.9s
# [CV] max_leaf_nodes=8 ................................................
# [CV]  max_leaf_nodes=49, score=(train=1.000, test=0.575), total=  11.7s
# [CV] max_leaf_nodes=9 ................................................
# [CV]  max_leaf_nodes=2, score=(train=1.000, test=0.620), total=  15.4s
# [CV] max_leaf_nodes=10 ...............................................
# [CV]  max_leaf_nodes=6, score=(train=1.000, test=0.635), total=  13.9s
# [CV] max_leaf_nodes=11 ...............................................
# [CV]  max_leaf_nodes=7, score=(train=1.000, test=0.620), total=  13.5s
# [CV] max_leaf_nodes=12 ...............................................
# [CV]  max_leaf_nodes=5, score=(train=1.000, test=0.625), total=  14.8s
# [CV] max_leaf_nodes=13 ...............................................
# [CV]  max_leaf_nodes=8, score=(train=1.000, test=0.615), total=  13.3s
# [CV] max_leaf_nodes=14 ...............................................
# [CV]  max_leaf_nodes=9, score=(train=1.000, test=0.600), total=  13.5s
# [CV] max_leaf_nodes=15 ...............................................
# [CV]  max_leaf_nodes=4, score=(train=1.000, test=0.635), total=  16.2s
# [CV] max_leaf_nodes=16 ...............................................
# [CV]  max_leaf_nodes=3, score=(train=1.000, test=0.630), total=  18.4s
# [CV] max_leaf_nodes=17 ...............................................
# [CV]  max_leaf_nodes=10, score=(train=1.000, test=0.625), total=  11.7s
# [CV] max_leaf_nodes=18 ...............................................
# [CV]  max_leaf_nodes=12, score=(train=1.000, test=0.605), total=  12.3s
# [CV] max_leaf_nodes=19 ...............................................
# [CV]  max_leaf_nodes=11, score=(train=1.000, test=0.620), total=  12.6s
# [CV] max_leaf_nodes=20 ...............................................
# [CV]  max_leaf_nodes=14, score=(train=1.000, test=0.605), total=  12.6s
# [CV] max_leaf_nodes=21 ...............................................
# [CV]  max_leaf_nodes=13, score=(train=1.000, test=0.615), total=  13.0s
# [CV] max_leaf_nodes=22 ...............................................
# [CV]  max_leaf_nodes=15, score=(train=1.000, test=0.620), total=  13.1s
# [CV] max_leaf_nodes=23 ...............................................
# [CV]  max_leaf_nodes=16, score=(train=1.000, test=0.625), total=  12.9s
# [CV] max_leaf_nodes=24 ...............................................
# [CV]  max_leaf_nodes=17, score=(train=1.000, test=0.625), total=  12.1s
# [CV] max_leaf_nodes=25 ...............................................
# [Parallel(n_jobs=-1)]: Done  66 out of  98 | elapsed:  1.6min remaining:   46.0s
# [CV]  max_leaf_nodes=18, score=(train=1.000, test=0.630), total=  11.4s
# [CV] max_leaf_nodes=26 ...............................................
# [CV]  max_leaf_nodes=19, score=(train=1.000, test=0.620), total=  12.4s
# [CV] max_leaf_nodes=27 ...............................................
# [CV]  max_leaf_nodes=20, score=(train=1.000, test=0.615), total=  12.5s
# [CV] max_leaf_nodes=28 ...............................................
# [CV]  max_leaf_nodes=21, score=(train=1.000, test=0.610), total=  13.0s
# [CV] max_leaf_nodes=29 ...............................................
# [CV]  max_leaf_nodes=22, score=(train=1.000, test=0.615), total=  13.0s
# [CV] max_leaf_nodes=30 ...............................................
# [CV]  max_leaf_nodes=23, score=(train=1.000, test=0.640), total=  13.0s
# [CV] max_leaf_nodes=31 ...............................................
# [CV]  max_leaf_nodes=24, score=(train=1.000, test=0.630), total=  13.0s
# [CV] max_leaf_nodes=32 ...............................................
# [CV]  max_leaf_nodes=25, score=(train=1.000, test=0.625), total=  12.6s
# [CV] max_leaf_nodes=33 ...............................................
# [CV]  max_leaf_nodes=26, score=(train=1.000, test=0.615), total=  11.8s
# [CV] max_leaf_nodes=34 ...............................................
# [CV]  max_leaf_nodes=27, score=(train=1.000, test=0.615), total=  12.4s
# [CV] max_leaf_nodes=35 ...............................................
# [CV]  max_leaf_nodes=28, score=(train=1.000, test=0.620), total=  12.6s
# [CV] max_leaf_nodes=36 ...............................................
# [CV]  max_leaf_nodes=29, score=(train=1.000, test=0.595), total=  12.9s
# [CV] max_leaf_nodes=37 ...............................................
# [CV]  max_leaf_nodes=32, score=(train=1.000, test=0.620), total=  12.4s
# [CV] max_leaf_nodes=38 ...............................................
# [CV]  max_leaf_nodes=30, score=(train=1.000, test=0.620), total=  13.0s
# [CV] max_leaf_nodes=39 ...............................................
# [CV]  max_leaf_nodes=31, score=(train=1.000, test=0.600), total=  12.6s
# [CV] max_leaf_nodes=40 ...............................................
# [CV]  max_leaf_nodes=33, score=(train=1.000, test=0.615), total=  12.3s
# [CV] max_leaf_nodes=41 ...............................................
# [CV]  max_leaf_nodes=34, score=(train=1.000, test=0.620), total=  10.7s
# [CV] max_leaf_nodes=42 ...............................................
# [CV]  max_leaf_nodes=35, score=(train=1.000, test=0.620), total=  10.6s
# [CV] max_leaf_nodes=43 ...............................................
# [CV]  max_leaf_nodes=36, score=(train=1.000, test=0.620), total=  10.8s
# [CV] max_leaf_nodes=44 ...............................................
# [CV]  max_leaf_nodes=37, score=(train=1.000, test=0.625), total=  11.1s
# [CV] max_leaf_nodes=45 ...............................................
# [CV]  max_leaf_nodes=38, score=(train=1.000, test=0.610), total=  10.9s
# [CV] max_leaf_nodes=46 ...............................................
# [CV]  max_leaf_nodes=40, score=(train=1.000, test=0.605), total=  11.1s
# [CV] max_leaf_nodes=47 ...............................................
# [CV]  max_leaf_nodes=39, score=(train=1.000, test=0.600), total=  11.2s
# [CV] max_leaf_nodes=48 ...............................................
# [CV]  max_leaf_nodes=41, score=(train=1.000, test=0.620), total=  10.9s
# [CV] max_leaf_nodes=49 ...............................................
# [CV]  max_leaf_nodes=42, score=(train=1.000, test=0.620), total=  10.3s
# [CV]  max_leaf_nodes=43, score=(train=1.000, test=0.625), total=   9.8s
# [CV]  max_leaf_nodes=44, score=(train=1.000, test=0.620), total=   9.9s
# [CV]  max_leaf_nodes=46, score=(train=1.000, test=0.625), total=   9.6s
# [CV]  max_leaf_nodes=45, score=(train=1.000, test=0.620), total=   9.9s
# [CV]  max_leaf_nodes=47, score=(train=1.000, test=0.630), total=   9.5s
# [CV]  max_leaf_nodes=48, score=(train=1.000, test=0.605), total=   9.6s
# [CV]  max_leaf_nodes=49, score=(train=1.000, test=0.620), total=   9.3s
# [Parallel(n_jobs=-1)]: Done  98 out of  98 | elapsed:  2.3min finished

# %%
with plt.style.context('ggplot'):
    boost_train_scores_mean = np.mean(boost_learning_curve_results["train_scores"], axis=1)
    boost_train_scores_std = np.std(boost_learning_curve_results["train_scores"], axis=1)
    boost_test_scores_mean = np.mean(boost_learning_curve_results["test_scores"], axis=1)
    boost_test_scores_std = np.std(boost_learning_curve_results["test_scores"], axis=1)
    
    fig0, ax0 = plt.subplots()
    ax0.set_xlabel("Percent of Training Set")
    ax0.set_ylabel("Accuracy (%)", color='tab:orange')
    ax0.set_title("{} {} Learning Curve".format(boost_segment, dataset))
    ax0.tick_params(axis='y', labelcolor="black")
    ax0.set_ylim(0, 1.1)

    lw = 2
    plt.plot([i for i in range(50)], boost_train_scores_mean, label="Training score",
                 color="darkorange", lw=lw)
    plt.fill_between([i for i in range(50)], boost_train_scores_mean - boost_train_scores_std,
                     boost_train_scores_mean + boost_train_scores_std, alpha=0.2,
                     color="darkorange", lw=lw)
    plt.plot([i for i in range(50)], boost_test_scores_mean, label="Testing score",
                 color="navy", lw=lw)
    plt.fill_between([i for i in range(50)], boost_test_scores_mean - boost_test_scores_std,
                     boost_test_scores_mean + boost_test_scores_std, alpha=0.2,
                     color="navy", lw=lw)
    plt.legend(loc="best")
    plt.savefig("{}_{}_Learning_Curve.png".format(boost_segment, dataset))
    plt.show()
    
plt.close("all")

# %%
with plt.style.context('ggplot'):
    boost_train_scores_mean = np.mean(boost_validation_curve_results["train_scores"], axis=1)
    boost_train_scores_std = np.std(boost_validation_curve_results["train_scores"], axis=1)
    boost_test_scores_mean = np.mean(boost_validation_curve_results["test_scores"], axis=1)
    boost_test_scores_std = np.std(boost_validation_curve_results["test_scores"], axis=1)

    plt.title("Validation Curve with {}\n {}".format(boost_segment, dataset))
    plt.xlabel("{}".format("max_leaf_nodes"))
    plt.ylabel("Score")
    plt.ylim(0.0, 1.1)
    lw = 2
    plt.plot([i for i in range(49)], boost_train_scores_mean, label="Training score",
                 color="darkorange", lw=lw)
    plt.fill_between([i for i in range(49)], boost_train_scores_mean - boost_train_scores_std,
                     boost_train_scores_mean + boost_train_scores_std, alpha=0.2,
                     color="darkorange", lw=lw)
    plt.plot([i for i in range(49)], boost_test_scores_mean, label="Cross-validation score",
                 color="navy", lw=lw)
    plt.fill_between([i for i in range(49)], boost_test_scores_mean - boost_test_scores_std,
                     boost_test_scores_mean + boost_test_scores_std, alpha=0.2,
                     color="navy", lw=lw)
    plt.legend(loc="best")
    plt.savefig("{}_{}_Validation_Curve.png".format(boost_segment, dataset))
    plt.show()
