# %%
import os
import pathlib
import sys
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import datetime
from timeit import default_timer as timer

from LoadData import LoadData

import os
import sys
from datetime import datetime

import matplotlib.pyplot as plt
import pandas as pd
from sklearn import metrics, svm
from sklearn.metrics import classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.tree._tree import TREE_LEAF

from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier

from sklearn.preprocessing import StandardScaler
from sklearn.utils import parallel_backend


TESTING = True
DECISION_TREE = False
SUPPORT_VECTOR = True
NEURAL_NET = False
K_NEAREST = False
BOOSTING = False
NORMALIZE_DATA = False
USE_PCA = True
DataSetName = "MNIST"

# %%
cwd = pathlib.Path().absolute()
training_data_path = "{}/mnist-train-data.csv".format(cwd)
testing_data_path = "{}/mnist-test-data.csv".format(cwd)

with parallel_backend('threading'):
    training_labels, training_data, _ = LoadData(training_data_path, normalize=NORMALIZE_DATA)
    testing_labels, testing_data, _ = LoadData(testing_data_path, normalize=NORMALIZE_DATA)

Scaler = StandardScaler().fit(training_data)
        
training_data = Scaler.transform(training_data)
testing_data = Scaler.transform(testing_data)
# Out:
# Attempting to load: mnist-train-data.csv
#
# Loading Complete
# Data Statistics:
#    Number of Entries: 60000
#    Shape of Entry: (785,)
#
# Attempting to load: mnist-test-data.csv
#
# Loading Complete
# Data Statistics:
#    Number of Entries: 10000
#    Shape of Entry: (785,)

# %%
def FindCorrectPredictions(prediction_array, actual_array):
    idx = np.argwhere(actual_array != prediction_array)
    actual = actual_array[idx]
    predicted = prediction_array[idx]
    pred_actual_hstack = np.hstack((predicted, actual))
    final_hstack = np.hstack((idx, pred_actual_hstack))
    df = pd.DataFrame(final_hstack, columns=["Index Of Image", "Predicted Image", "Actual Image"])
    return df

# %%
def prune_index11(clf, index, threshold):
    try:
        """
        prune_index(dt.tree_, 0, 3)
        https://stackoverflow.com/questions/49428469/pruning-decision-trees
        """

        if clf.tree_.value[index][0].sum() < threshold:
            # turn node into a leaf by "unlinking" its children
            clf.tree_.children_left[index] = TREE_LEAF
            clf.tree_.children_right[index] = TREE_LEAF
        # if there are children, visit them as well
        if clf.tree_.children_left[index] != TREE_LEAF:
            prune_index(clf.tree_.children_left[index], threshold)
            prune_index(clf.tree_.children_right[index], threshold)

    except Exception as err:
        print("Exception occurred while pruning Decision Tree. \n", err)
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        print(exc_type, fname, exc_tb.tb_lineno)

# %%
NeuralNetwork_Classifier = MLPClassifier(solver='sgd', max_iter=200, verbose=1, hidden_layer_sizes=(100,))

# %%
KNN_Classifier = KNeighborsClassifier()

# %%
Boosted_Classifier = GradientBoostingClassifier(n_estimators=100, max_depth=100, verbose=3)

# %%
SVM_Classifier = svm.SVC(kernel='rbf', verbose=3, max_iter=1000)

# %%
DecisionTree_Classifier = DecisionTreeClassifier(criterion="entropy", max_depth=100)

# %%
"""
TRAINING TIME

"""
# Out:
# '\nTRAINING TIME\n\n'

# %%
# limit = 4000
# testing_subset = testing_data[:limit, :]
# training_subset = training_data[:limit, :]
# testing_sublabels = testing_labels[:limit]
# training_sublabels = training_labels[:limit ,]

solvers = ["Adam", "SGD"]

adam_runtime = [0.0]
adam_accuracy = [0.0]

sgd_runtime = [0.0]
sgd_accuracy = [0.0]

# %%
for solver in solvers:
    NeuralNetwork_Classifier = MLPClassifier(solver=solver.lower(), max_iter=200, verbose=1, hidden_layer_sizes=(100,))
    for i in range(1, 11, 1):
        print("{} - Training Size: {}%".format(solver, (i * 10)))
        start_time = timer()
        with parallel_backend('threading'):
            NeuralNetwork_Classifier.fit(training_data[:int((60000 * (0.1 * i))), :], training_labels[:int((60000 * (0.1 * i)))])
        end_time = timer()
        elapsed_time = end_time - start_time
        print(elapsed_time)
        if solver == "SGD":
            sgd_accuracy.append(NeuralNetwork_Classifier.score(testing_data, testing_labels))
            sgd_runtime.append(elapsed_time)
        else:
            adam_accuracy.append(NeuralNetwork_Classifier.score(testing_data, testing_labels))
            adam_runtime.append(elapsed_time)
# Out:
# Adam - Training Size: 10%
# Iteration 1, loss = 1.05280865
# Iteration 2, loss = 0.33818426
# Iteration 3, loss = 0.22797887
# Iteration 4, loss = 0.17242877
# Iteration 5, loss = 0.13819311
# Iteration 6, loss = 0.11251370
# Iteration 7, loss = 0.09358416
# Iteration 8, loss = 0.07992448
# Iteration 9, loss = 0.06702717
# Iteration 10, loss = 0.05692914
# Iteration 11, loss = 0.04876429
# Iteration 12, loss = 0.04221169
# Iteration 13, loss = 0.03606889
# Iteration 14, loss = 0.03133508
# Iteration 15, loss = 0.02731206
# Iteration 16, loss = 0.02367196
# Iteration 17, loss = 0.02071212
# Iteration 18, loss = 0.01850940
# Iteration 19, loss = 0.01645951
# Iteration 20, loss = 0.01470912
# Iteration 21, loss = 0.01314073
# Iteration 22, loss = 0.01186185
# Iteration 23, loss = 0.01079911
# Iteration 24, loss = 0.00971556
# Iteration 25, loss = 0.00892309
# Iteration 26, loss = 0.00825458
# Iteration 27, loss = 0.00748028
# Iteration 28, loss = 0.00693469
# Iteration 29, loss = 0.00649232
# Iteration 30, loss = 0.00601490
# Iteration 31, loss = 0.00553752
# Iteration 32, loss = 0.00519401
# Iteration 33, loss = 0.00485271
# Iteration 34, loss = 0.00453633
# Iteration 35, loss = 0.00426343
# Iteration 36, loss = 0.00401403
# Iteration 37, loss = 0.00378605
# Iteration 38, loss = 0.00356716
# Iteration 39, loss = 0.00336461
# Iteration 40, loss = 0.00319773
# Iteration 41, loss = 0.00303573
# Iteration 42, loss = 0.00287717
# Iteration 43, loss = 0.00273332
# Iteration 44, loss = 0.00259783
# Iteration 45, loss = 0.00247413
# Iteration 46, loss = 0.00237468
# Iteration 47, loss = 0.00226853
# Iteration 48, loss = 0.00216702
# Iteration 49, loss = 0.00207764
# Iteration 50, loss = 0.00198275
# Iteration 51, loss = 0.00190806
# Iteration 52, loss = 0.00183427
# Iteration 53, loss = 0.00175502
# Iteration 54, loss = 0.00168451
# Iteration 55, loss = 0.00161595
# Iteration 56, loss = 0.00155370
# Iteration 57, loss = 0.00149797
# Iteration 58, loss = 0.00144957
# Iteration 59, loss = 0.00139488
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# 6.132596400000011
# Adam - Training Size: 20%
# Iteration 1, loss = 0.70297409
# Iteration 2, loss = 0.24824065
# Iteration 3, loss = 0.17156515
# Iteration 4, loss = 0.13066269
# Iteration 5, loss = 0.10268572
# Iteration 6, loss = 0.08366086
# Iteration 7, loss = 0.06759547
# Iteration 8, loss = 0.05654541
# Iteration 9, loss = 0.04697834
# Iteration 10, loss = 0.03905526
# Iteration 11, loss = 0.03295619
# Iteration 12, loss = 0.02767742
# Iteration 13, loss = 0.02309684
# Iteration 14, loss = 0.01978599
# Iteration 15, loss = 0.01713624
# Iteration 16, loss = 0.01470716
# Iteration 17, loss = 0.01253174
# Iteration 18, loss = 0.01105295
# Iteration 19, loss = 0.00961075
# Iteration 20, loss = 0.00842376
# Iteration 21, loss = 0.00746389
# Iteration 22, loss = 0.00675964
# Iteration 23, loss = 0.00599440
# Iteration 24, loss = 0.00534079
# Iteration 25, loss = 0.00484697
# Iteration 26, loss = 0.00440057
# Iteration 27, loss = 0.00400217
# Iteration 28, loss = 0.00365616
# Iteration 29, loss = 0.00336931
# Iteration 30, loss = 0.00310022
# Iteration 31, loss = 0.00286680
# Iteration 32, loss = 0.00265057
# Iteration 33, loss = 0.00248325
# Iteration 34, loss = 0.00230921
# Iteration 35, loss = 0.00214359
# Iteration 36, loss = 0.00201245
# Iteration 37, loss = 0.00187059
# Iteration 38, loss = 0.00178025
# Iteration 39, loss = 0.00165357
# Iteration 40, loss = 0.00157024
# Iteration 41, loss = 0.00148188
# Iteration 42, loss = 0.00139232
# Iteration 43, loss = 0.00131811
# Iteration 44, loss = 0.00125035
# Iteration 45, loss = 0.00118423
# Iteration 46, loss = 0.00112629
# Iteration 47, loss = 0.00107127
# Iteration 48, loss = 0.00102257
# Iteration 49, loss = 0.00096666
# Iteration 50, loss = 0.00092766
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# 10.558491799999956
# Adam - Training Size: 30%
# Iteration 1, loss = 0.57335066
# Iteration 2, loss = 0.21898326
# Iteration 3, loss = 0.15218993
# Iteration 4, loss = 0.11452238
# Iteration 5, loss = 0.08953359
# Iteration 6, loss = 0.07084514
# Iteration 7, loss = 0.05739979
# Iteration 8, loss = 0.04667013
# Iteration 9, loss = 0.03764558
# Iteration 10, loss = 0.03115959
# Iteration 11, loss = 0.02607868
# Iteration 12, loss = 0.02132280
# Iteration 13, loss = 0.01770071
# Iteration 14, loss = 0.01469504
# Iteration 15, loss = 0.01239491
# Iteration 16, loss = 0.01068262
# Iteration 17, loss = 0.00899848
# Iteration 18, loss = 0.00762386
# Iteration 19, loss = 0.00682226
# Iteration 20, loss = 0.00593406
# Iteration 21, loss = 0.00520332
# Iteration 22, loss = 0.00450146
# Iteration 23, loss = 0.00397267
# Iteration 24, loss = 0.00361238
# Iteration 25, loss = 0.00324607
# Iteration 26, loss = 0.00293781
# Iteration 27, loss = 0.00264693
# Iteration 28, loss = 0.00241554
# Iteration 29, loss = 0.00219874
# Iteration 30, loss = 0.00202910
# Iteration 31, loss = 0.00186564
# Iteration 32, loss = 0.00170522
# Iteration 33, loss = 0.00158465
# Iteration 34, loss = 0.00146071
# Iteration 35, loss = 0.00135874
# Iteration 36, loss = 0.00125977
# Iteration 37, loss = 0.00117780
# Iteration 38, loss = 0.00110381
# Iteration 39, loss = 0.00103413
# Iteration 40, loss = 0.00097176
# Iteration 41, loss = 0.00091004
# Iteration 42, loss = 0.00085370
# Iteration 43, loss = 0.00081008
# Iteration 44, loss = 0.00075920
# Iteration 45, loss = 0.00071964
# Iteration 46, loss = 0.00068032
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# 14.28320030000009
# Adam - Training Size: 40%
# Iteration 1, loss = 0.50519556
# Iteration 2, loss = 0.19383912
# Iteration 3, loss = 0.13374435
# Iteration 4, loss = 0.10117223
# Iteration 5, loss = 0.07843050
# Iteration 6, loss = 0.06208527
# Iteration 7, loss = 0.04977226
# Iteration 8, loss = 0.03985375
# Iteration 9, loss = 0.03234952
# Iteration 10, loss = 0.02607782
# Iteration 11, loss = 0.02126253
# Iteration 12, loss = 0.01744303
# Iteration 13, loss = 0.01479490
# Iteration 14, loss = 0.01221658
# Iteration 15, loss = 0.00996744
# Iteration 16, loss = 0.00850777
# Iteration 17, loss = 0.00717604
# Iteration 18, loss = 0.00613185
# Iteration 19, loss = 0.00521785
# Iteration 20, loss = 0.00455883
# Iteration 21, loss = 0.00388273
# Iteration 22, loss = 0.00343847
# Iteration 23, loss = 0.00306539
# Iteration 24, loss = 0.00270426
# Iteration 25, loss = 0.00242346
# Iteration 26, loss = 0.00214038
# Iteration 27, loss = 0.00192210
# Iteration 28, loss = 0.00174694
# Iteration 29, loss = 0.00159378
# Iteration 30, loss = 0.00144919
# Iteration 31, loss = 0.00132137
# Iteration 32, loss = 0.00119219
# Iteration 33, loss = 0.00110518
# Iteration 34, loss = 0.00102781
# Iteration 35, loss = 0.00093425
# Iteration 36, loss = 0.00088341
# Iteration 37, loss = 0.00080692
# Iteration 38, loss = 0.00075244
# Iteration 39, loss = 0.00069800
# Iteration 40, loss = 0.00064990
# Iteration 41, loss = 0.00061429
# Iteration 42, loss = 0.00057508
# Iteration 43, loss = 0.00053958
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# 17.3786912999999
# Adam - Training Size: 50%
# Iteration 1, loss = 0.46403743
# Iteration 2, loss = 0.17634007
# Iteration 3, loss = 0.12277596
# Iteration 4, loss = 0.09323826
# Iteration 5, loss = 0.07225034
# Iteration 6, loss = 0.05717145
# Iteration 7, loss = 0.04465574
# Iteration 8, loss = 0.03614725
# Iteration 9, loss = 0.02855490
# Iteration 10, loss = 0.02260095
# Iteration 11, loss = 0.01834881
# Iteration 12, loss = 0.01553475
# Iteration 13, loss = 0.01215048
# Iteration 14, loss = 0.01008875
# Iteration 15, loss = 0.00823135
# Iteration 16, loss = 0.00691090
# Iteration 17, loss = 0.00578212
# Iteration 18, loss = 0.00488269
# Iteration 19, loss = 0.00417891
# Iteration 20, loss = 0.00357357
# Iteration 21, loss = 0.00308266
# Iteration 22, loss = 0.00268272
# Iteration 23, loss = 0.00234040
# Iteration 24, loss = 0.00205961
# Iteration 25, loss = 0.00184247
# Iteration 26, loss = 0.00163016
# Iteration 27, loss = 0.00149632
# Iteration 28, loss = 0.00130245
# Iteration 29, loss = 0.00118640
# Iteration 30, loss = 0.00107777
# Iteration 31, loss = 0.00097791
# Iteration 32, loss = 0.00089807
# Iteration 33, loss = 0.00082515
# Iteration 34, loss = 0.00075832
# Iteration 35, loss = 0.00069179
# Iteration 36, loss = 0.00063672
# Iteration 37, loss = 0.00059081
# Iteration 38, loss = 0.00055589
# Iteration 39, loss = 0.00051126
# Iteration 40, loss = 0.00047736
# Iteration 41, loss = 0.00044585
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# 19.9868034000001
# Adam - Training Size: 60%
# Iteration 1, loss = 0.43212620
# Iteration 2, loss = 0.16861797
# Iteration 3, loss = 0.11493964
# Iteration 4, loss = 0.08684040
# Iteration 5, loss = 0.06655894
# Iteration 6, loss = 0.05238275
# Iteration 7, loss = 0.04148755
# Iteration 8, loss = 0.03261054
# Iteration 9, loss = 0.02542882
# Iteration 10, loss = 0.02048068
# Iteration 11, loss = 0.01614168
# Iteration 12, loss = 0.01313536
# Iteration 13, loss = 0.01064969
# Iteration 14, loss = 0.00867532
# Iteration 15, loss = 0.00702641
# Iteration 16, loss = 0.00587209
# Iteration 17, loss = 0.00479803
# Iteration 18, loss = 0.00399873
# Iteration 19, loss = 0.00336942
# Iteration 20, loss = 0.00292375
# Iteration 21, loss = 0.00248813
# Iteration 22, loss = 0.00214413
# Iteration 23, loss = 0.00186974
# Iteration 24, loss = 0.00164814
# Iteration 25, loss = 0.00145223
# Iteration 26, loss = 0.00128964
# Iteration 27, loss = 0.00114832
# Iteration 28, loss = 0.00104862
# Iteration 29, loss = 0.00095646
# Iteration 30, loss = 0.00085230
# Iteration 31, loss = 0.00075655
# Iteration 32, loss = 0.00070356
# Iteration 33, loss = 0.00062467
# Iteration 34, loss = 0.00057401
# Iteration 35, loss = 0.00053624
# Iteration 36, loss = 0.00049783
# Iteration 37, loss = 0.00045830
# Iteration 38, loss = 0.00042438
# Iteration 39, loss = 0.00040566
# Iteration 40, loss = 0.00037720
# Iteration 41, loss = 0.00036069
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# 23.129155099999934
# Adam - Training Size: 70%
# Iteration 1, loss = 0.40175833
# Iteration 2, loss = 0.15968807
# Iteration 3, loss = 0.10944171
# Iteration 4, loss = 0.08245452
# Iteration 5, loss = 0.06391127
# Iteration 6, loss = 0.05162592
# Iteration 7, loss = 0.04023721
# Iteration 8, loss = 0.03116603
# Iteration 9, loss = 0.02525000
# Iteration 10, loss = 0.02078228
# Iteration 11, loss = 0.01692929
# Iteration 12, loss = 0.01374535
# Iteration 13, loss = 0.01200949
# Iteration 14, loss = 0.00895058
# Iteration 15, loss = 0.00780233
# Iteration 16, loss = 0.00574488
# Iteration 17, loss = 0.00490440
# Iteration 18, loss = 0.00405428
# Iteration 19, loss = 0.00335603
# Iteration 20, loss = 0.00285139
# Iteration 21, loss = 0.00235799
# Iteration 22, loss = 0.00200650
# Iteration 23, loss = 0.00176543
# Iteration 24, loss = 0.00155024
# Iteration 25, loss = 0.00131588
# Iteration 26, loss = 0.00147891
# Iteration 27, loss = 0.00128144
# Iteration 28, loss = 0.00096918
# Iteration 29, loss = 0.00080130
# Iteration 30, loss = 0.00074085
# Iteration 31, loss = 0.00065072
# Iteration 32, loss = 0.00060374
# Iteration 33, loss = 0.00054627
# Iteration 34, loss = 0.00050286
# Iteration 35, loss = 0.00047646
# Iteration 36, loss = 0.00044684
# Iteration 37, loss = 0.00040945
# Iteration 38, loss = 0.00038070
# Iteration 39, loss = 0.00035569
# Iteration 40, loss = 0.00034017
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# 26.53002649999985
# Adam - Training Size: 80%
# Iteration 1, loss = 0.38224615
# Iteration 2, loss = 0.15269026
# Iteration 3, loss = 0.10573128
# Iteration 4, loss = 0.07913532
# Iteration 5, loss = 0.06173376
# Iteration 6, loss = 0.04857874
# Iteration 7, loss = 0.03796067
# Iteration 8, loss = 0.02994395
# Iteration 9, loss = 0.02402742
# Iteration 10, loss = 0.01923415
# Iteration 11, loss = 0.01595079
# Iteration 12, loss = 0.01172732
# Iteration 13, loss = 0.00932127
# Iteration 14, loss = 0.00742778
# Iteration 15, loss = 0.00579527
# Iteration 16, loss = 0.00493022
# Iteration 17, loss = 0.00415475
# Iteration 18, loss = 0.00323734
# Iteration 19, loss = 0.00280375
# Iteration 20, loss = 0.00222035
# Iteration 21, loss = 0.00198989
# Iteration 22, loss = 0.00180842
# Iteration 23, loss = 0.00143306
# Iteration 24, loss = 0.01548125
# Iteration 25, loss = 0.04703526
# Iteration 26, loss = 0.02059053
# Iteration 27, loss = 0.00706319
# Iteration 28, loss = 0.00158100
# Iteration 29, loss = 0.00123179
# Iteration 30, loss = 0.00092791
# Iteration 31, loss = 0.00079693
# Iteration 32, loss = 0.00073606
# Iteration 33, loss = 0.00068637
# Iteration 34, loss = 0.00064045
# Iteration 35, loss = 0.00060565
# Iteration 36, loss = 0.00057458
# Iteration 37, loss = 0.00054988
# Iteration 38, loss = 0.00051953
# Iteration 39, loss = 0.00049519
# Iteration 40, loss = 0.00046940
# Iteration 41, loss = 0.00044872
# Iteration 42, loss = 0.00043075
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# 31.935212899999897
# Adam - Training Size: 90%
# Iteration 1, loss = 0.35610270
# Iteration 2, loss = 0.14477753
# Iteration 3, loss = 0.10015733
# Iteration 4, loss = 0.07580784
# Iteration 5, loss = 0.05798929
# Iteration 6, loss = 0.04627463
# Iteration 7, loss = 0.03663764
# Iteration 8, loss = 0.02937361
# Iteration 9, loss = 0.02355380
# Iteration 10, loss = 0.01905236
# Iteration 11, loss = 0.01515175
# Iteration 12, loss = 0.01223789
# Iteration 13, loss = 0.00994123
# Iteration 14, loss = 0.00785441
# Iteration 15, loss = 0.00619772
# Iteration 16, loss = 0.00492967
# Iteration 17, loss = 0.00420213
# Iteration 18, loss = 0.00337269
# Iteration 19, loss = 0.00277227
# Iteration 20, loss = 0.00219774
# Iteration 21, loss = 0.00200100
# Iteration 22, loss = 0.00589276
# Iteration 23, loss = 0.03804864
# Iteration 24, loss = 0.02122163
# Iteration 25, loss = 0.00813133
# Iteration 26, loss = 0.00382540
# Iteration 27, loss = 0.00152937
# Iteration 28, loss = 0.00125457
# Iteration 29, loss = 0.00094032
# Iteration 30, loss = 0.00078783
# Iteration 31, loss = 0.00072745
# Iteration 32, loss = 0.00067485
# Iteration 33, loss = 0.00063889
# Iteration 34, loss = 0.00059718
# Iteration 35, loss = 0.00056359
# Iteration 36, loss = 0.00054546
# Iteration 37, loss = 0.00055541
# Iteration 38, loss = 0.00051173
# Iteration 39, loss = 0.00593114
# Iteration 40, loss = 0.03474465
# Iteration 41, loss = 0.01659378
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# 34.591115800000125
# Adam - Training Size: 100%
# Iteration 1, loss = 0.34930775
# Iteration 2, loss = 0.14427736
# Iteration 3, loss = 0.10108604
# Iteration 4, loss = 0.07517208
# Iteration 5, loss = 0.05784871
# Iteration 6, loss = 0.04561406
# Iteration 7, loss = 0.03717016
# Iteration 8, loss = 0.02970612
# Iteration 9, loss = 0.02281785
# Iteration 10, loss = 0.01805656
# Iteration 11, loss = 0.01437797
# Iteration 12, loss = 0.01142516
# Iteration 13, loss = 0.00901807
# Iteration 14, loss = 0.00740798
# Iteration 15, loss = 0.00619802
# Iteration 16, loss = 0.00534307
# Iteration 17, loss = 0.00437734
# Iteration 18, loss = 0.00418412
# Iteration 19, loss = 0.01212281
# Iteration 20, loss = 0.02028971
# Iteration 21, loss = 0.01529127
# Iteration 22, loss = 0.00763843
# Iteration 23, loss = 0.00352190
# Iteration 24, loss = 0.00192288
# Iteration 25, loss = 0.00123631
# Iteration 26, loss = 0.00099424
# Iteration 27, loss = 0.00093671
# Iteration 28, loss = 0.00080518
# Iteration 29, loss = 0.00075182
# Iteration 30, loss = 0.00067985
# Iteration 31, loss = 0.00066006
# Iteration 32, loss = 0.00065350
# Iteration 33, loss = 0.00059671
# Iteration 34, loss = 0.00052519
# Iteration 35, loss = 0.00048815
# Iteration 36, loss = 0.00046024
# Iteration 37, loss = 0.00043712
# Iteration 38, loss = 0.00040956
# Iteration 39, loss = 0.03536808
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# 36.72426829999995
# SGD - Training Size: 10%
# Iteration 1, loss = 2.27434489
# Iteration 2, loss = 1.41064854
# Iteration 3, loss = 1.02817489
# Iteration 4, loss = 0.83573777
# Iteration 5, loss = 0.71765788
# Iteration 6, loss = 0.63723235
# Iteration 7, loss = 0.57720237
# Iteration 8, loss = 0.53103456
# Iteration 9, loss = 0.49342376
# Iteration 10, loss = 0.46282724
# Iteration 11, loss = 0.43645553
# Iteration 12, loss = 0.41402805
# Iteration 13, loss = 0.39436385
# Iteration 14, loss = 0.37739991
# Iteration 15, loss = 0.36204184
# Iteration 16, loss = 0.34852440
# Iteration 17, loss = 0.33638114
# Iteration 18, loss = 0.32535698
# Iteration 19, loss = 0.31522661
# Iteration 20, loss = 0.30597656
# Iteration 21, loss = 0.29734845
# Iteration 22, loss = 0.28942817
# Iteration 23, loss = 0.28201466
# Iteration 24, loss = 0.27514895
# Iteration 25, loss = 0.26865482
# Iteration 26, loss = 0.26257293
# Iteration 27, loss = 0.25686391
# Iteration 28, loss = 0.25139669
# Iteration 29, loss = 0.24621365
# Iteration 30, loss = 0.24133238
# Iteration 31, loss = 0.23661452
# Iteration 32, loss = 0.23220210
# Iteration 33, loss = 0.22799295
# Iteration 34, loss = 0.22383230
# Iteration 35, loss = 0.21988671
# Iteration 36, loss = 0.21615283
# Iteration 37, loss = 0.21249843
# Iteration 38, loss = 0.20901387
# Iteration 39, loss = 0.20569580
# Iteration 40, loss = 0.20248542
# Iteration 41, loss = 0.19934125
# Iteration 42, loss = 0.19638116
# Iteration 43, loss = 0.19343823
# Iteration 44, loss = 0.19064071
# Iteration 45, loss = 0.18788323
# Iteration 46, loss = 0.18520731
# Iteration 47, loss = 0.18267653
# Iteration 48, loss = 0.18020629
# Iteration 49, loss = 0.17777783
# Iteration 50, loss = 0.17548756
# Iteration 51, loss = 0.17312894
# Iteration 52, loss = 0.17095801
# Iteration 53, loss = 0.16877599
# Iteration 54, loss = 0.16668091
# Iteration 55, loss = 0.16459832
# Iteration 56, loss = 0.16258008
# Iteration 57, loss = 0.16062561
# Iteration 58, loss = 0.15867948
# Iteration 59, loss = 0.15677477
# Iteration 60, loss = 0.15496392
# Iteration 61, loss = 0.15315792
# Iteration 62, loss = 0.15141783
# Iteration 63, loss = 0.14971147
# Iteration 64, loss = 0.14799245
# Iteration 65, loss = 0.14634956
# Iteration 66, loss = 0.14468982
# Iteration 67, loss = 0.14318349
# Iteration 68, loss = 0.14164938
# Iteration 69, loss = 0.14011289
# Iteration 70, loss = 0.13859460
# Iteration 71, loss = 0.13715141
# Iteration 72, loss = 0.13572989
# Iteration 73, loss = 0.13433577
# Iteration 74, loss = 0.13290786
# Iteration 75, loss = 0.13155487
# Iteration 76, loss = 0.13020349
# Iteration 77, loss = 0.12890782
# Iteration 78, loss = 0.12762097
# Iteration 79, loss = 0.12636898
# Iteration 80, loss = 0.12512722
# Iteration 81, loss = 0.12393400
# Iteration 82, loss = 0.12269199
# Iteration 83, loss = 0.12150715
# Iteration 84, loss = 0.12037167
# Iteration 85, loss = 0.11916225
# Iteration 86, loss = 0.11812217
# Iteration 87, loss = 0.11695106
# Iteration 88, loss = 0.11589138
# Iteration 89, loss = 0.11478010
# Iteration 90, loss = 0.11372779
# Iteration 91, loss = 0.11269348
# Iteration 92, loss = 0.11169052
# Iteration 93, loss = 0.11063035
# Iteration 94, loss = 0.10969255
# Iteration 95, loss = 0.10870947
# Iteration 96, loss = 0.10770906
# Iteration 97, loss = 0.10676867
# Iteration 98, loss = 0.10581269
# Iteration 99, loss = 0.10489786
# Iteration 100, loss = 0.10393810
# Iteration 101, loss = 0.10308608
# Iteration 102, loss = 0.10216039
# Iteration 103, loss = 0.10130121
# Iteration 104, loss = 0.10042364
# Iteration 105, loss = 0.09955711
# Iteration 106, loss = 0.09877299
# Iteration 107, loss = 0.09790290
# Iteration 108, loss = 0.09708157
# Iteration 109, loss = 0.09627893
# Iteration 110, loss = 0.09550050
# Iteration 111, loss = 0.09466273
# Iteration 112, loss = 0.09389275
# Iteration 113, loss = 0.09318495
# Iteration 114, loss = 0.09239082
# Iteration 115, loss = 0.09159320
# Iteration 116, loss = 0.09088690
# Iteration 117, loss = 0.09015739
# Iteration 118, loss = 0.08944057
# Iteration 119, loss = 0.08875529
# Iteration 120, loss = 0.08803474
# Iteration 121, loss = 0.08734063
# Iteration 122, loss = 0.08665681
# Iteration 123, loss = 0.08598050
# Iteration 124, loss = 0.08529926
# Iteration 125, loss = 0.08464313
# Iteration 126, loss = 0.08400178
# Iteration 127, loss = 0.08335516
# Iteration 128, loss = 0.08268525
# Iteration 129, loss = 0.08207153
# Iteration 130, loss = 0.08145771
# Iteration 131, loss = 0.08085160
# Iteration 132, loss = 0.08022588
# Iteration 133, loss = 0.07963702
# Iteration 134, loss = 0.07902964
# Iteration 135, loss = 0.07842602
# Iteration 136, loss = 0.07785675
# Iteration 137, loss = 0.07727547
# Iteration 138, loss = 0.07670455
# Iteration 139, loss = 0.07611750
# Iteration 140, loss = 0.07555379
# Iteration 141, loss = 0.07500483
# Iteration 142, loss = 0.07447617
# Iteration 143, loss = 0.07391681
# Iteration 144, loss = 0.07340009
# Iteration 145, loss = 0.07285974
# Iteration 146, loss = 0.07235034
# Iteration 147, loss = 0.07181810
# Iteration 148, loss = 0.07127838
# Iteration 149, loss = 0.07080358
# Iteration 150, loss = 0.07026517
# Iteration 151, loss = 0.06978710
# Iteration 152, loss = 0.06931627
# Iteration 153, loss = 0.06882790
# Iteration 154, loss = 0.06832966
# Iteration 155, loss = 0.06785742
# Iteration 156, loss = 0.06739028
# Iteration 157, loss = 0.06691949
# Iteration 158, loss = 0.06645657
# Iteration 159, loss = 0.06599165
# Iteration 160, loss = 0.06555532
# Iteration 161, loss = 0.06510625
# Iteration 162, loss = 0.06465967
# Iteration 163, loss = 0.06421727
# Iteration 164, loss = 0.06379031
# Iteration 165, loss = 0.06337888
# Iteration 166, loss = 0.06292628
# Iteration 167, loss = 0.06249433
# Iteration 168, loss = 0.06208400
# Iteration 169, loss = 0.06167423
# Iteration 170, loss = 0.06127010
# Iteration 171, loss = 0.06089994
# Iteration 172, loss = 0.06045670
# Iteration 173, loss = 0.06008456
# Iteration 174, loss = 0.05967890
# Iteration 175, loss = 0.05929201
# Iteration 176, loss = 0.05891039
# Iteration 177, loss = 0.05852379
# Iteration 178, loss = 0.05813130
# Iteration 179, loss = 0.05776039
# Iteration 180, loss = 0.05739281
# Iteration 181, loss = 0.05703513
# Iteration 182, loss = 0.05666840
# Iteration 183, loss = 0.05630308
# Iteration 184, loss = 0.05594746
# Iteration 185, loss = 0.05559487
# Iteration 186, loss = 0.05525442
# Iteration 187, loss = 0.05489966
# Iteration 188, loss = 0.05455535
# Iteration 189, loss = 0.05420437
# Iteration 190, loss = 0.05387135
# Iteration 191, loss = 0.05353656
# Iteration 192, loss = 0.05320908
# Iteration 193, loss = 0.05287756
# Iteration 194, loss = 0.05254814
# Iteration 195, loss = 0.05223580
# Iteration 196, loss = 0.05191672
# Iteration 197, loss = 0.05159365
# Iteration 198, loss = 0.05128121
# Iteration 199, loss = 0.05099245
# Iteration 200, loss = 0.05066455
# 15.7013879000001
# SGD - Training Size: 20%
# C:\ProgramData\Anaconda3\envs\CS7641\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Iteration 1, loss = 1.75445623
# Iteration 2, loss = 0.88004705
# Iteration 3, loss = 0.65161923
# Iteration 4, loss = 0.54304031
# Iteration 5, loss = 0.47702345
# Iteration 6, loss = 0.43190034
# Iteration 7, loss = 0.39870779
# Iteration 8, loss = 0.37276975
# Iteration 9, loss = 0.35172087
# Iteration 10, loss = 0.33412566
# Iteration 11, loss = 0.31915387
# Iteration 12, loss = 0.30604038
# Iteration 13, loss = 0.29459856
# Iteration 14, loss = 0.28426596
# Iteration 15, loss = 0.27491924
# Iteration 16, loss = 0.26641370
# Iteration 17, loss = 0.25861686
# Iteration 18, loss = 0.25150027
# Iteration 19, loss = 0.24477505
# Iteration 20, loss = 0.23871052
# Iteration 21, loss = 0.23286298
# Iteration 22, loss = 0.22745878
# Iteration 23, loss = 0.22227659
# Iteration 24, loss = 0.21748786
# Iteration 25, loss = 0.21286899
# Iteration 26, loss = 0.20851708
# Iteration 27, loss = 0.20432697
# Iteration 28, loss = 0.20034454
# Iteration 29, loss = 0.19658045
# Iteration 30, loss = 0.19291453
# Iteration 31, loss = 0.18945569
# Iteration 32, loss = 0.18610599
# Iteration 33, loss = 0.18287375
# Iteration 34, loss = 0.17973925
# Iteration 35, loss = 0.17675009
# Iteration 36, loss = 0.17384360
# Iteration 37, loss = 0.17107192
# Iteration 38, loss = 0.16838267
# Iteration 39, loss = 0.16572522
# Iteration 40, loss = 0.16321483
# Iteration 41, loss = 0.16079098
# Iteration 42, loss = 0.15837165
# Iteration 43, loss = 0.15611140
# Iteration 44, loss = 0.15384302
# Iteration 45, loss = 0.15162303
# Iteration 46, loss = 0.14951059
# Iteration 47, loss = 0.14745926
# Iteration 48, loss = 0.14543668
# Iteration 49, loss = 0.14349295
# Iteration 50, loss = 0.14156889
# Iteration 51, loss = 0.13968993
# Iteration 52, loss = 0.13787513
# Iteration 53, loss = 0.13616070
# Iteration 54, loss = 0.13442294
# Iteration 55, loss = 0.13274585
# Iteration 56, loss = 0.13108350
# Iteration 57, loss = 0.12943830
# Iteration 58, loss = 0.12787100
# Iteration 59, loss = 0.12630854
# Iteration 60, loss = 0.12482448
# Iteration 61, loss = 0.12335464
# Iteration 62, loss = 0.12189916
# Iteration 63, loss = 0.12050453
# Iteration 64, loss = 0.11908806
# Iteration 65, loss = 0.11778800
# Iteration 66, loss = 0.11642791
# Iteration 67, loss = 0.11514978
# Iteration 68, loss = 0.11384112
# Iteration 69, loss = 0.11257679
# Iteration 70, loss = 0.11132681
# Iteration 71, loss = 0.11013688
# Iteration 72, loss = 0.10897060
# Iteration 73, loss = 0.10776072
# Iteration 74, loss = 0.10664324
# Iteration 75, loss = 0.10550986
# Iteration 76, loss = 0.10438610
# Iteration 77, loss = 0.10332373
# Iteration 78, loss = 0.10223203
# Iteration 79, loss = 0.10120089
# Iteration 80, loss = 0.10015539
# Iteration 81, loss = 0.09914370
# Iteration 82, loss = 0.09816862
# Iteration 83, loss = 0.09717456
# Iteration 84, loss = 0.09619879
# Iteration 85, loss = 0.09527373
# Iteration 86, loss = 0.09433389
# Iteration 87, loss = 0.09336827
# Iteration 88, loss = 0.09248986
# Iteration 89, loss = 0.09162097
# Iteration 90, loss = 0.09078467
# Iteration 91, loss = 0.08985696
# Iteration 92, loss = 0.08903038
# Iteration 93, loss = 0.08817205
# Iteration 94, loss = 0.08737338
# Iteration 95, loss = 0.08653702
# Iteration 96, loss = 0.08576540
# Iteration 97, loss = 0.08496227
# Iteration 98, loss = 0.08416485
# Iteration 99, loss = 0.08341491
# Iteration 100, loss = 0.08264802
# Iteration 101, loss = 0.08189799
# Iteration 102, loss = 0.08118937
# Iteration 103, loss = 0.08048426
# Iteration 104, loss = 0.07975903
# Iteration 105, loss = 0.07903958
# Iteration 106, loss = 0.07835135
# Iteration 107, loss = 0.07769596
# Iteration 108, loss = 0.07700878
# Iteration 109, loss = 0.07635908
# Iteration 110, loss = 0.07568070
# Iteration 111, loss = 0.07505601
# Iteration 112, loss = 0.07441832
# Iteration 113, loss = 0.07378952
# Iteration 114, loss = 0.07317345
# Iteration 115, loss = 0.07256122
# Iteration 116, loss = 0.07193475
# Iteration 117, loss = 0.07136404
# Iteration 118, loss = 0.07077359
# Iteration 119, loss = 0.07019851
# Iteration 120, loss = 0.06965663
# Iteration 121, loss = 0.06905650
# Iteration 122, loss = 0.06848998
# Iteration 123, loss = 0.06793985
# Iteration 124, loss = 0.06738755
# Iteration 125, loss = 0.06689995
# Iteration 126, loss = 0.06635401
# Iteration 127, loss = 0.06583893
# Iteration 128, loss = 0.06529807
# Iteration 129, loss = 0.06480321
# Iteration 130, loss = 0.06429595
# Iteration 131, loss = 0.06379595
# Iteration 132, loss = 0.06329812
# Iteration 133, loss = 0.06278271
# Iteration 134, loss = 0.06231381
# Iteration 135, loss = 0.06183794
# Iteration 136, loss = 0.06137526
# Iteration 137, loss = 0.06093001
# Iteration 138, loss = 0.06044555
# Iteration 139, loss = 0.05998727
# Iteration 140, loss = 0.05955653
# Iteration 141, loss = 0.05910015
# Iteration 142, loss = 0.05866696
# Iteration 143, loss = 0.05822456
# Iteration 144, loss = 0.05778167
# Iteration 145, loss = 0.05733200
# Iteration 146, loss = 0.05695236
# Iteration 147, loss = 0.05653694
# Iteration 148, loss = 0.05612331
# Iteration 149, loss = 0.05571286
# Iteration 150, loss = 0.05529630
# Iteration 151, loss = 0.05490097
# Iteration 152, loss = 0.05450854
# Iteration 153, loss = 0.05413325
# Iteration 154, loss = 0.05372906
# Iteration 155, loss = 0.05332341
# Iteration 156, loss = 0.05296100
# Iteration 157, loss = 0.05258947
# Iteration 158, loss = 0.05221677
# Iteration 159, loss = 0.05185875
# Iteration 160, loss = 0.05145758
# Iteration 161, loss = 0.05113102
# Iteration 162, loss = 0.05073760
# Iteration 163, loss = 0.05040972
# Iteration 164, loss = 0.05007021
# Iteration 165, loss = 0.04970544
# Iteration 166, loss = 0.04938193
# Iteration 167, loss = 0.04903227
# Iteration 168, loss = 0.04869937
# Iteration 169, loss = 0.04836959
# Iteration 170, loss = 0.04802691
# Iteration 171, loss = 0.04773228
# Iteration 172, loss = 0.04739089
# Iteration 173, loss = 0.04708979
# Iteration 174, loss = 0.04674818
# Iteration 175, loss = 0.04644534
# Iteration 176, loss = 0.04613798
# Iteration 177, loss = 0.04582756
# Iteration 178, loss = 0.04554273
# Iteration 179, loss = 0.04523230
# Iteration 180, loss = 0.04493097
# Iteration 181, loss = 0.04463058
# Iteration 182, loss = 0.04434405
# Iteration 183, loss = 0.04407065
# Iteration 184, loss = 0.04377512
# Iteration 185, loss = 0.04349420
# Iteration 186, loss = 0.04320505
# Iteration 187, loss = 0.04291802
# Iteration 188, loss = 0.04264216
# Iteration 189, loss = 0.04238153
# Iteration 190, loss = 0.04211844
# Iteration 191, loss = 0.04184212
# Iteration 192, loss = 0.04158524
# Iteration 193, loss = 0.04131242
# Iteration 194, loss = 0.04104374
# Iteration 195, loss = 0.04078450
# Iteration 196, loss = 0.04054213
# Iteration 197, loss = 0.04028285
# Iteration 198, loss = 0.04003378
# Iteration 199, loss = 0.03977988
# Iteration 200, loss = 0.03953292
# 32.08685209999999
# SGD - Training Size: 30%
# C:\ProgramData\Anaconda3\envs\CS7641\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Iteration 1, loss = 1.61473791
# Iteration 2, loss = 0.80428227
# Iteration 3, loss = 0.59871430
# Iteration 4, loss = 0.49980906
# Iteration 5, loss = 0.44015995
# Iteration 6, loss = 0.39910022
# Iteration 7, loss = 0.36846876
# Iteration 8, loss = 0.34434903
# Iteration 9, loss = 0.32474784
# Iteration 10, loss = 0.30821704
# Iteration 11, loss = 0.29394244
# Iteration 12, loss = 0.28143648
# Iteration 13, loss = 0.27040211
# Iteration 14, loss = 0.26043142
# Iteration 15, loss = 0.25152834
# Iteration 16, loss = 0.24342105
# Iteration 17, loss = 0.23586767
# Iteration 18, loss = 0.22903630
# Iteration 19, loss = 0.22263569
# Iteration 20, loss = 0.21665835
# Iteration 21, loss = 0.21117410
# Iteration 22, loss = 0.20586408
# Iteration 23, loss = 0.20099719
# Iteration 24, loss = 0.19635645
# Iteration 25, loss = 0.19195888
# Iteration 26, loss = 0.18779147
# Iteration 27, loss = 0.18387619
# Iteration 28, loss = 0.18009409
# Iteration 29, loss = 0.17644113
# Iteration 30, loss = 0.17298346
# Iteration 31, loss = 0.16972853
# Iteration 32, loss = 0.16658061
# Iteration 33, loss = 0.16355936
# Iteration 34, loss = 0.16058109
# Iteration 35, loss = 0.15782428
# Iteration 36, loss = 0.15513362
# Iteration 37, loss = 0.15249331
# Iteration 38, loss = 0.14999542
# Iteration 39, loss = 0.14760571
# Iteration 40, loss = 0.14530078
# Iteration 41, loss = 0.14301559
# Iteration 42, loss = 0.14079705
# Iteration 43, loss = 0.13862943
# Iteration 44, loss = 0.13661893
# Iteration 45, loss = 0.13461100
# Iteration 46, loss = 0.13268133
# Iteration 47, loss = 0.13078364
# Iteration 48, loss = 0.12891294
# Iteration 49, loss = 0.12714613
# Iteration 50, loss = 0.12541913
# Iteration 51, loss = 0.12369363
# Iteration 52, loss = 0.12205307
# Iteration 53, loss = 0.12045211
# Iteration 54, loss = 0.11885795
# Iteration 55, loss = 0.11731426
# Iteration 56, loss = 0.11582711
# Iteration 57, loss = 0.11439127
# Iteration 58, loss = 0.11293717
# Iteration 59, loss = 0.11154057
# Iteration 60, loss = 0.11015273
# Iteration 61, loss = 0.10882112
# Iteration 62, loss = 0.10753384
# Iteration 63, loss = 0.10619210
# Iteration 64, loss = 0.10495275
# Iteration 65, loss = 0.10369941
# Iteration 66, loss = 0.10250593
# Iteration 67, loss = 0.10134093
# Iteration 68, loss = 0.10017637
# Iteration 69, loss = 0.09905654
# Iteration 70, loss = 0.09791131
# Iteration 71, loss = 0.09680647
# Iteration 72, loss = 0.09575387
# Iteration 73, loss = 0.09468432
# Iteration 74, loss = 0.09365035
# Iteration 75, loss = 0.09260961
# Iteration 76, loss = 0.09163653
# Iteration 77, loss = 0.09065148
# Iteration 78, loss = 0.08970238
# Iteration 79, loss = 0.08875014
# Iteration 80, loss = 0.08779279
# Iteration 81, loss = 0.08692655
# Iteration 82, loss = 0.08601266
# Iteration 83, loss = 0.08512288
# Iteration 84, loss = 0.08421402
# Iteration 85, loss = 0.08339045
# Iteration 86, loss = 0.08254046
# Iteration 87, loss = 0.08172194
# Iteration 88, loss = 0.08091383
# Iteration 89, loss = 0.08007556
# Iteration 90, loss = 0.07929623
# Iteration 91, loss = 0.07852804
# Iteration 92, loss = 0.07775892
# Iteration 93, loss = 0.07700616
# Iteration 94, loss = 0.07623977
# Iteration 95, loss = 0.07551828
# Iteration 96, loss = 0.07480429
# Iteration 97, loss = 0.07410023
# Iteration 98, loss = 0.07339654
# Iteration 99, loss = 0.07273085
# Iteration 100, loss = 0.07201406
# Iteration 101, loss = 0.07135977
# Iteration 102, loss = 0.07070464
# Iteration 103, loss = 0.07007219
# Iteration 104, loss = 0.06941825
# Iteration 105, loss = 0.06879176
# Iteration 106, loss = 0.06815707
# Iteration 107, loss = 0.06755838
# Iteration 108, loss = 0.06693401
# Iteration 109, loss = 0.06633604
# Iteration 110, loss = 0.06572562
# Iteration 111, loss = 0.06516285
# Iteration 112, loss = 0.06458246
# Iteration 113, loss = 0.06403258
# Iteration 114, loss = 0.06344059
# Iteration 115, loss = 0.06290480
# Iteration 116, loss = 0.06236677
# Iteration 117, loss = 0.06182094
# Iteration 118, loss = 0.06126912
# Iteration 119, loss = 0.06075820
# Iteration 120, loss = 0.06022043
# Iteration 121, loss = 0.05970858
# Iteration 122, loss = 0.05921080
# Iteration 123, loss = 0.05871593
# Iteration 124, loss = 0.05823465
# Iteration 125, loss = 0.05772466
# Iteration 126, loss = 0.05723314
# Iteration 127, loss = 0.05675031
# Iteration 128, loss = 0.05629109
# Iteration 129, loss = 0.05582700
# Iteration 130, loss = 0.05535942
# Iteration 131, loss = 0.05490038
# Iteration 132, loss = 0.05445160
# Iteration 133, loss = 0.05399933
# Iteration 134, loss = 0.05356374
# Iteration 135, loss = 0.05311151
# Iteration 136, loss = 0.05269991
# Iteration 137, loss = 0.05227646
# Iteration 138, loss = 0.05185293
# Iteration 139, loss = 0.05145370
# Iteration 140, loss = 0.05103538
# Iteration 141, loss = 0.05061836
# Iteration 142, loss = 0.05022099
# Iteration 143, loss = 0.04981668
# Iteration 144, loss = 0.04943658
# Iteration 145, loss = 0.04903247
# Iteration 146, loss = 0.04866490
# Iteration 147, loss = 0.04828879
# Iteration 148, loss = 0.04788836
# Iteration 149, loss = 0.04756377
# Iteration 150, loss = 0.04717194
# Iteration 151, loss = 0.04680663
# Iteration 152, loss = 0.04644802
# Iteration 153, loss = 0.04609473
# Iteration 154, loss = 0.04573549
# Iteration 155, loss = 0.04537847
# Iteration 156, loss = 0.04503193
# Iteration 157, loss = 0.04468181
# Iteration 158, loss = 0.04436581
# Iteration 159, loss = 0.04401166
# Iteration 160, loss = 0.04369622
# Iteration 161, loss = 0.04336244
# Iteration 162, loss = 0.04304743
# Iteration 163, loss = 0.04271580
# Iteration 164, loss = 0.04240576
# Iteration 165, loss = 0.04209110
# Iteration 166, loss = 0.04178394
# Iteration 167, loss = 0.04147695
# Iteration 168, loss = 0.04116043
# Iteration 169, loss = 0.04087075
# Iteration 170, loss = 0.04058194
# Iteration 171, loss = 0.04027878
# Iteration 172, loss = 0.03999184
# Iteration 173, loss = 0.03969167
# Iteration 174, loss = 0.03941525
# Iteration 175, loss = 0.03913127
# Iteration 176, loss = 0.03885269
# Iteration 177, loss = 0.03857709
# Iteration 178, loss = 0.03829038
# Iteration 179, loss = 0.03803813
# Iteration 180, loss = 0.03776184
# Iteration 181, loss = 0.03749487
# Iteration 182, loss = 0.03724137
# Iteration 183, loss = 0.03696407
# Iteration 184, loss = 0.03670719
# Iteration 185, loss = 0.03647028
# Iteration 186, loss = 0.03619750
# Iteration 187, loss = 0.03595869
# Iteration 188, loss = 0.03571236
# Iteration 189, loss = 0.03546900
# Iteration 190, loss = 0.03521720
# Iteration 191, loss = 0.03498293
# Iteration 192, loss = 0.03474810
# Iteration 193, loss = 0.03449958
# Iteration 194, loss = 0.03427902
# Iteration 195, loss = 0.03404070
# Iteration 196, loss = 0.03380672
# Iteration 197, loss = 0.03357467
# Iteration 198, loss = 0.03336120
# Iteration 199, loss = 0.03314640
# Iteration 200, loss = 0.03291383
# 47.125415100000055
# SGD - Training Size: 40%
# C:\ProgramData\Anaconda3\envs\CS7641\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Iteration 1, loss = 1.43011053
# Iteration 2, loss = 0.66292790
# Iteration 3, loss = 0.49861141
# Iteration 4, loss = 0.42149056
# Iteration 5, loss = 0.37484445
# Iteration 6, loss = 0.34245608
# Iteration 7, loss = 0.31818014
# Iteration 8, loss = 0.29912574
# Iteration 9, loss = 0.28351595
# Iteration 10, loss = 0.27033563
# Iteration 11, loss = 0.25893464
# Iteration 12, loss = 0.24920349
# Iteration 13, loss = 0.24029177
# Iteration 14, loss = 0.23242182
# Iteration 15, loss = 0.22519341
# Iteration 16, loss = 0.21860114
# Iteration 17, loss = 0.21253056
# Iteration 18, loss = 0.20688672
# Iteration 19, loss = 0.20151947
# Iteration 20, loss = 0.19655801
# Iteration 21, loss = 0.19191773
# Iteration 22, loss = 0.18753797
# Iteration 23, loss = 0.18332392
# Iteration 24, loss = 0.17942549
# Iteration 25, loss = 0.17565034
# Iteration 26, loss = 0.17204510
# Iteration 27, loss = 0.16870161
# Iteration 28, loss = 0.16544749
# Iteration 29, loss = 0.16228338
# Iteration 30, loss = 0.15928495
# Iteration 31, loss = 0.15636206
# Iteration 32, loss = 0.15360014
# Iteration 33, loss = 0.15085753
# Iteration 34, loss = 0.14827953
# Iteration 35, loss = 0.14579575
# Iteration 36, loss = 0.14336202
# Iteration 37, loss = 0.14105151
# Iteration 38, loss = 0.13868871
# Iteration 39, loss = 0.13653243
# Iteration 40, loss = 0.13442577
# Iteration 41, loss = 0.13234021
# Iteration 42, loss = 0.13034670
# Iteration 43, loss = 0.12836428
# Iteration 44, loss = 0.12652942
# Iteration 45, loss = 0.12473011
# Iteration 46, loss = 0.12290751
# Iteration 47, loss = 0.12119189
# Iteration 48, loss = 0.11947611
# Iteration 49, loss = 0.11783202
# Iteration 50, loss = 0.11622697
# Iteration 51, loss = 0.11463840
# Iteration 52, loss = 0.11311226
# Iteration 53, loss = 0.11163110
# Iteration 54, loss = 0.11015007
# Iteration 55, loss = 0.10870502
# Iteration 56, loss = 0.10740477
# Iteration 57, loss = 0.10598558
# Iteration 58, loss = 0.10463947
# Iteration 59, loss = 0.10333504
# Iteration 60, loss = 0.10205080
# Iteration 61, loss = 0.10079729
# Iteration 62, loss = 0.09959269
# Iteration 63, loss = 0.09840583
# Iteration 64, loss = 0.09720596
# Iteration 65, loss = 0.09603641
# Iteration 66, loss = 0.09490484
# Iteration 67, loss = 0.09381808
# Iteration 68, loss = 0.09270568
# Iteration 69, loss = 0.09165074
# Iteration 70, loss = 0.09060944
# Iteration 71, loss = 0.08957135
# Iteration 72, loss = 0.08859845
# Iteration 73, loss = 0.08756059
# Iteration 74, loss = 0.08659435
# Iteration 75, loss = 0.08562718
# Iteration 76, loss = 0.08469775
# Iteration 77, loss = 0.08374585
# Iteration 78, loss = 0.08285738
# Iteration 79, loss = 0.08196814
# Iteration 80, loss = 0.08110562
# Iteration 81, loss = 0.08023062
# Iteration 82, loss = 0.07938130
# Iteration 83, loss = 0.07856066
# Iteration 84, loss = 0.07773688
# Iteration 85, loss = 0.07692684
# Iteration 86, loss = 0.07612267
# Iteration 87, loss = 0.07536294
# Iteration 88, loss = 0.07458631
# Iteration 89, loss = 0.07381730
# Iteration 90, loss = 0.07307380
# Iteration 91, loss = 0.07235443
# Iteration 92, loss = 0.07162182
# Iteration 93, loss = 0.07090879
# Iteration 94, loss = 0.07020492
# Iteration 95, loss = 0.06951023
# Iteration 96, loss = 0.06883081
# Iteration 97, loss = 0.06815488
# Iteration 98, loss = 0.06748953
# Iteration 99, loss = 0.06685359
# Iteration 100, loss = 0.06621067
# Iteration 101, loss = 0.06557378
# Iteration 102, loss = 0.06494617
# Iteration 103, loss = 0.06435892
# Iteration 104, loss = 0.06373579
# Iteration 105, loss = 0.06315274
# Iteration 106, loss = 0.06253574
# Iteration 107, loss = 0.06196740
# Iteration 108, loss = 0.06138428
# Iteration 109, loss = 0.06081162
# Iteration 110, loss = 0.06024773
# Iteration 111, loss = 0.05972523
# Iteration 112, loss = 0.05916585
# Iteration 113, loss = 0.05862129
# Iteration 114, loss = 0.05808345
# Iteration 115, loss = 0.05756979
# Iteration 116, loss = 0.05706532
# Iteration 117, loss = 0.05654534
# Iteration 118, loss = 0.05606091
# Iteration 119, loss = 0.05555164
# Iteration 120, loss = 0.05505358
# Iteration 121, loss = 0.05455869
# Iteration 122, loss = 0.05407618
# Iteration 123, loss = 0.05359491
# Iteration 124, loss = 0.05311841
# Iteration 125, loss = 0.05266800
# Iteration 126, loss = 0.05224793
# Iteration 127, loss = 0.05176912
# Iteration 128, loss = 0.05130476
# Iteration 129, loss = 0.05088719
# Iteration 130, loss = 0.05044151
# Iteration 131, loss = 0.05001763
# Iteration 132, loss = 0.04959003
# Iteration 133, loss = 0.04917205
# Iteration 134, loss = 0.04875307
# Iteration 135, loss = 0.04833495
# Iteration 136, loss = 0.04793629
# Iteration 137, loss = 0.04753466
# Iteration 138, loss = 0.04713965
# Iteration 139, loss = 0.04675897
# Iteration 140, loss = 0.04636165
# Iteration 141, loss = 0.04599123
# Iteration 142, loss = 0.04561150
# Iteration 143, loss = 0.04524054
# Iteration 144, loss = 0.04487651
# Iteration 145, loss = 0.04450158
# Iteration 146, loss = 0.04414224
# Iteration 147, loss = 0.04378861
# Iteration 148, loss = 0.04344603
# Iteration 149, loss = 0.04309564
# Iteration 150, loss = 0.04273975
# Iteration 151, loss = 0.04242118
# Iteration 152, loss = 0.04208738
# Iteration 153, loss = 0.04175235
# Iteration 154, loss = 0.04142646
# Iteration 155, loss = 0.04110285
# Iteration 156, loss = 0.04077329
# Iteration 157, loss = 0.04045460
# Iteration 158, loss = 0.04015932
# Iteration 159, loss = 0.03985056
# Iteration 160, loss = 0.03954522
# Iteration 161, loss = 0.03922813
# Iteration 162, loss = 0.03895442
# Iteration 163, loss = 0.03863928
# Iteration 164, loss = 0.03834443
# Iteration 165, loss = 0.03805766
# Iteration 166, loss = 0.03777136
# Iteration 167, loss = 0.03749002
# Iteration 168, loss = 0.03720933
# Iteration 169, loss = 0.03692183
# Iteration 170, loss = 0.03664845
# Iteration 171, loss = 0.03639263
# Iteration 172, loss = 0.03612489
# Iteration 173, loss = 0.03585076
# Iteration 174, loss = 0.03559310
# Iteration 175, loss = 0.03532474
# Iteration 176, loss = 0.03506450
# Iteration 177, loss = 0.03479808
# Iteration 178, loss = 0.03456547
# Iteration 179, loss = 0.03431613
# Iteration 180, loss = 0.03406847
# Iteration 181, loss = 0.03381903
# Iteration 182, loss = 0.03357494
# Iteration 183, loss = 0.03334195
# Iteration 184, loss = 0.03309838
# Iteration 185, loss = 0.03287890
# Iteration 186, loss = 0.03264008
# Iteration 187, loss = 0.03239950
# Iteration 188, loss = 0.03218065
# Iteration 189, loss = 0.03195850
# Iteration 190, loss = 0.03173180
# Iteration 191, loss = 0.03151928
# Iteration 192, loss = 0.03129250
# Iteration 193, loss = 0.03106968
# Iteration 194, loss = 0.03087823
# Iteration 195, loss = 0.03065513
# Iteration 196, loss = 0.03045438
# Iteration 197, loss = 0.03023954
# Iteration 198, loss = 0.03004347
# Iteration 199, loss = 0.02983641
# Iteration 200, loss = 0.02962485
# 63.331296000000066
# SGD - Training Size: 50%
# C:\ProgramData\Anaconda3\envs\CS7641\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Iteration 1, loss = 1.26074840
# Iteration 2, loss = 0.57567422
# Iteration 3, loss = 0.44545541
# Iteration 4, loss = 0.38163098
# Iteration 5, loss = 0.34150440
# Iteration 6, loss = 0.31309606
# Iteration 7, loss = 0.29149546
# Iteration 8, loss = 0.27423570
# Iteration 9, loss = 0.25989313
# Iteration 10, loss = 0.24779734
# Iteration 11, loss = 0.23718556
# Iteration 12, loss = 0.22781634
# Iteration 13, loss = 0.21943688
# Iteration 14, loss = 0.21183251
# Iteration 15, loss = 0.20491730
# Iteration 16, loss = 0.19858617
# Iteration 17, loss = 0.19276318
# Iteration 18, loss = 0.18738895
# Iteration 19, loss = 0.18236483
# Iteration 20, loss = 0.17762250
# Iteration 21, loss = 0.17318778
# Iteration 22, loss = 0.16900029
# Iteration 23, loss = 0.16506960
# Iteration 24, loss = 0.16137062
# Iteration 25, loss = 0.15782145
# Iteration 26, loss = 0.15440783
# Iteration 27, loss = 0.15123655
# Iteration 28, loss = 0.14815171
# Iteration 29, loss = 0.14522210
# Iteration 30, loss = 0.14246159
# Iteration 31, loss = 0.13972064
# Iteration 32, loss = 0.13716055
# Iteration 33, loss = 0.13462597
# Iteration 34, loss = 0.13222411
# Iteration 35, loss = 0.12992860
# Iteration 36, loss = 0.12769119
# Iteration 37, loss = 0.12556584
# Iteration 38, loss = 0.12346560
# Iteration 39, loss = 0.12147018
# Iteration 40, loss = 0.11954678
# Iteration 41, loss = 0.11768415
# Iteration 42, loss = 0.11582019
# Iteration 43, loss = 0.11404969
# Iteration 44, loss = 0.11236525
# Iteration 45, loss = 0.11065890
# Iteration 46, loss = 0.10907435
# Iteration 47, loss = 0.10749532
# Iteration 48, loss = 0.10594127
# Iteration 49, loss = 0.10440488
# Iteration 50, loss = 0.10297657
# Iteration 51, loss = 0.10151646
# Iteration 52, loss = 0.10016564
# Iteration 53, loss = 0.09880714
# Iteration 54, loss = 0.09746794
# Iteration 55, loss = 0.09621076
# Iteration 56, loss = 0.09494264
# Iteration 57, loss = 0.09370550
# Iteration 58, loss = 0.09248999
# Iteration 59, loss = 0.09134949
# Iteration 60, loss = 0.09016166
# Iteration 61, loss = 0.08903144
# Iteration 62, loss = 0.08795807
# Iteration 63, loss = 0.08687153
# Iteration 64, loss = 0.08579932
# Iteration 65, loss = 0.08478698
# Iteration 66, loss = 0.08377567
# Iteration 67, loss = 0.08274808
# Iteration 68, loss = 0.08180906
# Iteration 69, loss = 0.08085412
# Iteration 70, loss = 0.07991780
# Iteration 71, loss = 0.07902204
# Iteration 72, loss = 0.07808998
# Iteration 73, loss = 0.07722050
# Iteration 74, loss = 0.07635223
# Iteration 75, loss = 0.07551553
# Iteration 76, loss = 0.07468213
# Iteration 77, loss = 0.07387301
# Iteration 78, loss = 0.07306733
# Iteration 79, loss = 0.07223233
# Iteration 80, loss = 0.07150426
# Iteration 81, loss = 0.07070681
# Iteration 82, loss = 0.06996319
# Iteration 83, loss = 0.06920768
# Iteration 84, loss = 0.06845817
# Iteration 85, loss = 0.06775840
# Iteration 86, loss = 0.06706346
# Iteration 87, loss = 0.06637305
# Iteration 88, loss = 0.06567194
# Iteration 89, loss = 0.06501939
# Iteration 90, loss = 0.06433259
# Iteration 91, loss = 0.06369249
# Iteration 92, loss = 0.06304909
# Iteration 93, loss = 0.06242948
# Iteration 94, loss = 0.06179686
# Iteration 95, loss = 0.06118659
# Iteration 96, loss = 0.06059022
# Iteration 97, loss = 0.05999365
# Iteration 98, loss = 0.05941018
# Iteration 99, loss = 0.05883840
# Iteration 100, loss = 0.05824060
# Iteration 101, loss = 0.05768540
# Iteration 102, loss = 0.05713666
# Iteration 103, loss = 0.05660083
# Iteration 104, loss = 0.05605678
# Iteration 105, loss = 0.05551582
# Iteration 106, loss = 0.05499364
# Iteration 107, loss = 0.05448400
# Iteration 108, loss = 0.05397568
# Iteration 109, loss = 0.05346566
# Iteration 110, loss = 0.05299170
# Iteration 111, loss = 0.05246636
# Iteration 112, loss = 0.05199481
# Iteration 113, loss = 0.05150987
# Iteration 114, loss = 0.05105237
# Iteration 115, loss = 0.05057580
# Iteration 116, loss = 0.05012645
# Iteration 117, loss = 0.04967066
# Iteration 118, loss = 0.04923386
# Iteration 119, loss = 0.04879399
# Iteration 120, loss = 0.04832853
# Iteration 121, loss = 0.04791859
# Iteration 122, loss = 0.04748513
# Iteration 123, loss = 0.04708401
# Iteration 124, loss = 0.04666136
# Iteration 125, loss = 0.04626166
# Iteration 126, loss = 0.04585273
# Iteration 127, loss = 0.04544019
# Iteration 128, loss = 0.04504159
# Iteration 129, loss = 0.04466836
# Iteration 130, loss = 0.04428292
# Iteration 131, loss = 0.04391664
# Iteration 132, loss = 0.04353995
# Iteration 133, loss = 0.04315997
# Iteration 134, loss = 0.04280415
# Iteration 135, loss = 0.04245546
# Iteration 136, loss = 0.04210975
# Iteration 137, loss = 0.04172542
# Iteration 138, loss = 0.04139371
# Iteration 139, loss = 0.04104182
# Iteration 140, loss = 0.04069436
# Iteration 141, loss = 0.04037314
# Iteration 142, loss = 0.04003409
# Iteration 143, loss = 0.03970145
# Iteration 144, loss = 0.03938091
# Iteration 145, loss = 0.03906543
# Iteration 146, loss = 0.03873737
# Iteration 147, loss = 0.03842210
# Iteration 148, loss = 0.03811916
# Iteration 149, loss = 0.03782474
# Iteration 150, loss = 0.03750695
# Iteration 151, loss = 0.03721755
# Iteration 152, loss = 0.03694490
# Iteration 153, loss = 0.03663050
# Iteration 154, loss = 0.03633744
# Iteration 155, loss = 0.03606311
# Iteration 156, loss = 0.03578390
# Iteration 157, loss = 0.03550742
# Iteration 158, loss = 0.03523181
# Iteration 159, loss = 0.03497176
# Iteration 160, loss = 0.03468623
# Iteration 161, loss = 0.03441756
# Iteration 162, loss = 0.03416265
# Iteration 163, loss = 0.03390528
# Iteration 164, loss = 0.03363922
# Iteration 165, loss = 0.03339505
# Iteration 166, loss = 0.03313011
# ...
# Iteration 138, loss = 0.03606275
# Iteration 139, loss = 0.03577104
# Iteration 140, loss = 0.03548035
# Iteration 141, loss = 0.03517571
# Iteration 142, loss = 0.03489080
# Iteration 143, loss = 0.03461187
# Iteration 144, loss = 0.03431089
# Iteration 145, loss = 0.03404298
# Iteration 146, loss = 0.03376290
# Iteration 147, loss = 0.03349285
# Iteration 148, loss = 0.03321980
# Iteration 149, loss = 0.03295729
# Iteration 150, loss = 0.03269304
# Iteration 151, loss = 0.03242216
# Iteration 152, loss = 0.03218135
# Iteration 153, loss = 0.03190891
# Iteration 154, loss = 0.03166104
# Iteration 155, loss = 0.03140502
# Iteration 156, loss = 0.03114344
# Iteration 157, loss = 0.03091854
# Iteration 158, loss = 0.03067127
# Iteration 159, loss = 0.03042569
# Iteration 160, loss = 0.03020290
# Iteration 161, loss = 0.02995462
# Iteration 162, loss = 0.02973909
# Iteration 163, loss = 0.02949698
# Iteration 164, loss = 0.02927190
# Iteration 165, loss = 0.02904861
# Iteration 166, loss = 0.02883258
# Iteration 167, loss = 0.02860089
# Iteration 168, loss = 0.02839037
# Iteration 169, loss = 0.02817150
# Iteration 170, loss = 0.02795343
# Iteration 171, loss = 0.02774177
# Iteration 172, loss = 0.02753362
# Iteration 173, loss = 0.02733366
# Iteration 174, loss = 0.02713711
# Iteration 175, loss = 0.02691590
# Iteration 176, loss = 0.02672345
# Iteration 177, loss = 0.02652382
# Iteration 178, loss = 0.02632892
# Iteration 179, loss = 0.02612867
# Iteration 180, loss = 0.02593555
# Iteration 181, loss = 0.02575360
# Iteration 182, loss = 0.02556381
# Iteration 183, loss = 0.02536592
# Iteration 184, loss = 0.02518404
# Iteration 185, loss = 0.02501328
# Iteration 186, loss = 0.02482831
# Iteration 187, loss = 0.02465250
# Iteration 188, loss = 0.02446714
# Iteration 189, loss = 0.02429734
# Iteration 190, loss = 0.02412317
# Iteration 191, loss = 0.02395802
# Iteration 192, loss = 0.02378068
# Iteration 193, loss = 0.02362848
# Iteration 194, loss = 0.02344683
# Iteration 195, loss = 0.02328993
# Iteration 196, loss = 0.02312666
# Iteration 197, loss = 0.02296240
# Iteration 198, loss = 0.02280850
# Iteration 199, loss = 0.02263620
# Iteration 200, loss = 0.02249257
# 125.00973049999993
# SGD - Training Size: 90%
# C:\ProgramData\Anaconda3\envs\CS7641\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Iteration 1, loss = 1.07951692
# Iteration 2, loss = 0.46269071
# Iteration 3, loss = 0.36306733
# Iteration 4, loss = 0.31330069
# Iteration 5, loss = 0.28170013
# Iteration 6, loss = 0.25932139
# Iteration 7, loss = 0.24210290
# Iteration 8, loss = 0.22812117
# Iteration 9, loss = 0.21648409
# Iteration 10, loss = 0.20645210
# Iteration 11, loss = 0.19775574
# Iteration 12, loss = 0.18999003
# Iteration 13, loss = 0.18306430
# Iteration 14, loss = 0.17676100
# Iteration 15, loss = 0.17111470
# Iteration 16, loss = 0.16580960
# Iteration 17, loss = 0.16097379
# Iteration 18, loss = 0.15645660
# Iteration 19, loss = 0.15220087
# Iteration 20, loss = 0.14827463
# Iteration 21, loss = 0.14455747
# Iteration 22, loss = 0.14105947
# Iteration 23, loss = 0.13775655
# Iteration 24, loss = 0.13460622
# Iteration 25, loss = 0.13167784
# Iteration 26, loss = 0.12882104
# Iteration 27, loss = 0.12612012
# Iteration 28, loss = 0.12353459
# Iteration 29, loss = 0.12107921
# Iteration 30, loss = 0.11870394
# Iteration 31, loss = 0.11646199
# Iteration 32, loss = 0.11426134
# Iteration 33, loss = 0.11216329
# Iteration 34, loss = 0.11013998
# Iteration 35, loss = 0.10817773
# Iteration 36, loss = 0.10627411
# Iteration 37, loss = 0.10446669
# Iteration 38, loss = 0.10270852
# Iteration 39, loss = 0.10101438
# Iteration 40, loss = 0.09934978
# Iteration 41, loss = 0.09770711
# Iteration 42, loss = 0.09621571
# Iteration 43, loss = 0.09468086
# Iteration 44, loss = 0.09321384
# Iteration 45, loss = 0.09184519
# Iteration 46, loss = 0.09040634
# Iteration 47, loss = 0.08907097
# Iteration 48, loss = 0.08778701
# Iteration 49, loss = 0.08651149
# Iteration 50, loss = 0.08527490
# Iteration 51, loss = 0.08410722
# Iteration 52, loss = 0.08290638
# Iteration 53, loss = 0.08174305
# Iteration 54, loss = 0.08064615
# Iteration 55, loss = 0.07958770
# Iteration 56, loss = 0.07849096
# Iteration 57, loss = 0.07744735
# Iteration 58, loss = 0.07646494
# Iteration 59, loss = 0.07545672
# Iteration 60, loss = 0.07449734
# Iteration 61, loss = 0.07353212
# Iteration 62, loss = 0.07261435
# Iteration 63, loss = 0.07170741
# Iteration 64, loss = 0.07083254
# Iteration 65, loss = 0.06993125
# Iteration 66, loss = 0.06907200
# Iteration 67, loss = 0.06825186
# Iteration 68, loss = 0.06744397
# Iteration 69, loss = 0.06662744
# Iteration 70, loss = 0.06583203
# Iteration 71, loss = 0.06506960
# Iteration 72, loss = 0.06430271
# Iteration 73, loss = 0.06356229
# Iteration 74, loss = 0.06281868
# Iteration 75, loss = 0.06209722
# Iteration 76, loss = 0.06139357
# Iteration 77, loss = 0.06070797
# Iteration 78, loss = 0.06002609
# Iteration 79, loss = 0.05938485
# Iteration 80, loss = 0.05870083
# Iteration 81, loss = 0.05807716
# Iteration 82, loss = 0.05742884
# Iteration 83, loss = 0.05681747
# Iteration 84, loss = 0.05621046
# Iteration 85, loss = 0.05560137
# Iteration 86, loss = 0.05501596
# Iteration 87, loss = 0.05443383
# Iteration 88, loss = 0.05384939
# Iteration 89, loss = 0.05329707
# Iteration 90, loss = 0.05273362
# Iteration 91, loss = 0.05219311
# Iteration 92, loss = 0.05164516
# Iteration 93, loss = 0.05113033
# Iteration 94, loss = 0.05060818
# Iteration 95, loss = 0.05011064
# Iteration 96, loss = 0.04959711
# Iteration 97, loss = 0.04909663
# Iteration 98, loss = 0.04860534
# Iteration 99, loss = 0.04811677
# Iteration 100, loss = 0.04765154
# Iteration 101, loss = 0.04717051
# Iteration 102, loss = 0.04672350
# Iteration 103, loss = 0.04624608
# Iteration 104, loss = 0.04582486
# Iteration 105, loss = 0.04538129
# Iteration 106, loss = 0.04494170
# Iteration 107, loss = 0.04451607
# Iteration 108, loss = 0.04408361
# Iteration 109, loss = 0.04365658
# Iteration 110, loss = 0.04324340
# Iteration 111, loss = 0.04284459
# Iteration 112, loss = 0.04244330
# Iteration 113, loss = 0.04204419
# Iteration 114, loss = 0.04165718
# Iteration 115, loss = 0.04125928
# Iteration 116, loss = 0.04091129
# Iteration 117, loss = 0.04051390
# Iteration 118, loss = 0.04014487
# Iteration 119, loss = 0.03977396
# Iteration 120, loss = 0.03941745
# Iteration 121, loss = 0.03906238
# Iteration 122, loss = 0.03869919
# Iteration 123, loss = 0.03836512
# Iteration 124, loss = 0.03801845
# Iteration 125, loss = 0.03766652
# Iteration 126, loss = 0.03735123
# Iteration 127, loss = 0.03701820
# Iteration 128, loss = 0.03667581
# Iteration 129, loss = 0.03635946
# Iteration 130, loss = 0.03604266
# Iteration 131, loss = 0.03574406
# Iteration 132, loss = 0.03541698
# Iteration 133, loss = 0.03512632
# Iteration 134, loss = 0.03482116
# Iteration 135, loss = 0.03452306
# Iteration 136, loss = 0.03422629
# Iteration 137, loss = 0.03393687
# Iteration 138, loss = 0.03365301
# Iteration 139, loss = 0.03335986
# Iteration 140, loss = 0.03308719
# Iteration 141, loss = 0.03281837
# Iteration 142, loss = 0.03253502
# Iteration 143, loss = 0.03227033
# Iteration 144, loss = 0.03199592
# Iteration 145, loss = 0.03173477
# Iteration 146, loss = 0.03147964
# Iteration 147, loss = 0.03123622
# Iteration 148, loss = 0.03097786
# Iteration 149, loss = 0.03073029
# Iteration 150, loss = 0.03046810
# Iteration 151, loss = 0.03022439
# Iteration 152, loss = 0.02999619
# Iteration 153, loss = 0.02973062
# Iteration 154, loss = 0.02951411
# Iteration 155, loss = 0.02927336
# Iteration 156, loss = 0.02904256
# Iteration 157, loss = 0.02880390
# Iteration 158, loss = 0.02859515
# Iteration 159, loss = 0.02835893
# Iteration 160, loss = 0.02814208
# Iteration 161, loss = 0.02792491
# Iteration 162, loss = 0.02770461
# Iteration 163, loss = 0.02748820
# Iteration 164, loss = 0.02728147
# Iteration 165, loss = 0.02707843
# Iteration 166, loss = 0.02686566
# Iteration 167, loss = 0.02665598
# Iteration 168, loss = 0.02645132
# Iteration 169, loss = 0.02625771
# Iteration 170, loss = 0.02606226
# Iteration 171, loss = 0.02586112
# Iteration 172, loss = 0.02566292
# Iteration 173, loss = 0.02546519
# Iteration 174, loss = 0.02529809
# Iteration 175, loss = 0.02509494
# Iteration 176, loss = 0.02490876
# Iteration 177, loss = 0.02472845
# Iteration 178, loss = 0.02456075
# Iteration 179, loss = 0.02436532
# Iteration 180, loss = 0.02419496
# Iteration 181, loss = 0.02400599
# Iteration 182, loss = 0.02384116
# Iteration 183, loss = 0.02365380
# Iteration 184, loss = 0.02348770
# Iteration 185, loss = 0.02332126
# Iteration 186, loss = 0.02315461
# Iteration 187, loss = 0.02298588
# Iteration 188, loss = 0.02282313
# Iteration 189, loss = 0.02266029
# Iteration 190, loss = 0.02250310
# Iteration 191, loss = 0.02234208
# Iteration 192, loss = 0.02217695
# Iteration 193, loss = 0.02202748
# Iteration 194, loss = 0.02186857
# Iteration 195, loss = 0.02172296
# Iteration 196, loss = 0.02156758
# Iteration 197, loss = 0.02142217
# Iteration 198, loss = 0.02126700
# Iteration 199, loss = 0.02111729
# Iteration 200, loss = 0.02098324
# 139.92905949999977
# SGD - Training Size: 100%
# C:\ProgramData\Anaconda3\envs\CS7641\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Iteration 1, loss = 0.95589176
# Iteration 2, loss = 0.42401589
# Iteration 3, loss = 0.33649144
# Iteration 4, loss = 0.29270968
# Iteration 5, loss = 0.26456257
# Iteration 6, loss = 0.24413925
# Iteration 7, loss = 0.22851430
# Iteration 8, loss = 0.21576264
# Iteration 9, loss = 0.20503034
# Iteration 10, loss = 0.19579294
# Iteration 11, loss = 0.18773906
# Iteration 12, loss = 0.18055867
# Iteration 13, loss = 0.17412845
# Iteration 14, loss = 0.16835538
# Iteration 15, loss = 0.16306514
# Iteration 16, loss = 0.15824064
# Iteration 17, loss = 0.15377430
# Iteration 18, loss = 0.14963458
# Iteration 19, loss = 0.14571155
# Iteration 20, loss = 0.14207751
# Iteration 21, loss = 0.13867218
# Iteration 22, loss = 0.13543398
# Iteration 23, loss = 0.13239158
# Iteration 24, loss = 0.12950918
# Iteration 25, loss = 0.12672837
# Iteration 26, loss = 0.12414247
# Iteration 27, loss = 0.12159044
# Iteration 28, loss = 0.11923763
# Iteration 29, loss = 0.11694130
# Iteration 30, loss = 0.11474947
# Iteration 31, loss = 0.11261508
# Iteration 32, loss = 0.11061214
# Iteration 33, loss = 0.10871788
# Iteration 34, loss = 0.10678281
# Iteration 35, loss = 0.10499117
# Iteration 36, loss = 0.10320714
# Iteration 37, loss = 0.10147934
# Iteration 38, loss = 0.09987608
# Iteration 39, loss = 0.09828053
# Iteration 40, loss = 0.09672509
# Iteration 41, loss = 0.09525119
# Iteration 42, loss = 0.09380997
# Iteration 43, loss = 0.09238049
# Iteration 44, loss = 0.09103109
# Iteration 45, loss = 0.08971055
# Iteration 46, loss = 0.08839736
# Iteration 47, loss = 0.08715937
# Iteration 48, loss = 0.08590524
# Iteration 49, loss = 0.08474947
# Iteration 50, loss = 0.08357063
# Iteration 51, loss = 0.08243135
# Iteration 52, loss = 0.08132367
# Iteration 53, loss = 0.08022402
# Iteration 54, loss = 0.07915484
# Iteration 55, loss = 0.07811840
# Iteration 56, loss = 0.07711049
# Iteration 57, loss = 0.07614184
# Iteration 58, loss = 0.07515498
# Iteration 59, loss = 0.07420108
# Iteration 60, loss = 0.07325374
# Iteration 61, loss = 0.07234117
# Iteration 62, loss = 0.07146075
# Iteration 63, loss = 0.07058390
# Iteration 64, loss = 0.06972584
# Iteration 65, loss = 0.06890505
# Iteration 66, loss = 0.06803284
# Iteration 67, loss = 0.06720990
# Iteration 68, loss = 0.06644144
# Iteration 69, loss = 0.06566450
# Iteration 70, loss = 0.06489244
# Iteration 71, loss = 0.06414798
# Iteration 72, loss = 0.06339196
# Iteration 73, loss = 0.06266644
# Iteration 74, loss = 0.06195212
# Iteration 75, loss = 0.06123752
# Iteration 76, loss = 0.06055795
# Iteration 77, loss = 0.05986977
# Iteration 78, loss = 0.05925981
# Iteration 79, loss = 0.05857627
# Iteration 80, loss = 0.05793002
# Iteration 81, loss = 0.05730917
# Iteration 82, loss = 0.05669517
# Iteration 83, loss = 0.05608672
# Iteration 84, loss = 0.05548086
# Iteration 85, loss = 0.05487015
# Iteration 86, loss = 0.05429364
# Iteration 87, loss = 0.05372897
# Iteration 88, loss = 0.05316779
# Iteration 89, loss = 0.05261289
# Iteration 90, loss = 0.05206251
# Iteration 91, loss = 0.05153878
# Iteration 92, loss = 0.05099440
# Iteration 93, loss = 0.05048481
# Iteration 94, loss = 0.04995110
# Iteration 95, loss = 0.04947164
# Iteration 96, loss = 0.04895362
# Iteration 97, loss = 0.04847257
# Iteration 98, loss = 0.04798468
# Iteration 99, loss = 0.04750600
# Iteration 100, loss = 0.04703240
# Iteration 101, loss = 0.04659862
# Iteration 102, loss = 0.04613344
# Iteration 103, loss = 0.04568814
# Iteration 104, loss = 0.04524191
# Iteration 105, loss = 0.04480144
# Iteration 106, loss = 0.04436557
# Iteration 107, loss = 0.04397114
# Iteration 108, loss = 0.04353817
# Iteration 109, loss = 0.04312833
# Iteration 110, loss = 0.04274009
# Iteration 111, loss = 0.04232987
# Iteration 112, loss = 0.04194274
# Iteration 113, loss = 0.04155917
# Iteration 114, loss = 0.04115411
# Iteration 115, loss = 0.04079556
# Iteration 116, loss = 0.04040197
# Iteration 117, loss = 0.04006254
# Iteration 118, loss = 0.03967465
# Iteration 119, loss = 0.03931210
# Iteration 120, loss = 0.03897323
# Iteration 121, loss = 0.03862302
# Iteration 122, loss = 0.03827963
# Iteration 123, loss = 0.03793074
# Iteration 124, loss = 0.03759598
# Iteration 125, loss = 0.03725489
# Iteration 126, loss = 0.03694266
# Iteration 127, loss = 0.03662408
# Iteration 128, loss = 0.03629200
# Iteration 129, loss = 0.03596982
# Iteration 130, loss = 0.03565834
# Iteration 131, loss = 0.03536310
# Iteration 132, loss = 0.03505543
# Iteration 133, loss = 0.03476770
# Iteration 134, loss = 0.03447147
# Iteration 135, loss = 0.03418145
# Iteration 136, loss = 0.03389048
# Iteration 137, loss = 0.03359725
# Iteration 138, loss = 0.03332050
# Iteration 139, loss = 0.03304591
# Iteration 140, loss = 0.03276939
# Iteration 141, loss = 0.03250391
# Iteration 142, loss = 0.03222833
# Iteration 143, loss = 0.03196064
# Iteration 144, loss = 0.03171919
# Iteration 145, loss = 0.03144524
# Iteration 146, loss = 0.03118570
# Iteration 147, loss = 0.03092665
# Iteration 148, loss = 0.03068749
# Iteration 149, loss = 0.03044369
# Iteration 150, loss = 0.03018863
# Iteration 151, loss = 0.02993731
# Iteration 152, loss = 0.02971280
# Iteration 153, loss = 0.02948660
# Iteration 154, loss = 0.02924243
# Iteration 155, loss = 0.02900078
# Iteration 156, loss = 0.02878191
# Iteration 157, loss = 0.02855526
# Iteration 158, loss = 0.02833283
# Iteration 159, loss = 0.02810363
# Iteration 160, loss = 0.02789807
# Iteration 161, loss = 0.02768813
# Iteration 162, loss = 0.02746487
# Iteration 163, loss = 0.02726657
# Iteration 164, loss = 0.02704178
# Iteration 165, loss = 0.02684970
# Iteration 166, loss = 0.02662073
# Iteration 167, loss = 0.02643904
# Iteration 168, loss = 0.02624081
# Iteration 169, loss = 0.02603803
# Iteration 170, loss = 0.02584818
# Iteration 171, loss = 0.02565296
# Iteration 172, loss = 0.02545466
# Iteration 173, loss = 0.02526956
# Iteration 174, loss = 0.02507007
# Iteration 175, loss = 0.02489062
# Iteration 176, loss = 0.02471302
# Iteration 177, loss = 0.02452938
# Iteration 178, loss = 0.02434758
# Iteration 179, loss = 0.02417004
# Iteration 180, loss = 0.02399662
# Iteration 181, loss = 0.02382581
# Iteration 182, loss = 0.02365075
# Iteration 183, loss = 0.02348244
# Iteration 184, loss = 0.02331062
# Iteration 185, loss = 0.02313504
# Iteration 186, loss = 0.02298683
# Iteration 187, loss = 0.02282207
# Iteration 188, loss = 0.02265221
# Iteration 189, loss = 0.02249673
# Iteration 190, loss = 0.02234126
# Iteration 191, loss = 0.02218770
# Iteration 192, loss = 0.02202747
# Iteration 193, loss = 0.02186806
# Iteration 194, loss = 0.02172014
# Iteration 195, loss = 0.02157730
# Iteration 196, loss = 0.02141776
# Iteration 197, loss = 0.02127347
# Iteration 198, loss = 0.02112117
# Iteration 199, loss = 0.02098658
# Iteration 200, loss = 0.02083713
# 155.84172830000034
# C:\ProgramData\Anaconda3\envs\CS7641\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
adam_accuracy = np.asarray(adam_accuracy)
adam_runtime = np.asarray(adam_runtime)
sgd_accuracy = np.asarray(sgd_accuracy)
sgd_runtime = np.asarray(sgd_runtime)

# %%
adam_accuracy.tofile('adam_accuracy_MNIST.csv',sep=',',format='%.3f')
adam_runtime.tofile('adam_runtime_MNIST.csv',sep=',',format='%.3f')
sgd_accuracy.tofile('sgd_accuracy_MNIST.csv',sep=',',format='%.3f')
sgd_runtime.tofile('sgd_runtime_MNIST.csv',sep=',',format='%.3f')

# %%
with parallel_backend('threading'):
    KNN_Classifier.fit(training_subset, training_sublabels)

# %%
with parallel_backend('threading'):
    Boosted_Classifier.fit(training_subset, training_sublabels)

# %%
with parallel_backend('threading'):
    SVM_Classifier.fit(training_data, training_labels)

# %%
with parallel_backend('threading'):
    DecisionTree_Classifier.fit(training_data, training_labels)

# %%
"""
PREDICTIONS

"""

# %%
plt.close('all')
Neural_Predict = NeuralNetwork_Classifier.predict(testing_data)
Neural_Report = metrics.classification_report(testing_labels, y_pred=Neural_Predict)
print(Neural_Report)

nn_confusion_matrix = metrics.plot_confusion_matrix(NeuralNetwork_Classifier, testing_data,
                                                 testing_labels, values_format=".4g")
nn_confusion_matrix.figure_.suptitle("Neural Network Confusion Matrix")
plt.show()

# %%
plt.close('all')
KNN_Predict = KNN_Classifier.predict(testing_subset)
KNN_Report = metrics.classification_report(testing_sublabels, y_pred=KNN_Predict)
print(KNN_Report)

knn_confusion_matrix = metrics.plot_confusion_matrix(KNN_Classifier, testing_subset,
                                                 testing_sublabels, values_format=".4g")
knn_confusion_matrix.figure_.suptitle("K Nearest Neighbor Confusion Matrix")
plt.show()

# %%
plt.close('all')
Boosted_Predict = Boosted_Classifier.predict(testing_subset)
Boosted_Report = metrics.classification_report(testing_sublabels, y_pred=Boosted_Predict)
print(Boosted_Report)

dt_confusion_matrix = metrics.plot_confusion_matrix(DecisionTree_Classifier, testing_subset,
                                                 testing_sublabels, values_format=".4g")
dt_confusion_matrix.figure_.suptitle("Boosted Decision Tree Confusion Matrix")
plt.show()

# %%
plt.close('all')
SVM_Predict = SVM_Classifier.predict(testing_data)
SVM_Report = metrics.classification_report(testing_labels, y_pred=SVM_Predict)
print(SVM_Report)

svm_confusion_matrix = metrics.plot_confusion_matrix(SVM_Classifier, testing_data,
                                                 testing_labels, values_format=".4g")
svm_confusion_matrix.figure_.suptitle("Support Vector Machine Confusion Matrix")
plt.show()

# %%
plt.close('all')
DecisionTree_Predict = DecisionTree_Classifier.predict(testing_data)
DecisionTree_Report = metrics.classification_report(testing_labels, y_pred=DecisionTree_Predict)
print(DecisionTree_Report)

dt_confusion_matrix = metrics.plot_confusion_matrix(DecisionTree_Classifier, testing_data,
                                                 testing_labels, values_format=".4g")
dt_confusion_matrix.figure_.suptitle("Decision Tree Confusion Matrix")
plt.show()

# %%
DecisionTree_Classifier.get_depth()
# prune_index11(clf=DecisionTree_Classifier, index=0, threshold=50)
# print("Pruned")
# DecisionTree_Classifier.get_depth()

# %%
print("Pruned")

# %%
t = DecisionTree_Classifier
print(type(t))

# %%
"""
Results

"""

# %%
nn_results = FindCorrectPredictions(Neural_Predict, testing_labels)
print(nn_results)

# %%
knn_results = FindCorrectPredictions(KNN_Predict, testing_sublabels)
print(nn_results)

# %%
boosted_results = FindCorrectPredictions(Boosted_Predict,testing_sublabels)
print(boosted_results)

# %%
svm_results = FindCorrectPredictions(SVM_Predict, testing_sublabels)
print(svm_results)

# %%
dt_results = FindCorrectPredictions(DecisionTree_Predict, testing_labels)
print(dt_results)

# %%
adam_accuracy = np.loadtxt("{}/adam_accuracy_MNIST.csv".format(cwd), delimiter=",")
adam_runtime = np.loadtxt("{}/adam_runtime_MNIST.csv".format(cwd), delimiter=",")

# %%
sgd_accuracy = np.loadtxt("{}/sgd_accuracy_MNIST.csv".format(cwd), delimiter=",")
sgd_runtime = np.loadtxt("{}/sgd_runtime_MNIST.csv".format(cwd), delimiter=",")

# %%
print(len(adam_accuracy))
print(adam_accuracy)
print(len(adam_runtime))
print(adam_runtime)
print(len(sgd_accuracy))
print(sgd_accuracy)
print(len(sgd_runtime))
print(sgd_runtime)
# Out:
# 11
# [0.    0.936 0.951 0.962 0.965 0.971 0.973 0.971 0.975 0.972 0.968]
# 11
# [ 0.     6.133 10.558 14.283 17.379 19.987 23.129 26.53  31.935 34.591
#  36.724]
# 11
# [0.    0.928 0.943 0.955 0.96  0.964 0.967 0.967 0.968 0.971 0.972]
# 11
# [  0.     15.701  32.087  47.125  63.331  78.825  94.419 110.086 125.01
#  139.929 155.842]

# %%
print(solvers)

# %%
colors = ["tab:orange", "tab:blue", "tab:green", "tab:red"]

run = [sgd_runtime, adam_runtime]
acc = [sgd_accuracy, adam_accuracy]

for solver in range(len(solvers)):
    with plt.style.context('ggplot'):
        fig0, ax0 = plt.subplots()
        ax0.set_xlabel("Percent of Training Set")
        ax0.set_ylabel("Accuracy (%)", color='tab:orange')
        ax0.set_title("Accuracy vs Training Set Size vs Training Time {} \n MNIST".format(solvers[solver]))
        ax0.tick_params(axis='y', labelcolor="black")
        ax0.set_ylim(0, 1.1)
        ax3 = ax0.twinx()
        ax3.set_ylabel("Training Time (s)", color="tab:blue")
        ax3.set_ylim(0, max(max(adam_runtime), max(sgd_runtime)) + 10)
        ax3.tick_params(axis='y', labelcolor="black")
        for i in range(1):        
            ax0.plot([i for i in range(11)], acc[solver], colors[i], marker='o', label=solvers[solver])
            ax3.plot([i for i in range(11)], run[solver], colors[i+1], marker="1", label="{} training-time".format(solvers[solver]))
        fig0.tight_layout()
        dir = "{}/Training_{}_MNIST_Set_Size_Impact_vs_Training_Time.png".format(cwd, solvers[solver])
        plt.savefig(dir)
#         plt.close("all")
