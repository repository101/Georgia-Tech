# %%
import ml_util as utl

# %%
a = utl.find_best_neural_network_gradient_descent(train_limit=1000)
# Out:
# C:\Users\joshu\OneDrive - Georgia Institute of Technology\Georgia-Tech\CS 7641 - Machine Learning\Assignments\Randomized Optimization\NeuralNetwork/Gradient_Descent folder already exists.
# dataset folder already exists.
# Fashion-MNIST dataset found:
# 	Loading Fashion-MNIST.feather
# 	Finished loading Fashion-MNIST dataset
# Finished making cross-validation sets
# 	Each validation set is a 20.000% subset of the training set, with replacement
# Total Iterations: 8
# 		CV 0: Completed
# 		CV 1: Completed
# 		CV 2: Completed
# 		CV 3: Completed
# 		CV 4: Completed
# 	Current Iteration: 1
# 		Best Training Accuracy: 0.113%
# 		Best Validation Accuracy: 0.106%
# 		Iteration Time: 2.975s
# 			Learning Rate: 0.1000
# 			Max Iterations: 100
# 			Iteration Training Accuracy: 0.113%
# 			Iteration Validation Accuracy: 0.106%
# 		CV 0: Completed
# 		CV 1: Completed
# 		CV 2: Completed
# 		CV 3: Completed
# 		CV 4: Completed
# 	Current Iteration: 2
# 		Best Training Accuracy: 0.113%
# ...

# %%
a.iloc[:,[0, 2]].plot()
# Out:
# <AxesSubplot:>
