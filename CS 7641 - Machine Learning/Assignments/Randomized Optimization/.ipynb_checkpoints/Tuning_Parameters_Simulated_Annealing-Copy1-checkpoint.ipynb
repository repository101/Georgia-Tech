# %%
import time
import mlrose_hiive as mlrose
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.metrics import accuracy_score

random_state = 7
start = 10
stop = 101
step = 10
size = 20
problem_name = "Tuning"
plt.style.use('ggplot')

# %% [markdown]
# ### Tuning Parameters

# %%
weights = np.random.uniform(low=1, high=10, size=size).astype('int')
values = np.random.uniform(low=10, high=100, size=size).astype('int')
max_weight_pct = 0.6
fitness = mlrose.Knapsack(weights, values, max_weight_pct=max_weight_pct)

problem = mlrose.DiscreteOpt(length=size, fitness_fn=fitness, maximize=True, max_val=2)
algo_stats = []

# %% [markdown]
# ### Random Hill Climb -  Parameters

# %%
# Random Hill Climbing

# for max_attempts in range(start, stop, step):
#     print("Random Hill Climbing")
#     print("\t Attempt: {}\n".format(max_attempts))
#     start_time = time.time()*100
#     best_state, best_fitness, curve_vals = mlrose.random_hill_climb(problem, max_attempts=max_attempts, curve=True, random_state=random_state)
#     stop_time = time.time()*100
#     runtime = stop_time - start_time
#     algo_stats.append([problem_name, "Default_RHC", best_state, best_fitness, max_attempts, curve_vals.size, curve_vals, runtime])
  
# for i in range(10, 100, 10):
#     for max_attempts in range(start, stop, step):
#         print("Random Hill Climbing")
#         print("\t Attempt: {}\n".format(max_attempts))
#         start_time = time.time()*100
#         best_state, best_fitness, curve_vals = mlrose.random_hill_climb(problem, 
#                                                                         max_attempts=max_attempts, 
#                                                                         curve=True, 
#                                                                         random_state=random_state,
#                                                                         restarts=i)
#         stop_time = time.time()*100
#         runtime = stop_time - start_time
#         algo_stats.append([problem_name, "RHC_{}".format(i), 
#                            best_state, best_fitness, max_attempts, curve_vals.size, curve_vals, runtime])

# dfstats = pd.DataFrame(algo_stats, columns=['Problem', 'Algorithm', 'Best_State', 'Best_Fitness', 'Max_Attempts', 'Iterations', 'Fitness', 'Runtime'])

# dfstats.sort_values(['Best_Fitness', 'Iterations'], ascending=[False, True]).iloc[0]

# plt.close('all')
# fig, axs = plt.subplots(1, 3, figsize=(20, 6), facecolor='w', edgecolor='k', sharex=True, sharey=True)
# fig.tight_layout()
# for ax, max_attempts in zip(axs.ravel(), [10, 50, 100]):
#     for i in range(0, dfstats[dfstats['Max_Attempts']==max_attempts].shape[0]):
#         ax.plot(dfstats[dfstats['Max_Attempts']==max_attempts].iloc[i]['Fitness'], 
#                 label=dfstats[dfstats['Max_Attempts']==max_attempts].iloc[i]['Algorithm'])
#         ax.set_title('{}: Fitness Vs Iterations \n(Max Attempts: {}, default)'.format(problem_name, max_attempts))
#         ax.legend(loc='lower right')
#         ax.set_xlabel('Interations')
#         ax.set_ylabel('Fitness')
#         ax.minorticks_on()
#         ax.grid(b=True, which='major', color='k', linestyle='-', alpha=0.1)
#         ax.grid(b=True, which='minor', color='r', linestyle='-', alpha=0.05)
    

# plt.savefig("{}_Fitness_With_Restarts.png".format(problem_name), bbox_inches='tight')  

# plt.close('all')
# fig, axs = plt.subplots(1, 3, figsize=(20, 6), facecolor='w', edgecolor='k', sharex=True, sharey=True)
# fig.tight_layout()
# for ax, max_attempts in zip(axs.ravel(), [10, 50, 100]):
#     for i in range(0, dfstats[dfstats['Max_Attempts']==max_attempts].shape[0]):
#         ax.stem(dfstats[dfstats['Max_Attempts']==max_attempts]['Algorithm'], dfstats[dfstats['Max_Attempts']==max_attempts]['Runtime'])
#         ax.stackplot(dfstats[dfstats['Max_Attempts']==max_attempts]['Algorithm'], dfstats[dfstats['Max_Attempts']==max_attempts]['Runtime'], labels=dfstats[dfstats['Max_Attempts']==max_attempts]['Algorithm'])
#         ax.set_title('{}: Runtime \n(Max Attempts: {}, w/Restarts)'.format(problem_name, max_attempts))
#         ax.set_xlabel('Algorithm')
#         ax.set_ylabel('Runtime (ms)')
#         ax.minorticks_on()
#         ax.grid(b=True, which='major', color='k', linestyle='-', alpha=0.1)
#         ax.grid(b=True, which='minor', color='r', linestyle='-', alpha=0.05)

# plt.savefig("{}_Runtime_With_Restarts.png".format(problem_name), bbox_inches='tight')

# %% [markdown]
# ### Genetic Algorithm -  Parameters

# %%
# Genetic Algorithm
# for max_attempts in range(start, stop, step):
#     print("Genetic Algorithm")
#     print("\t Attempt: {}\n".format(max_attempts))
#     start_time = time.time()*100
#     best_state, best_fitness, curve_vals = mlrose.genetic_alg(problem, 
#                                                               max_attempts=max_attempts, 
#                                                               curve=True, 
#                                                               random_state=random_state)
#     stop_time = time.time()*100
#     runtime = stop_time - start_time
#     algo_stats.append([problem_name, "Default_GA", best_state, best_fitness, max_attempts, curve_vals.size, curve_vals, runtime]) 

# for i in np.arange(0.5, 1.0, 0.05):
#     i = i.round(2)
#     print("Genetic Algorithm")
#     print("\t Attempt: {}\n".format(i))
#     for max_attempts in range(start, stop, step):
#         start_time = time.time()*100
#         best_state, best_fitness, curve_vals = mlrose.genetic_alg(problem, 
#                                                                   max_attempts=max_attempts, 
#                                                                   curve=True, 
#                                                                   random_state=random_state,
#                                                                   mutation_prob=0.9,
#                                                                   elite_dreg_ratio=0.9,
#                                                                   pop_breed_percent=0.55)
        
#         """
#         Best Genetic Algorithm Parameters
#             mutation_prob=0.9,
#             elite_dreg_ratio=0.9,
#             pop_breed_percent=0.55
#         """ 
#         stop_time = time.time()*100
#         runtime = stop_time - start_time
#         algo_stats.append([problem_name, "{}".format(i), best_state, best_fitness, max_attempts, curve_vals.size, curve_vals, runtime]) 

# dfstats = pd.DataFrame(algo_stats, columns=['Problem', 'Algorithm', 'Best_State', 'Best_Fitness', 'Max_Attempts', 'Iterations', 'Fitness', 'Runtime'])

# dfstats.sort_values(['Best_Fitness', 'Iterations'], ascending=[False, True]).iloc[0]

# plt.close('all')
# fig, axs = plt.subplots(1, 3, figsize=(20, 6), facecolor='w', edgecolor='k', sharex=True, sharey=True)
# fig.tight_layout()
# for ax, max_attempts in zip(axs.ravel(), [10, 50, 100]):
#     for i in range(0, dfstats[dfstats['Max_Attempts']==max_attempts].shape[0]):
#         ax.plot(dfstats[dfstats['Max_Attempts']==max_attempts].iloc[i]['Fitness'], 
#                 label=dfstats[dfstats['Max_Attempts']==max_attempts].iloc[i]['Algorithm'])
#         ax.set_title('{}: Fitness Vs Iterations \n(Max Attempts: {}, Mutation Probability)'.format(problem_name, max_attempts))
#         ax.legend(loc='lower right')
#         ax.set_xlabel('Interations')
#         ax.set_ylabel('Fitness')
#         ax.minorticks_on()
#         ax.grid(b=True, which='major', color='k', linestyle='-', alpha=0.1)
#         ax.grid(b=True, which='minor', color='r', linestyle='-', alpha=0.05)
    

# plt.savefig("{}_Fitness_With_Mutation_Probability.png".format(problem_name), bbox_inches='tight')  

# fig, axs = plt.subplots(1, 3, figsize=(20, 6), facecolor='w', edgecolor='k', sharex=True, sharey=True)
# fig.tight_layout()
# for ax, max_attempts in zip(axs.ravel(), [10, 50, 100]):
#     for i in range(0, dfstats[dfstats['Max_Attempts']==max_attempts].shape[0]):
#         ax.stem(dfstats[dfstats['Max_Attempts']==max_attempts]['Algorithm'], dfstats[dfstats['Max_Attempts']==max_attempts]['Runtime'])
#         ax.stackplot(dfstats[dfstats['Max_Attempts']==max_attempts]['Algorithm'], dfstats[dfstats['Max_Attempts']==max_attempts]['Runtime'], 
#                      labels=dfstats[dfstats['Max_Attempts']==max_attempts]['Algorithm'])
#         ax.set_title('{}: Runtime \n(Max Attempts: {}, Mutation Probability)'.format(problem_name, max_attempts))
#         ax.set_xlabel('Mutation Probability')
#         ax.set_ylabel('Runtime (ms)')
#         ax.minorticks_on()
#         ax.grid(b=True, which='major', color='k', linestyle='-', alpha=0.1)
#         ax.grid(b=True, which='minor', color='r', linestyle='-', alpha=0.05)

# plt.savefig("{}_Runtime_With_Mutation_Probability.png".format(problem_name), bbox_inches='tight')

# %% [markdown]
# ### Simulated Annealing -  Parameters

# %%
# Simulated Annealing
for max_attempts in range(start, stop, step):
    print("Simulated Annealing")
    print("\t Attempt: {}\n".format(max_attempts))
    start_time = time.time()*100
    best_state, best_fitness, curve_vals = mlrose.simulated_annealing(problem, max_attempts=max_attempts, curve=True, random_state=random_state)
    stop_time = time.time()*100
    runtime = stop_time - start_time
    algo_stats.append([problem_name, "Default", best_state, best_fitness, max_attempts, curve_vals.size, curve_vals, runtime]) 

decays = {"GeoDecay": mlrose.GeomDecay(init_temp=5.0, decay=0.75), 
          "ArithDecay": mlrose.ArithDecay(init_temp=5.0, decay=0.75), 
          "ExpDecay": mlrose.ExpDecay(init_temp=5.0, decay=0.75)}

for key in decays:
    print("Simulated Annealing")
    print("\t Attempt: {}\n".format(key))
    for max_attempts in range(start, stop, step):
        start_time = time.time()*100
        best_state, best_fitness, curve_vals = mlrose.simulated_annealing(problem, 
                                                                          max_attempts=max_attempts, 
                                                                          curve=True,
                                                                          random_state=random_state,
                                                                          schedule=decays[key])
        stop_time = time.time()*100
        runtime = stop_time - start_time
        algo_stats.append([problem_name, key, best_state, best_fitness, max_attempts, curve_vals.size, curve_vals, runtime]) 

dfstats = pd.DataFrame(algo_stats, columns=['Problem', 'Algorithm', 'Best_State', 'Best_Fitness', 'Max_Attempts', 'Iterations', 'Fitness', 'Runtime'])

dfstats.sort_values(['Best_Fitness', 'Iterations'], ascending=[False, True]).iloc[0]

plt.close('all')
fig, axs = plt.subplots(1, 3, figsize=(20, 6), facecolor='w', edgecolor='k', sharex=True, sharey=True)
fig.tight_layout()
for ax, max_attempts in zip(axs.ravel(), [10, 50, 100]):
    for i in range(0, dfstats[dfstats['Max_Attempts']==max_attempts].shape[0]):
        ax.plot(dfstats[dfstats['Max_Attempts']==max_attempts].iloc[i]['Fitness'], 
                label=dfstats[dfstats['Max_Attempts']==max_attempts].iloc[i]['Algorithm'])
        ax.set_title('{}: Fitness Vs Iterations \n(Max Attempts: {}, Decay)'.format(problem_name, max_attempts))
        ax.legend(loc='lower right')
        ax.set_xlabel('Interations')
        ax.set_ylabel('Fitness')
        ax.minorticks_on()
        ax.grid(b=True, which='major', color='k', linestyle='-', alpha=0.1)
        ax.grid(b=True, which='minor', color='r', linestyle='-', alpha=0.05)
    

plt.savefig("{}_Fitness_With_Mutations.png".format(problem_name), bbox_inches='tight')  

fig, axs = plt.subplots(1, 3, figsize=(20, 6), facecolor='w', edgecolor='k', sharex=True, sharey=True)
fig.tight_layout()
for ax, max_attempts in zip(axs.ravel(), [10, 50, 100]):
    for i in range(0, dfstats[dfstats['Max_Attempts']==max_attempts].shape[0]):
        ax.stem(dfstats[dfstats['Max_Attempts']==max_attempts]['Algorithm'], dfstats[dfstats['Max_Attempts']==max_attempts]['Runtime'])
        ax.stackplot(dfstats[dfstats['Max_Attempts']==max_attempts]['Algorithm'], dfstats[dfstats['Max_Attempts']==max_attempts]['Runtime'], labels=dfstats[dfstats['Max_Attempts']==max_attempts]['Algorithm'])
        ax.set_title('{}: Runtime \n(Max Attempts: {}, Decay)'.format(problem_name, max_attempts))
        ax.set_xlabel('Decay')
        ax.set_ylabel('Runtime (ms)')
        ax.minorticks_on()
        ax.grid(b=True, which='major', color='k', linestyle='-', alpha=0.1)
        ax.grid(b=True, which='minor', color='r', linestyle='-', alpha=0.05)

plt.savefig("{}_Runtime_With__Decay.png".format(problem_name), bbox_inches='tight')
# Out:
# Simulated Annealing
# 	 Attempt: 10
#
# Simulated Annealing
# 	 Attempt: 20
#
# Simulated Annealing
# 	 Attempt: 30
#
# Simulated Annealing
# 	 Attempt: 40
#
# Simulated Annealing
# 	 Attempt: 50
#
# Simulated Annealing
# 	 Attempt: 60
#
# Simulated Annealing
# 	 Attempt: 70
#
# Simulated Annealing
# 	 Attempt: 80
#
# Simulated Annealing
# 	 Attempt: 90
#
# Simulated Annealing
# 	 Attempt: 100
#
# Simulated Annealing
# 	 Attempt: GeoDecay
#
# Simulated Annealing
# 	 Attempt: ArithDecay
#
# Simulated Annealing
# 	 Attempt: ExpDecay

# %%
# # MIMIC
# for max_attempts in range(start, stop, step):
#     print("MIMIC")
#     print("\t Attempt: {}\n".format(max_attempts))
#     start_time = time.time()*100
#     best_state, best_fitness, curve_vals = mlrose.mimic(problem, max_attempts=max_attempts, curve=True, random_state=random_state)
#     stop_time = time.time()*100
#     runtime = stop_time - start_time
#     algo_stats.append([problem_name, "MIMIC", best_state, best_fitness, max_attempts, curve_vals.size, curve_vals, runtime])

# dfstats = pd.DataFrame(algo_stats, columns=['Problem', 'Algorithm', 'Best_State', 'Best_Fitness', 'Max_Attempts', 'Iterations', 'Fitness', 'Runtime'])

# dfstats.sort_values(['Best_Fitness', 'Iterations'], ascending=[False, True]).iloc[0]

# plt.close('all')
# fig, axs = plt.subplots(1, 3, figsize=(20, 6), facecolor='w', edgecolor='k', sharex=True, sharey=True)
# fig.tight_layout()
# for ax, max_attempts in zip(axs.ravel(), [10, 50, 100]):
#     for i in range(0, dfstats[dfstats['Max_Attempts']==max_attempts].shape[0]):
#         ax.plot(dfstats[dfstats['Max_Attempts']==max_attempts].iloc[i]['Fitness'], 
#                 label=dfstats[dfstats['Max_Attempts']==max_attempts].iloc[i]['Algorithm'])
#         ax.set_title('{}: Fitness Vs Iterations \n(Max Attempts: {}, default)'.format(problem_name, max_attempts))
#         ax.legend(loc='lower right')
#         ax.set_xlabel('Interations')
#         ax.set_ylabel('Fitness')
#         ax.minorticks_on()
#         ax.grid(b=True, which='major', color='k', linestyle='-', alpha=0.1)
#         ax.grid(b=True, which='minor', color='r', linestyle='-', alpha=0.05)
    

# plt.savefig("{}_Fitness_With_Mutations.png".format(problem_name), bbox_inches='tight')  

# plt.close('all')
# fig, axs = plt.subplots(1, 3, figsize=(20, 6), facecolor='w', edgecolor='k', sharex=True, sharey=True)
# fig.tight_layout()
# for ax, max_attempts in zip(axs.ravel(), [10, 50, 100]):
#     for i in range(0, dfstats[dfstats['Max_Attempts']==max_attempts].shape[0]):
#         ax.stem(dfstats[dfstats['Max_Attempts']==max_attempts]['Algorithm'], dfstats[dfstats['Max_Attempts']==max_attempts]['Runtime'])
#         ax.stackplot(dfstats[dfstats['Max_Attempts']==max_attempts]['Algorithm'], dfstats[dfstats['Max_Attempts']==max_attempts]['Runtime'], labels=dfstats[dfstats['Max_Attempts']==max_attempts]['Algorithm'])
#         ax.set_title('{}: Runtime \n(Max Attempts: {}, w/Restarts)'.format(problem_name, max_attempts))
#         ax.set_xlabel('Algorithm')
#         ax.set_ylabel('Runtime (ms)')
#         ax.minorticks_on()
#         ax.grid(b=True, which='major', color='k', linestyle='-', alpha=0.1)
#         ax.grid(b=True, which='minor', color='r', linestyle='-', alpha=0.05)

# plt.savefig("{}_Runtime_With_Mutations.png".format(problem_name), bbox_inches='tight')
