# %%
import ml_util as utl

# %%
problems = ["ContinuousPeaks"]
sizes = ["L"]

for prob in problems:
    for size in sizes:
        print(f"Current: \n\tProblem: {prob}\n\tSize: {size}")
        utl.run_optimization_tests(prob, size)
        print(f"Finished Problem:{prob} Size:{size}")
print("Hey")
# Out:
# Current:
# 	Problem: ContinuousPeaks
# 	Size: L
# created folder :  C:\Users\joshu\OneDrive - Georgia Institute of Technology\Georgia-Tech\CS 7641 - Machine Learning\Assignments\Randomized Optimization\ContinuousPeaks
# Randomized Hill Climbing Optimization:
# 	Total Iterations: 40
#
# Randomized Hill Climb:
# 	Current Best Fitness: 100000
# 	Current Iteration: 1
# 	Remaining Iterations: 39
# 	Elapsed Time: 0.004s
#
# Randomized Hill Climb:
# 	Current Best Fitness: 11.0
# 	Current Iteration: 2
# 	Remaining Iterations: 38
# 	Elapsed Time: 0.005s
#
# Randomized Hill Climb:
# 	Current Best Fitness: 11.0
# 	Current Iteration: 3
# 	Remaining Iterations: 37
# 	Elapsed Time: 0.006s
#
# Randomized Hill Climb:
# 	Current Best Fitness: 11.0
# 	Current Iteration: 4
# 	Remaining Iterations: 36
# 	Elapsed Time: 0.009s
#
# Randomized Hill Climb:
# 	Current Best Fitness: 11.0
# 	Current Iteration: 5
# 	Remaining Iterations: 35
# 	Elapsed Time: 0.009s
#
# Randomized Hill Climb:
# ...
