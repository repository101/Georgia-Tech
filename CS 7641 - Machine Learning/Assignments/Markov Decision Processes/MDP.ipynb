# %%
import MarkovDecisionProcesses as mdp
import numpy as np
from util import load_pickles
import os
import pickle
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import gridspec
import pandas as pd
plt.style.use("ggplot")
mpl.rcParams['figure.figsize'] = [8, 6]
mpl.rcParams['figure.dpi'] = 200
mpl.rcParams['savefig.dpi'] = 500

plt.tight_layout()
np.random.seed(42)

# %%
value_iteration_forest_large, policy_iteration_forest_large, q_learner_forest_large = mdp.run_large_forest()

# %%
raw_value_iteration, value_iteration_frozen_large, raw_policy_iteration, policy_iteration_frozen_large, raw_q_learner, q_learner_frozen_large = mdp.run_large_frozen()
# Out:
# Starting: Value Iteration
#
# Iter: 0  delta: 1.0
# Iter: 1  delta: 0.99
# Iter: 2  delta: 0.9801
# Iter: 3  delta: 0.9703
# Iter: 4  delta: 0.9606
# Iter: 5  delta: 0.95099
# Iter: 6  delta: 0.94148
# Iter: 7  delta: 0.93207
# Iter: 8  delta: 0.92274
# Iter: 9  delta: 0.91352
# Iter: 10  delta: 0.90438
# Iter: 11  delta: 0.89534
# Iter: 12  delta: 0.88638
# Iter: 13  delta: 0.87752
# Iter: 14  delta: 0.86875
# Iter: 15  delta: 0.86006
# Iter: 16  delta: 0.85146
# Iter: 17  delta: 0.84294
# Value Iteration
# 	Number of States: 100
# 	Max Iterations: 50000
# 	Gamma: 0.99
# 	Run Time: 0.06614s
# 	Average Score: 0.843
# 	Highest Score: 72.530
#
# Starting: Policy Iteration
#
# Policy-Iteration converged at step 19.
# Policy Iteration
# 	Number of States: 100
# 	Max Iterations: 50000
# 	Gamma: 0.99
# 	Run Time: 0.10141s
# 	Average Score: 0.843
# 	Highest Score: 72.530
#
# Starting: Q Learning
# Q Learner
# 	Number of States: 100
# 	Max Iterations: 400000
# 	Gamma: 0.99
# ...

# %%
all_data = load_pickles()

# %%
for key, _ in all_data.items():
    if "large" in key:
        print(key)
#         sep_key = key.split("_")
#         title = f"{sep_key[1][0].upper() + sep_key[1][1::]} {sep_key[2][0].upper() + sep_key[2][1::]} on {sep_key[-2][0].upper() + sep_key[-2][1::]} \n{sep_key[-1][0].upper() + sep_key[-1][1::]} for various {sep_key[-3][0].upper() + sep_key[-3][1::]}"
#         all_data[key].plot(title=title, figsize=(10,6))
#         plt.savefig(f"junk/{key}.png")
# Out:
# large_policy_iteration_gamma_forest_reward
# large_policy_iteration_gamma_forest_runtime
# large_policy_iteration_gamma_frozen_reward
# large_policy_iteration_gamma_frozen_runtime
# large_policy_iteration_eps_forest_reward
# large_policy_iteration_eps_forest_runtime
# large_policy_iteration_eps_frozen_reward
# large_policy_iteration_eps_frozen_runtime
# large_value_iteration_gamma_forest_reward
# large_value_iteration_gamma_forest_runtime
# large_value_iteration_gamma_frozen_reward
# large_value_iteration_gamma_frozen_runtime
# large_value_iteration_eps_forest_reward
# large_value_iteration_eps_forest_runtime
# large_value_iteration_eps_frozen_reward
# large_value_iteration_eps_frozen_runtime
# large_q_learner_gamma_forest_reward
# large_q_learner_gamma_forest_runtime
# large_q_learner_gamma_frozen_reward
# large_q_learner_gamma_frozen_runtime
# large_q_learner_eps_forest_reward
# large_q_learner_eps_forest_runtime
# large_q_learner_eps_frozen_reward
# ...

# %%
plt.close("all")
plt.style.use("ggplot")
fig = plt.figure(figsize=(12, 8), constrained_layout=True)
gs = gridspec.GridSpec(2, 2, width_ratios=[4, 4], height_ratios=[4,4], figure=fig, wspace=0.05, hspace=0.15)
ax0 = plt.subplot(gs[0, 0])
ax1 = plt.subplot(gs[0, 1])
ax2 = plt.subplot(gs[1, 0])
ax3 = plt.subplot(gs[1, 1])

all_data["large_q_learner_gamma_forest_reward"].plot(title="0", ax=ax0)
all_data["large_q_learner_eps_forest_reward"].plot(title="0", ax=ax2)
all_data["large_q_learner_gamma_forest_runtime"].plot(title="0", ax=ax1)
all_data["large_q_learner_eps_forest_runtime"].plot(title="0", ax=ax3)
problem = "Forest Management"
learner = "Q-Learner"


xlabel = "Iterations"
ylabel_reward = "Reward"
ylabel_runtime = "Runtime"
ax0.set_ylabel(f"{ylabel_reward}", fontsize=10, weight='heavy')
ax0.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax0.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax0.set_title(f"Reward Vs Gamma\n{learner}\n{problem}", fontsize=12, weight='bold')

ax1.set_ylabel(f"{ylabel_runtime}", fontsize=10, weight='heavy')
ax1.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax1.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax1.set_title(f"Runtime Vs Gamma\n{learner}\n{problem}", fontsize=12, weight='bold')

ax2.set_ylabel(f"{ylabel_reward}", fontsize=10, weight='heavy')
ax2.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax2.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax2.set_title(f"Reward Vs Epsilon\n{learner}\n{problem}", fontsize=12, weight='bold')

ax3.set_ylabel(f"{ylabel_runtime}", fontsize=10, weight='heavy')
ax3.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax3.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax3.set_title(f"Runtime Vs Epsilon\n{learner}\n{problem}", fontsize=12, weight='bold')

plt.savefig(f"{problem}_Varied_Hyper_parameters_{learner}.png")

# %%
plt.close("all")
plt.style.use("ggplot")
fig = plt.figure(figsize=(12, 8), constrained_layout=True)
gs = gridspec.GridSpec(2, 2, width_ratios=[4, 4], height_ratios=[4,4], figure=fig, wspace=0.05, hspace=0.15)
ax0 = plt.subplot(gs[0, 0])
ax1 = plt.subplot(gs[0, 1])
ax2 = plt.subplot(gs[1, 0])
ax3 = plt.subplot(gs[1, 1])

all_data["large_q_learner_gamma_frozen_reward"].plot(title="0", ax=ax0)
all_data["large_q_learner_eps_frozen_reward"].plot(title="0", ax=ax2)
all_data["large_q_learner_gamma_frozen_runtime"].plot(title="0", ax=ax1)
all_data["large_q_learner_eps_frozen_runtime"].plot(title="0", ax=ax3)
problem = "Frozen Lake"
learner = "Q-Learner"


xlabel = "Iterations"
ylabel_reward = "Reward"
ylabel_runtime = "Runtime"
ax0.set_ylabel(f"{ylabel_reward}", fontsize=10, weight='heavy')
ax0.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax0.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax0.set_title(f"Reward Vs Gamma\n{learner}\n{problem}", fontsize=12, weight='bold')

ax1.set_ylabel(f"{ylabel_runtime}", fontsize=10, weight='heavy')
ax1.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax1.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax1.set_title(f"Runtime Vs Gamma\n{learner}\n{problem}", fontsize=12, weight='bold')

ax2.set_ylabel(f"{ylabel_reward}", fontsize=10, weight='heavy')
ax2.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax2.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax2.set_title(f"Reward Vs Epsilon\n{learner}\n{problem}", fontsize=12, weight='bold')

ax3.set_ylabel(f"{ylabel_runtime}", fontsize=10, weight='heavy')
ax3.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax3.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax3.set_title(f"Runtime Vs Epsilon\n{learner}\n{problem}", fontsize=12, weight='bold')

plt.savefig(f"{problem}_Varied_Hyper_parameters_{learner}.png")

# %%
plt.close("all")
plt.style.use("ggplot")
fig = plt.figure(figsize=(12, 8), constrained_layout=True)
gs = gridspec.GridSpec(2, 2, width_ratios=[4, 4], height_ratios=[4,4], figure=fig, wspace=0.05, hspace=0.15)
ax0 = plt.subplot(gs[0, 0])
ax1 = plt.subplot(gs[0, 1])
ax2 = plt.subplot(gs[1, 0])
ax3 = plt.subplot(gs[1, 1])

all_data["large_policy_iteration_gamma_forest_reward"].plot(title="0", ax=ax0)
all_data["large_policy_iteration_eps_forest_reward"].plot(title="0", ax=ax2)
all_data["large_policy_iteration_gamma_forest_runtime"].plot(title="0", ax=ax1)
all_data["large_policy_iteration_eps_forest_runtime"].plot(title="0", ax=ax3)
problem = "Forest Management"
learner = "Policy Iteration"


xlabel = "Iterations"
ylabel_reward = "Reward"
ylabel_runtime = "Runtime"
ax0.set_ylabel(f"{ylabel_reward}", fontsize=10, weight='heavy')
ax0.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax0.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax0.set_title(f"Reward Vs Gamma\n{learner}\n{problem}", fontsize=12, weight='bold')

ax1.set_ylabel(f"{ylabel_runtime}", fontsize=10, weight='heavy')
ax1.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax1.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax1.set_title(f"Runtime Vs Gamma\n{learner}\n{problem}", fontsize=12, weight='bold')

ax2.set_ylabel(f"{ylabel_reward}", fontsize=10, weight='heavy')
ax2.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax2.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax2.set_title(f"Reward Vs Epsilon\n{learner}\n{problem}", fontsize=12, weight='bold')

ax3.set_ylabel(f"{ylabel_runtime}", fontsize=10, weight='heavy')
ax3.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax3.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax3.set_title(f"Runtime Vs Epsilon\n{learner}\n{problem}", fontsize=12, weight='bold')

plt.savefig(f"{problem}_Varied_Hyper_parameters_{learner}.png")

# %%
plt.close("all")
plt.style.use("ggplot")
fig = plt.figure(figsize=(12, 8), constrained_layout=True)
gs = gridspec.GridSpec(2, 2, width_ratios=[4, 4], height_ratios=[4,4], figure=fig, wspace=0.05, hspace=0.15)
ax0 = plt.subplot(gs[0, 0])
ax1 = plt.subplot(gs[0, 1])
ax2 = plt.subplot(gs[1, 0])
ax3 = plt.subplot(gs[1, 1])

all_data["large_policy_iteration_gamma_frozen_reward"].plot(title="0", ax=ax0)
all_data["large_policy_iteration_eps_frozen_reward"].plot(title="0", ax=ax2)
all_data["large_policy_iteration_gamma_frozen_runtime"].plot(title="0", ax=ax1)
all_data["large_policy_iteration_eps_frozen_runtime"].plot(title="0", ax=ax3)
problem = "Frozen Lake"
learner = "Policy Iteration"


xlabel = "Iterations"
ylabel_reward = "Reward"
ylabel_runtime = "Runtime"
ax0.set_ylabel(f"{ylabel_reward}", fontsize=10, weight='heavy')
ax0.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax0.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax0.set_title(f"Reward Vs Gamma\n{learner}\n{problem}", fontsize=12, weight='bold')

ax1.set_ylabel(f"{ylabel_runtime}", fontsize=10, weight='heavy')
ax1.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax1.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax1.set_title(f"Runtime Vs Gamma\n{learner}\n{problem}", fontsize=12, weight='bold')

ax2.set_ylabel(f"{ylabel_reward}", fontsize=10, weight='heavy')
ax2.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax2.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax2.set_title(f"Reward Vs Epsilon\n{learner}\n{problem}", fontsize=12, weight='bold')

ax3.set_ylabel(f"{ylabel_runtime}", fontsize=10, weight='heavy')
ax3.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax3.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax3.set_title(f"Runtime Vs Epsilon\n{learner}\n{problem}", fontsize=12, weight='bold')

plt.savefig(f"{problem}_Varied_Hyper_parameters_{learner}.png")

# %%
plt.close("all")
plt.style.use("ggplot")
fig = plt.figure(figsize=(12, 8), constrained_layout=True)
gs = gridspec.GridSpec(2, 2, width_ratios=[4, 4], height_ratios=[4,4], figure=fig, wspace=0.05, hspace=0.15)
ax0 = plt.subplot(gs[0, 0])
ax1 = plt.subplot(gs[0, 1])
ax2 = plt.subplot(gs[1, 0])
ax3 = plt.subplot(gs[1, 1])

all_data["large_value_iteration_gamma_forest_reward"].plot(title="0", ax=ax0)
all_data["large_value_iteration_eps_forest_reward"].plot(title="0", ax=ax2)
all_data["large_value_iteration_gamma_forest_runtime"].plot(title="0", ax=ax1)
all_data["large_value_iteration_eps_forest_runtime"].plot(title="0", ax=ax3)
problem = "Forest Management"
learner = "Value Iteration"


xlabel = "Iterations"
ylabel_reward = "Reward"
ylabel_runtime = "Runtime"
ax0.set_ylabel(f"{ylabel_reward}", fontsize=10, weight='heavy')
ax0.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax0.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax0.set_title(f"Reward Vs Gamma\n{learner}\n{problem}", fontsize=12, weight='bold')

ax1.set_ylabel(f"{ylabel_runtime}", fontsize=10, weight='heavy')
ax1.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax1.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax1.set_title(f"Runtime Vs Gamma\n{learner}\n{problem}", fontsize=12, weight='bold')

ax2.set_ylabel(f"{ylabel_reward}", fontsize=10, weight='heavy')
ax2.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax2.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax2.set_title(f"Reward Vs Epsilon\n{learner}\n{problem}", fontsize=12, weight='bold')

ax3.set_ylabel(f"{ylabel_runtime}", fontsize=10, weight='heavy')
ax3.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax3.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax3.set_title(f"Runtime Vs Epsilon\n{learner}\n{problem}", fontsize=12, weight='bold')

plt.savefig(f"{problem}_Varied_Hyper_parameters_{learner}.png")

# %%
plt.close("all")
plt.style.use("ggplot")
fig = plt.figure(figsize=(12, 8), constrained_layout=True)
gs = gridspec.GridSpec(2, 2, width_ratios=[4, 4], height_ratios=[4,4], figure=fig, wspace=0.05, hspace=0.15)
ax0 = plt.subplot(gs[0, 0])
ax1 = plt.subplot(gs[0, 1])
ax2 = plt.subplot(gs[1, 0])
ax3 = plt.subplot(gs[1, 1])

all_data["large_value_iteration_gamma_frozen_reward"].plot(title="0", ax=ax0)
all_data["large_value_iteration_eps_frozen_reward"].plot(title="0", ax=ax2)
all_data["large_value_iteration_gamma_frozen_runtime"].plot(title="0", ax=ax1)
all_data["large_value_iteration_eps_frozen_runtime"].plot(title="0", ax=ax3)
problem = "Frozen Lake"
learner = "Value Iteration"


xlabel = "Iterations"
ylabel_reward = "Reward"
ylabel_runtime = "Runtime"
ax0.set_ylabel(f"{ylabel_reward}", fontsize=10, weight='heavy')
ax0.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax0.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax0.set_title(f"Reward Vs Gamma\n{learner}\n{problem}", fontsize=12, weight='bold')

ax1.set_ylabel(f"{ylabel_runtime}", fontsize=10, weight='heavy')
ax1.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax1.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax1.set_title(f"Runtime Vs Gamma\n{learner}\n{problem}", fontsize=12, weight='bold')

ax2.set_ylabel(f"{ylabel_reward}", fontsize=10, weight='heavy')
ax2.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax2.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax2.set_title(f"Reward Vs Epsilon\n{learner}\n{problem}", fontsize=12, weight='bold')

ax3.set_ylabel(f"{ylabel_runtime}", fontsize=10, weight='heavy')
ax3.set_xlabel(f"{xlabel}", fontsize=10, weight='heavy')
ax3.legend(loc="best", markerscale=0.9, frameon=True, edgecolor="black", fancybox=True,
           shadow=True, fontsize=10)
ax3.set_title(f"Runtime Vs Epsilon\n{learner}\n{problem}", fontsize=12, weight='bold')

plt.savefig(f"{problem}_Varied_Hyper_parameters_{learner}.png")
